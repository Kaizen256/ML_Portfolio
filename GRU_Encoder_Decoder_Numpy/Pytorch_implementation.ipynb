# %% [markdown]
# Pytorch implementation for practice.

# %%
import torch
from torch import nn, optim
import numpy as np
import re
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Lists for cleaned sentences
eng_sentences = []
jpn_sentences = []

# To avoid duplicates
seen = set()

with open("jpn.txt", "r", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split("\t")

        # Extract English and Japanese parts
        eng = parts[0].strip().lower()
        jpn = parts[1].strip().lower()

        # Clean English: keep lowercase letters, numbers, and spaces
        eng = re.sub(r"[^a-z0-9\s]", "", eng)

        # Clean Japanese: keep the punctuation
        jpn = re.sub(r"[^\u3040-\u30ff\u4e00-\u9fff。、！？\s]", "", jpn)
        
        if eng not in seen:
            eng_sentences.append(eng)
            jpn_sentences.append(jpn)
            seen.add(eng)

print(f"English Sentences: {eng_sentences[0:10]}")
print(f"English Sentences Length: {len(eng_sentences)}")
print(f"Japanese Sentences: {jpn_sentences[0:10]}")
print(f"Japanese Sentences Length: {len(jpn_sentences)}")
# Out:
# cuda
# English Sentences: ['go', 'hi', 'run', 'who', 'wow', 'duck', 'fire', 'help', 'hide', 'jump']
# English Sentences Length: 94468
# Japanese Sentences: ['行け。', 'こんにちは。', '走れ。', '誰？', 'すごい！', '頭を下げろ！', '火事だ！', '助けて！', '隠れろ。', '飛び越えろ！']
# Japanese Sentences Length: 94468

# %%
from collections import Counter

counter = Counter()

# Count word frequency
for sent in eng_sentences:
    counter.update(sent.split())
    
# English to index mapping
eng_to_ind = {'<pad>': 0, '<unk>':1}
ind = 2

# Include words that appear 3+ times.
for word in counter:
    if counter[word] > 2:
        eng_to_ind[word] = ind
        ind += 1

jcounter = Counter()
# Count character frequency across Japanese sentences
for sent in jpn_sentences:
    jcounter.update(list(sent))

# Japanese to index and index to Japanese mapping
jpn_to_ind = {'<pad>': 0, '<unk>': 1, '<bos>': 2, '<eos>': 3}
ind_to_jpn = {0: '<pad>', 1: '<unk>', 2: '<bos>', 3: '<eos>'}
ind = 4

# Include characters that appear 3+ times
for word in jcounter:
    if jcounter[word] > 2:
        jpn_to_ind[word] = ind
        ind_to_jpn[ind] = word
        ind += 1

print("English Vocabulary Size:", len(eng_to_ind))
print("Japanese Vocabulary Size:", len(jpn_to_ind))
print(ind_to_jpn)
# Out:
# English Vocabulary Size: 6410
# Japanese Vocabulary Size: 2020
# {0: '<pad>', 1: '<unk>', 2: '<bos>', 3: '<eos>', 4: '行', 5: 'け', 6: '。', 7: 'こ', 8: 'ん', 9: 'に', 10: 'ち', 11: 'は', 12: '走', 13: 'れ', 14: '誰', 15: '？', 16: 'す', 17: 'ご', 18: 'い', 19: '！', 20: '頭', 21: 'を', 22: '下', 23: 'げ', 24: 'ろ', 25: '火', 26: '事', 27: 'だ', 28: '助', 29: 'て', 30: '隠', 31: '飛', 32: 'び', 33: '越', 34: 'え', 35: 'や', 36: 'め', 37: '待', 38: 'っ', 39: '続', 40: '急', 41: 'か', 42: 'じ', 43: 'た', 44: 'な', 45: 'る', 46: 'ほ', 47: 'ど', 48: '頑', 49: '張', 50: 'み', 51: '俺', 52: 'の', 53: '勝', 54: 'ー', 55: '落', 56: '着', 57: '撃', 58: '、', 59: 'チ', 60: 'ズ', 61: '買', 62: '乾', 63: '杯', 64: '直', 65: 'し', 66: '動', 67: 'く', 68: '起', 69: 'き', 70: 'さ', 71: 'あ', 72: 'と', 73: 'で', 74: '捕', 75: 'ま', 76: '彼', 77: '乗', 78: 'よ', 79: '抱', 80: '分', 81: '出', 82: '発', 83: '負', 84: '・', 85: '払', 86: '辞', 87: '職', 88: '歳', 89: '私', 90: '才', 91: '大', 92: '丈', 93: '夫', 94: '目', 95: '覚', 96: '聞', 97: '馬', 98: '鹿', 99: '本', 100: '当', 101: 'り', 102: 'が', 103: 'う', 104: '食', 105: 'べ', 106: '努', 107: '力', 108: 'お', 109: 'ら', 110: '何', 111: 'わ', 112: '僕', 113: 'ト', 114: 'ム', 115: 'ぞ', 116: '子', 117: '儀', 118: '連', 119: '絡', 120: 'ょ', 121: '電', 122: '話', 123: '入', 124: '向', 125: 'へ', 126: '帰', 127: 'ゆ', 128: '来', 129: '手', 130: '伝', 131: 'ハ', 132: 'イ', 133: '殴', 134: '悲', 135: '賛', 136: '成', 137: 'ば', 138: '吸', 139: '申', 140: '太', 141: 'も', 142: '年', 143: '引', 144: '込', 145: '思', 146: '案', 147: '仲', 148: '間', 149: '取', 150: '開', 151: 'バ', 152: 'ッ', 153: 'リ', 154: '会', 155: '見', 156: 'せ', 157: '黙', 158: '教', 159: '片', 160: '付', 161: '洗', 162: '知', 163: 'ぜ', 164: '君', 165: '男', 166: '勇', 167: '気', 168: '元', 169: '冷', 170: 'ゃ', 171: '探', 172: 'マ', 173: 'ジ', 174: '床', 175: '伏', 176: '静', 177: '考', 178: '先', 179: '楽', 180: 'ね', 181: '可', 182: '愛', 183: '深', 184: '失', 185: '敬', 186: 'ぎ', 187: '敗', 188: '忘', 189: '了', 190: '解', 191: '持', 192: 'そ', 193: '使', 194: '忙', 195: 'ク', 196: 'ル', 197: '公', 198: '平', 199: '暇', 200: '満', 201: '腹', 202: '道', 203: '迷', 204: '貧', 205: '乏', 206: '病', 207: '背', 208: '高', 209: '痛', 210: '新', 211: '妙', 212: '茶', 213: '立', 214: '禁', 215: 'ず', 216: '放', 217: '危', 218: '結', 219: '婚', 220: '止', 221: 'ス', 222: 'プ', 223: '言', 224: '座', 225: '死', 226: '逃', 227: '嘘', 228: 'つ', 229: '泳', 230: '涙', 231: '流', 232: '遅', 233: '任', 234: '精', 235: '一', 236: '警', 237: '告', 238: '意', 239: '致', 240: '次', 241: '質', 242: '問', 243: '答', 244: '謝', 245: '鳥', 246: 'ぶ', 247: '家', 248: '戻', 249: 'ぐ', 250: '今', 251: '泣', 252: '礼', 253: '寝', 254: '触', 255: '尻', 256: '重', 257: 'ド', 258: '恐', 259: '景', 260: '機', 261: '嫌', 262: '確', 263: 'キ', 264: '拍', 265: '残', 266: '念', 267: '降', 268: '参', 269: '怒', 270: '濡', 271: '叩', 272: '笑', 273: '好', 274: 'づ', 275: '約', 276: '束', 277: 'ラ', 278: 'ダ', 279: 'メ', 280: '欲', 281: '狂', 282: '同', 283: '通', 284: '官', 285: '人', 286: '退', 287: '屈', 288: '敢', 289: '文', 290: '無', 291: '潔', 292: '白', 293: '酔', 294: '早', 295: '番', 296: '几', 297: '帳', 298: '面', 299: '幸', 300: '福', 301: '細', 302: '準', 303: '備', 304: '悪', 305: '疲', 306: '若', 307: '視', 308: '遠', 309: '暑', 310: '品', 311: '超', 312: '臭', 313: '時', 314: '半', 315: 'テ', 316: 'レ', 317: 'ビ', 318: '寒', 319: 'カ', 320: 'コ', 321: '絶', 322: '交', 323: '料', 324: '変', 325: 'ワ', 326: 'ン', 327: '仕', 328: '離', 329: '中', 330: '後', 331: '読', 332: '前', 333: '述', 334: '照', 335: '女', 336: '試', 337: 'サ', 338: 'ピ', 339: '近', 340: '用', 341: '心', 342: 'ざ', 343: '図', 344: '星', 345: '去', 346: '終', 347: '理', 348: '飲', 349: '運', 350: '転', 351: '編', 352: '物', 353: '挑', 354: '戦', 355: '振', 356: '恥', 357: '屋', 358: '度', 359: '左', 360: '曲', 361: '鍵', 362: '功', 363: '紙', 364: '書', 365: '皆', 366: '正', 367: '違', 368: '周', 369: '辛', 370: 'ふ', 371: '歌', 372: '認', 373: '選', 374: '緒', 375: '混', 376: '滑', 377: '押', 378: 'む', 379: 'タ', 380: '燃', 381: '従', 382: '許', 383: 'ベ', 384: '諦', 385: '外', 386: '神', 387: '存', 388: '在', 389: '切', 390: '優', 391: '利', 392: '口', 393: '温', 394: '上', 395: '賢', 396: '惨', 397: '悟', 398: '壊', 399: '作', 400: '跳', 401: '歩', 402: '羨', 403: '別', 404: 'パ', 405: '恋', 406: '居', 407: '淋', 408: '必', 409 ...

# %%
eng_encoded = []

# Encode each English sentence at word level
# Maximum of 18 words per sentence
for sentence in eng_sentences:
    s = []
    for word in sentence.split():
        if word in eng_to_ind:
            s.append(eng_to_ind[word])
        else:
            s.append(1)
        if len(s) > 17:
            break
    while(len(s) < 18):
        s.append(0) # Padding
    eng_encoded.append(s)

jpn_encoded = []

# Encode each Japanese sentence character level
# Maximum of 45 characters per sentence including <bos> and <eos>
for sentence in jpn_sentences:
    s = [2] # 2 is <bos>
    for ch in sentence:
        if len(s) > 43:
            break # We need room to fit <eos> token.
        if ch in jpn_to_ind:
            s.append(jpn_to_ind[ch])
        else:
            s.append(1)   # 1 is <unk>
    s.append(3)           # 3 is <eos>
    while(len(s) < 45):
        s.append(0)       # 0 is <pad>
    jpn_encoded.append(s)

print(f"English Sentences Encoded Length: {len(eng_encoded)}")
print(f"Japanese Sentences Encoded Length: {len(jpn_encoded)}")
# Out:
# English Sentences Encoded Length: 94468
# Japanese Sentences Encoded Length: 94468

# %% [markdown]
# int(min(600, 1.6 * eng_vocab_size ** 0.56)) = 216
# int(min(600, 1.6 * jpn_vocab_size ** 0.56)) = 114

# %%
class Translator(nn.Module):
    def __init__(self, eng_vocab_size, jpn_vocab_size, enc_embed_size, dec_embed_size, hidden_size):
        super().__init__()
        self.enc_embed = nn.Embedding(num_embeddings=eng_vocab_size, embedding_dim=enc_embed_size, padding_idx=0)
        self.encoder = nn.LSTM(enc_embed_size, hidden_size, batch_first=True, num_layers=2, dropout=0.3, bidirectional=True)
        
        self.dec_embed = nn.Embedding(num_embeddings=jpn_vocab_size, embedding_dim=dec_embed_size, padding_idx=0)
        self.decoder = nn.LSTM(dec_embed_size, hidden_size, batch_first=True, num_layers=2, dropout=0.3)

        self.out = nn.Linear(hidden_size, jpn_vocab_size)
    
    def forward(self, x, y):
        x = self.enc_embed(x)
        _, (h, c) = self.encoder(x)

        # Reshape from (num_layers*2, batch, hidden) to (num_layers, 2, batch, hidden)
        h = h.view(self.encoder.num_layers, 2, x.size(0), self.encoder.hidden_size)
        c = c.view(self.encoder.num_layers, 2, x.size(0), self.encoder.hidden_size)

        # Sum forward and backward directions: (num_layers, batch, hidden)
        h = h.sum(dim=1)
        c = c.sum(dim=1)


        y = self.dec_embed(y)
        output, _ = self.decoder(y, (h, c))

        logits = self.out(output)
        return logits

# %%
from torch.utils.data import DataLoader, TensorDataset

X_tensor = torch.tensor(eng_encoded)
y_tensor = torch.tensor(jpn_encoded)

train_dataset = TensorDataset(X_tensor, y_tensor)
train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)

# %%
model = Translator(len(eng_to_ind), len(jpn_to_ind), 215, 115, 128).to(device)
loss_fn = nn.CrossEntropyLoss(ignore_index=0)
optim = optim.Adam(model.parameters(), lr=0.001)

epochs = 300
past_loss = []
for epoch in range(epochs):
    total_loss = 0

    for xb, yb in train_dataloader:
        xb = xb.to(device)
        yb = yb.to(device)
        optim.zero_grad()

        logits = model(xb, yb[:, :-1])
        targets = yb[:, 1:]

        logits = logits.reshape(-1, logits.size(-1))
        targets = targets.reshape(-1)

        loss = loss_fn(logits, targets)
        loss.backward()
        optim.step()

        total_loss += loss.item() * xb.size(0)
    total_loss = total_loss / len(eng_encoded)
    print(f"Epoch {epoch+1} | Loss: {total_loss:.4f}")
    if len(past_loss) > 5:
        if past_loss[-1] < total_loss and past_loss[-2] < past_loss[-1]:
            break
    past_loss.append(total_loss)
# Out:
# Epoch 1 | Loss: 3.6098
# Epoch 2 | Loss: 2.7116
# Epoch 3 | Loss: 2.4080
# Epoch 4 | Loss: 2.2116
# Epoch 5 | Loss: 2.0659
# Epoch 6 | Loss: 1.9541
# Epoch 7 | Loss: 1.8642
# Epoch 8 | Loss: 1.7895
# Epoch 9 | Loss: 1.7271
# Epoch 10 | Loss: 1.6737
# Epoch 11 | Loss: 1.6265
# Epoch 12 | Loss: 1.5873
# Epoch 13 | Loss: 1.5500
# Epoch 14 | Loss: 1.5168
# Epoch 15 | Loss: 1.4884
# Epoch 16 | Loss: 1.4610
# Epoch 17 | Loss: 1.4355
# Epoch 18 | Loss: 1.4132
# Epoch 19 | Loss: 1.3909
# Epoch 20 | Loss: 1.3711
# Epoch 21 | Loss: 1.3535
# Epoch 22 | Loss: 1.3360
# Epoch 23 | Loss: 1.3197
# Epoch 24 | Loss: 1.3047
# Epoch 25 | Loss: 1.2904
# Epoch 26 | Loss: 1.2757
# Epoch 27 | Loss: 1.2629
# Epoch 28 | Loss: 1.2506
# Epoch 29 | Loss: 1.2392
# Epoch 30 | Loss: 1.2272
# Epoch 31 | Loss: 1.2159
# Epoch 32 | Loss: 1.2064
# Epoch 33 | Loss: 1.1965
# Epoch 34 | Loss: 1.1869
# Epoch 35 | Loss: 1.1770
# Epoch 36 | Loss: 1.1688
# Epoch 37 | Loss: 1.1609
# Epoch 38 | Loss: 1.1525
# Epoch 39 | Loss: 1.1450
# Epoch 40 | Loss: 1.1352
# Epoch 41 | Loss: 1.1298
# Epoch 42 | Loss: 1.1226
# Epoch 43 | Loss: 1.1153
# Epoch 44 | Loss: 1.1088
# Epoch 45 | Loss: 1.1024
# Epoch 46 | Loss: 1.0953
# Epoch 47 | Loss: 1.0899
# Epoch 48 | Loss: 1.0829
# Epoch 49 | Loss: 1.0792
# Epoch 50 | Loss: 1.0726
# Epoch 51 | Loss: 1.0667
# Epoch 52 | Loss: 1.0628
# Epoch 53 | Loss: 1.0573
# Epoch 54 | Loss: 1.0531
# Epoch 55 | Loss: 1.0473
# Epoch 56 | Loss: 1.0438
# Epoch 57 | Loss: 1.0389
# Epoch 58 | Loss: 1.0341
# Epoch 59 | Loss: 1.0291
# Epoch 60 | Loss: 1.0251
# Epoch 61 | Loss: 1.0215
# Epoch 62 | Loss: 1.0176
# Epoch 63 | Loss: 1.0118
# Epoch 64 | Loss: 1.0104
# Epoch 65 | Loss: 1.0057
# Epoch 66 | Loss: 1.0007
# Epoch 67 | Loss: 0.9981
# Epoch 68 | Loss: 0.9943
# Epoch 69 | Loss: 0.9914
# Epoch 70 | Loss: 0.9869
# Epoch 71 | Loss: 0.9834
# Epoch 72 | Loss: 0.9816
# Epoch 73 | Loss: 0.9778
# Epoch 74 | Loss: 0.9738
# Epoch 75 | Loss: 0.9723
# Epoch 76 | Loss: 0.9690
# Epoch 77 | Loss: 0.9651
# Epoch 78 | Loss: 0.9614
# Epoch 79 | Loss: 0.9602
# Epoch 80 | Loss: 0.9563
# Epoch 81 | Loss: 0.9538
# Epoch 82 | Loss: 0.9517
# Epoch 83 | Loss: 0.9487
# Epoch 84 | Loss: 0.9476
# Epoch 85 | Loss: 0.9446
# Epoch 86 | Loss: 0.9412
# Epoch 87 | Loss: 0.9388
# Epoch 88 | Loss: 0.9373
# Epoch 89 | Loss: 0.9352
# Epoch 90 | Loss: 0.9317
# Epoch 91 | Loss: 0.9292
# Epoch 92 | Loss: 0.9273
# Epoch 93 | Loss: 0.9267
# Epoch 94 | Loss: 0.9224
# Epoch 95 | Loss: 0.9210
# Epoch 96 | Loss: 0.9198
# Epoch 97 | Loss: 0.9168
# Epoch 98 | Loss: 0.9142
# Epoch 99 | Loss: 0.9134
# Epoch 100 | Loss: 0.9111
# Epoch 101 | Loss: 0.9087
# Epoch 102 | Loss: 0.9081
# Epoch 103 | Loss: 0.9057
# Epoch 104 | Loss: 0.9025
# Epoch 105 | Loss: 0.9017
# Epoch 106 | Loss: 0.9005
# Epoch 107 | Loss: 0.8976
# Epoch 108 | Loss: 0.8976
# Epoch 109 | Loss: 0.8950
# Epoch 110 | Loss: 0.8939
# Epoch 111 | Loss: 0.8913
# Epoch 112 | Loss: 0.8896
# Epoch 113 | Loss: 0.8876
# Epoch 114 | Loss: 0.8871
# Epoch 115 | Loss: 0.8863
# Epoch 116 | Loss: 0.8829
# Epoch 117 | Loss: 0.8815
# Epoch 118 | Loss: 0.8811
# Epoch 119 | Loss: 0.8799
# Epoch 120 | Loss: 0.8778
# Epoch 121 | Loss: 0.8763
# Epoch 122 | Loss: 0.8742
# Epoch 123 | Loss: 0.8733
# Epoch 124 | Loss: 0.8717
# Epoch 125 | Loss: 0.8704
# Epoch 126 | Loss: 0.8673
# Epoch 127 | Loss: 0.8679
# Epoch 128 | Loss: 0.8662
# Epoch 129 | Loss: 0.8653
# Epoch 130 | Loss: 0.8640
# Epoch 131 | Loss: 0.8631
# Epoch 132 | Loss: 0.8607
# Epoch 133 | Loss: 0.8589
# Epoch 134 | Loss: 0.8595
# Epoch 135 | Loss: 0.8569
# Epoch 136 | Loss: 0.8562
# Epoch 137 | Loss: 0.8564
# Epoch 138 | Loss: 0.8536
# Epoch 139 | Loss: 0.8520
# Epoch 140 | Loss: 0.8518
# Epoch 141 | Loss: 0.8503
# Epoch 142 | Loss: 0.8492
# Epoch 143 | Loss: 0.8474
# Epoch 144 | Loss: 0.8480
# Epoch 145 | Loss: 0.8469
# Epoch 146 | Loss: 0.8448
# Epoch 147 | Loss: 0.8437
# Epoch 148 | Loss: 0.8424
# Epoch 149 | Loss: 0.8415
# Epoch 150 | Loss: 0.8418
# Epoch 151 | Loss: 0.8392
# Epoch 152 | Loss: 0.8403
# Epoch 153 | Loss: 0.8370
# Epoch 154 | Loss: 0.8372
# Epoch 155 | Loss: 0.8350
# Epoch 156 | Loss: 0.8360
# Epoch 157 | Loss: 0.8332
# Epoch 158 | Loss: 0.8348
# Epoch 159 | Loss: 0.8332
# Epoch 160 | Loss: 0.8316
# Epoch 161 | Loss: 0.8301
# Epoch 162 | Loss: 0.8305
# Epoch 163 | Loss: 0.8286
# Epoch 164 | Loss: 0.8277
# Epoch 165 | Loss: 0.8273
# Epoch 166 | Loss: 0.8272
# Epoch 167 | Loss: 0.8249
# Epoch 168 | Loss: 0.8247
# Epoch 169 | Loss: 0.8235
# Epoch 170 | Loss: 0.8229
# Epoch 171 | Loss: 0.8222
# Epoch 172 | Loss: 0.8214
# Epoch 173 | Loss: 0.8199
# Epoch 174 | Loss: 0.8191
# Epoch 175 | Loss: 0.8194
# Epoch 176 | Loss: 0.8182
# Epoch 177 | Loss: 0.8181
# Epoch 178 | Loss: 0.8163
# Epoch 179 | Loss: 0.8168
# Epoch 180 | Loss: 0.8143
# Epoch 181 | Loss: 0.8139
# Epoch 182 | Loss: 0.8134
# Epoch 183 | Loss: 0.8115
# Epoch 184 | Loss: 0.8128
# Epoch 185 | Loss: 0.8096
# Epoch 186 | Loss: 0.8107
# Epoch 187 | Loss: 0.8100
# Epoch 188 | Loss: 0.8089
# Epoch 189 | Loss: 0.8089
# Epoch 190 | Loss: 0.8080
# Epoch 191 | Loss: 0.8075
# Epoch 192 | Loss: 0.8059
# Epoch 193 | Loss: 0.8058
# Epoch 194 | Loss: 0.8054
# Epoch 195 | Loss: 0.8071
# Epoch 196 | Loss: 0.8035
# Epoch 197 | Loss: 0.8042
# Epoch 198 | Loss: 0.8031
# Epoch 199 | Loss: 0.8016
# Epoch 200 | Loss: 0.8016
# Epoch 201 | Loss: 0.8022

# %%
import torch.nn.functional as F

def translate_beam(model, src_seq, eng_to_ind, jpn_to_ind, ind_to_jpn, max_len=40, beam_width=3):
    model.eval()

    bos_id = jpn_to_ind["<bos>"]
    eos_id = jpn_to_ind["<eos>"]

    # Convert English words to indices
    src_indices = [eng_to_ind.get(tok, 1) for tok in src_seq]
    src_tensor = torch.tensor([src_indices], dtype=torch.long).to(device)
    with torch.no_grad():
        enc_embed = model.enc_embed(src_tensor)  # (1, T, D)
        _, (h, c) = model.encoder(enc_embed)

        # Combine forward & backward states for bidirectional encoder
        num_layers = model.encoder.num_layers
        batch_size = src_tensor.size(0)
        hidden_size = model.encoder.hidden_size

        # h and c are (num_layers*2, batch, hidden_size)
        h = h.view(num_layers, 2, batch_size, hidden_size).sum(dim=1)
        c = c.view(num_layers, 2, batch_size, hidden_size).sum(dim=1)

        # Each beam: (score, sequence, h, c)
        beam = [(0.0, [bos_id], h, c)]
        completed_sequences = []

        for _ in range(max_len):
            new_beam = []

            for score, seq, h_prev, c_prev in beam:
                inputs = torch.tensor([[seq[-1]]], dtype=torch.long).to(device)  # (1, 1)
                dec_embed = model.dec_embed(inputs)  # (1, 1, D)
                out, (h_new, c_new) = model.decoder(dec_embed, (h_prev, c_prev))  # out: (1, 1, H)
                logits = model.out(out[:, -1, :])  # (1, vocab_size)
                log_probs = F.log_softmax(logits, dim=-1)  # (1, vocab_size)

                topk_log_probs, topk_indices = torch.topk(log_probs, beam_width, dim=-1)  # (1, k)

                for i in range(beam_width):
                    word_id = topk_indices[0, i].item()
                    word_score = topk_log_probs[0, i].item()
                    new_seq = seq + [word_id]
                    new_score = score + word_score

                    if word_id == eos_id:
                        completed_sequences.append((new_score, new_seq))
                    else:
                        new_beam.append((new_score, new_seq, h_new, c_new))

            if not new_beam:
                break

            # Keep top-k
            beam = sorted(new_beam, key=lambda x: x[0], reverse=True)[:beam_width]
        
        if not completed_sequences:
            completed_sequences = [(score, seq) for score, seq, _, _ in beam]

        completed_sequences.sort(key=lambda x: x[0], reverse=True)
        best_seq = completed_sequences[0][1]

    # Convert to Japanese characters (skip <bos>, <eos>)
    return [ind_to_jpn.get(idx, '<unk>') for idx in best_seq[1:-1]]

# %%
eng_sentence = "The dog wants to come in"
tokens = eng_sentence.strip().lower().split()
output_chars = translate_beam(model, tokens, eng_to_ind, jpn_to_ind, ind_to_jpn, beam_width=5)
print("".join(output_chars))
# Out:
# 犬が来たいの。

# %% [markdown]
# In google translate, "犬が来たいの。" translates to "The dog wants to come."
