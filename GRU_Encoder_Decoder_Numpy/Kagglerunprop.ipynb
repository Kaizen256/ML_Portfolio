# %% [markdown]
# # GRU-based Encoder–Decoder for Machine Translation (NumPy)

# %% [markdown]
# In this project, I created a machine translation model using an encoder–decoder architecture built entirely from scratch in NumPy, without using any deep learning frameworks. The model translates from English to Japanese using a GRU (Gated Recurrent Unit).
# - Dataset: English Japanese sentence pairs selected from the Tatoeba Project
# - Architecture: Encoder–Decoder with GRU
# - Objective: Generate Japanese translations using only NumPy operations

# %% [markdown]
# ## Architecture Overview
# - **Embedding**: English and Japanese character tokens are first mapped to integer indices. Each index is embedded into a dense vector using separate embedding matrices.
# - **Encoder**: A GRU processes the full embedded English input sequence, the final hidden state is returned and represents the context of the entire input sentence.
# - **Decoder**: The decoder is another GRU that predicts the Japanese output one character at a time. It takes the embedded previous character and the hidden state from the previous step. The initial hidden state is the encoder's final hidden state.
# - **Output**: Immediately after running the decoder GRU on a time step, apply an FC layer to the hidden state at that time step to get output logits. Store those logits and at the end apply softmax.

# %% [markdown]
# ![Encoder Decoder Architecture](figures/ED_arch.png)
#
# Image source: Zhang, Aston and Lipton, Zachary C. and Li, Mu and Smola, Alexander J. - https://github.com/d2l-ai/d2l-en

# %% [markdown]
# ## 1. Loading and Filtering Sentence Pairs
#
# Read English Japanese sentence pairs from the `jpn.txt` file. Because training a model from scratch using only NumPy means we can't use a gpu, we need to make the dataset smaller. We only use sentences with 3 or less words. lowercase the English text, and clean both languages using regular expressions.
#
# For English, we remove all non-alphanumeric characters. For Japanese, we preserve Hiragana, Katakana, Kanji, and a few key punctuation symbols (like 。 and 、). Duplicate English sentences are also removed to avoid redundancy.

# %%
import numpy as np
import re

# Lists for cleaned sentences
eng_sentences = []
jpn_sentences = []

# To avoid duplicates
seen = set()

with open('/kaggle/input/japanese-english/jpn.txt', "r", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split("\t")

        # Extract English and Japanese parts
        eng = parts[0].strip().lower()
        jpn = parts[1].strip().lower()

        # Clean English: keep lowercase letters, numbers, and spaces
        eng = re.sub(r"[^a-z0-9\s]", "", eng)

        # Clean Japanese: keep the punctuation
        jpn = re.sub(r"[^\u3040-\u30ff\u4e00-\u9fff。、！？\s]", "", jpn)
        # Filtering out sentences, max 3 words
        if len(eng.split()) <= 3 and len(jpn.split()) <= 3 and eng not in seen:
            eng_sentences.append(eng)
            jpn_sentences.append(jpn)
            seen.add(eng)

print(f"English Sentences: {eng_sentences[0:10]}")
print(f"English Sentences Length: {len(eng_sentences)}")
print(f"Japanese Sentences: {jpn_sentences[0:10]}")
print(f"Japanese Sentences Length: {len(jpn_sentences)}")
# Out:
# English Sentences: ['go', 'hi', 'run', 'who', 'wow', 'duck', 'fire', 'help', 'hide', 'jump']
# English Sentences Length: 6627
# Japanese Sentences: ['行け。', 'こんにちは。', '走れ。', '誰？', 'すごい！', '頭を下げろ！', '火事だ！', '助けて！', '隠れろ。', '飛び越えろ！']
# Japanese Sentences Length: 6627

# %% [markdown]
# ## Vocabulary Construction
#
# We now build vocabularies for both English and Japanese.
#
# - English is tokenized at word level. We assign indices to all words that appear more than twice.
# - Japanese is tokenized at the character level, since words are not separated by spaces. Characters appearing more than twice are included in the vocabulary.
#
# We also add special tokens:
#
# | Token | Meaning         |
# |-------|------------------|
# | `<pad>` | Padding token     |
# | `<unk>` | Unknown token     |
# | `<bos>` | Beginning of sequence |
# | `<eos>` | End of sequence     |

# %%
from collections import Counter

counter = Counter()

# Count word frequency
for sent in eng_sentences:
    counter.update(sent.split())

# English to index mapping
eng_to_ind = {'<pad>': 0, '<unk>':1}
ind = 2

# Include words that appear 3+ times.
for word in counter:
    if counter[word] > 2:
        eng_to_ind[word] = ind
        ind += 1
        
print("English Vocabulary Size:", len(eng_to_ind))

jcounter = Counter()

# Count character frequency across Japanese sentences
for sent in jpn_sentences:
    jcounter.update(list(sent))

# Japanese to index and index to Japanese mapping
jpn_to_ind = {'<pad>': 0, '<unk>': 1, '<bos>': 2, '<eos>': 3}
ind_to_jpn = {0: '<pad>', 1: '<unk>', 2: '<bos>', 3: '<eos>'}
ind = 4

# Include characters that appear 3+ times
for char, freq in jcounter.most_common():
    if freq > 2:
        jpn_to_ind[char] = ind
        ind_to_jpn[ind] = char
        ind += 1

print("Japanese Vocabulary Size:", len(jpn_to_ind))
# Out:
# English Vocabulary Size: 971
# Japanese Vocabulary Size: 847

# %% [markdown]
# ## Encoding Sentences
#
# Now convert each sentence into a sequence of integer indices.
#
# - English Encoding:
#   - Tokenized at the word level.
#   - Each sentence is padded to 3 tokens using the `<pad>` (index 0).
#   - Unknown words are mapped to `<unk>` (index 1).
#
# - Japanese Encoding:
#   - Tokenized at the character level.
#   - Each sentence starts with `<bos>` (index 2) and ends with `<eos>` (index 3).
#   - Limit to 12 tokens total to include both `<bos>` and `<eos>`.
#   - Padding (`<pad>`) is added at the end if needed.

# %%
eng_encoded = []

# Encode each English sentence at word level
# Maximum of 3 words per sentence
for sentence in eng_sentences:
    s = []
    for word in sentence.split():
        if word in eng_to_ind:
            s.append(eng_to_ind[word])
        else:
            s.append(1)
    while(len(s) < 3):
        s.append(0) # Padding
    eng_encoded.append(s)

jpn_encoded = []

# Encode each Japanese sentence character level
# Maximum of twelve characters per sentence including <bos> and <eos>
for sentence in jpn_sentences:
    s = [2] # 2 is <bos>
    for ch in sentence:
        if len(s) > 10:
            break # We need room to fit <eos> token.
        if ch in jpn_to_ind:
            s.append(jpn_to_ind[ch])
        else:
            s.append(1)   # 1 is <unk>
    s.append(3)           # 3 is <eos>
    while(len(s) < 12):
        s.append(0)       # 0 is <pad>
    jpn_encoded.append(s)

print(f"English Sentences Encoded: {eng_encoded[0:10]}")
print(f"English Sentences Encoded Length: {len(eng_encoded)}")
print(f"Japanese Sentences Encoded: {jpn_encoded[0:5]}")
print(f"Japanese Sentences Encoded Length: {len(jpn_encoded)}")
# Out:
# English Sentences Encoded: [[2, 0, 0], [3, 0, 0], [4, 0, 0], [5, 0, 0], [6, 0, 0], [1, 0, 0], [7, 0, 0], [8, 0, 0], [9, 0, 0], [10, 0, 0]]
# English Sentences Encoded Length: 6627
# Japanese Sentences Encoded: [[2, 71, 47, 4, 3, 0, 0, 0, 0, 0, 0, 0], [2, 29, 23, 27, 42, 6, 4, 3, 0, 0, 0, 0], [2, 213, 28, 4, 3, 0, 0, 0, 0, 0, 0, 0], [2, 65, 26, 3, 0, 0, 0, 0, 0, 0, 0, 0], [2, 12, 79, 5, 53, 3, 0, 0, 0, 0, 0, 0]]
# Japanese Sentences Encoded Length: 6627

# %% [markdown]
# ## Creating Embedding Matrices
#
# - Vocabulary Size: Approximately 900 for each language.
# - Embedding Dimension: I estimated using int(min(600, 1.6 * vocab_size ** 0.56)) = 72
#   I wanted to use a power of 2, so I rounded down to 64.
#
# Each word or character will be embedded into a 64 dimensional dense vector.

# %%
embedding_size = 64
V_eng = len(eng_to_ind)  # English vocab size
V_jpn = len(jpn_to_ind)  # Japanese vocab size

eng_embedding = np.random.randn(V_eng, embedding_size) * 0.1
jpn_embedding = np.random.randn(V_jpn, embedding_size) * 0.1

print(f"English embedding shape: {eng_embedding.shape}")
print(f"Japanese embedding shape: {jpn_embedding.shape}")

# Example
eng_sentence = [5, 23, 8]
embedded_sentence = eng_embedding[eng_sentence]  # Shape (3, 64)
print(f"English input shape: {embedded_sentence.shape}")  # (seq_len, embedding_dim)
# Out:
# English embedding shape: (971, 64)
# Japanese embedding shape: (847, 64)
# English input shape: (3, 64)

# %% [markdown]
# ## Activation and Loss Functions
#
# - Sigmoid: Used in GRU gates.
# - Tanh: Used for the candidate hidden state.
# - Softmax: Converts decoder logits into probabilities.
# - Cross Entropy Loss: Measures prediction error between predicted softmax outputs and true labels.
#
# Documentation generated by ChatGPT

# %%
def sigmoid(x):
    """
    Element-wise Sigmoid activation function.
    Used in GRU for update/reset gates.
    
    Clips input to avoid overflow in exp.
    """
    x = np.clip(x, -50, 50)  # Prevent overflow
    return 1 / (1 + np.exp(-x))

def sigmoid_deriv(x):
    """
    Derivative of the Sigmoid function.
    Used during GRU backpropagation.
    """
    s = sigmoid(x)
    return s * (1 - s)

def tanh(x):
    """
    Element-wise hyperbolic tangent activation.
    Used in GRU for candidate hidden state.
    """
    return np.tanh(x)

def tanh_deriv(x):
    """
    Derivative of tanh function.
    Used in GRU backpropagation.
    """
    return 1.0 - np.tanh(x) ** 2

def softmax(Z: np.ndarray) -> np.ndarray:
    """
    Apply softmax over last dimension (class logits).
    
    Parameters:
    - Z: np.ndarray of shape (batch_size, num_classes)
      Raw logits for classification.
    
    Returns:
    - np.ndarray of same shape: softmax probabilities.
    """
    Z = Z - np.max(Z, axis=1, keepdims=True)
    exp_Z = np.exp(Z)
    return exp_Z / np.sum(exp_Z, axis=1, keepdims=True)

def CrossEntropy(yhat: np.ndarray, y: np.ndarray, eps: float = 1e-15) -> float:
    """
    Compute mean cross-entropy loss.

    Parameters:
    - yhat: np.ndarray of shape (batch_size, num_classes)
        Predicted probabilities (after softmax)
    - y: np.ndarray of shape (batch_size,)
        True class indices
    - eps: float
        Small constant to avoid log(0)

    Returns:
    - float: mean loss across the batch
    """
    yhat = np.clip(yhat, eps, 1 - eps)  # Prevent log(0)
    correct_probs = yhat[np.arange(len(y)), y]
    return -np.mean(np.log(correct_probs))

# %% [markdown]
# ## GRU Architecture and Implementation
#
# The Gated Recurrent Unit (GRU) is an RNN cell designed to assist with the vanishing/exploding gradient problem and capture long range dependencies more efficiently than a vanilla RNN. Below is a overview of the implementation.
#
# - Reset Gate (R): Determines how much of the past hidden state to forget.
# - Update Gate (Z): Determines how much of the new candidate state to use versus retaining the past hidden state.

# %% [markdown]
# ## GRU Architecture and Implementation
#
# The Gated Recurrent Unit (GRU) is an RNN cell designed to assist with the vanishing/exploding gradient problem and capture long range dependencies more efficiently than a vanilla RNN. Below is a overview of the implementation.
#
# - Reset Gate (R): Determines how much of the past hidden state to forget.
# - Update Gate (Z): Determines how much of the new candidate state to use versus retaining the past hidden state.
# Rₜ = σ(xₜ @ W_r.T + hₜ₋₁ @ U_r + b_r)
# ### Forward Pass (per time step \(t\))
# 1. Compute gates
#     - Rₜ = σ(xₜ @ W_r.T + hₜ₋₁ @ U_r + b_r)
#     - Zₜ = σ(xₜ @ W_z.T + hₜ₋₁ @ U_z + b_z)
# 2. Candidate state
#     - Cₜ = tanh(xₜ @ W_c.T + (Rₜ ⊙ hₜ₋₁) @ U_c + b_c)
# 3. Hidden state update
#     - xₜ = zₜ ⊙ hₜ₋₁ + (1 - Zₜ) ⊙ Cₜ
#
# Store (xₜ, hₜ₋₁, Rₜ, Zₜ, Cₜ, hₜ) at each step to use during backpropagation.
#
# ![GRU Architecture](figures/GRU_arch.png)
#
# ### Gradient Calculations
#
# Calculating the gradients is a tedious process, below are my calculations to get this model to work. There were a lot of problems.
#
# ![Backpropagation](figures/Backprop.png)
#
# ### Integration into Encoder–Decoder
# - Encoder GRU: Processes the input sequence and returns the final hidden state \(h_{enc}\).
# - Decoder GRU: Initialized with \(h_{enc}\), generates the target sequence by feeding its own previous output back as input.

# %%
class GRU:
    def __init__(self, input_size, hidden_size):
        self.input_size = input_size
        self.hidden_size = hidden_size

        # Xavier Normal std
        std = np.sqrt(2 / (input_size + hidden_size))

        # Reset gate (R)
        self.r_w = np.random.normal(0, std, size=(hidden_size, input_size))
        self.r_u = np.random.normal(0, std, size=(hidden_size, hidden_size))
        self.r_b = np.zeros(hidden_size)

        # Update gate (Z)
        self.z_w = np.random.normal(0, std, size=(hidden_size, input_size))
        self.z_u = np.random.normal(0, std, size=(hidden_size, hidden_size))
        self.z_b = np.zeros(hidden_size)

        # Candidate hidden state (C)
        self.c_w = np.random.normal(0, std, size=(hidden_size, input_size))
        self.c_u = np.random.normal(0, std, size=(hidden_size, hidden_size))
        self.c_b = np.zeros(hidden_size)
    
    def forward(self, X, H=None):
        batch_size, seq_len, embed_dim = X.shape # (N, T, D)
        if H is None:
            H = np.zeros(shape=(batch_size, self.hidden_size)) # (N, H)

        hidden_states = []
        store = [] # For backpropagation

        for i in range(seq_len):
            x_t = X[:, i, :]  # (N, D)
            R = sigmoid(x_t @ self.r_w.T + H @ self.r_u + self.r_b)  # (N, H)
            Z = sigmoid(x_t @ self.z_w.T + H @ self.z_u + self.z_b)  # (N, H)
            C = tanh(x_t @ self.c_w.T + (R * H) @ self.c_u + self.c_b)  # (N, H)

            H_new = Z * H + (1 - Z) * C  # (N, H)

            store.append((x_t, H, R, Z, C, H_new))
            H = H_new
            hidden_states.append(H[:, np.newaxis, :])
            

        return H, np.concatenate(hidden_states, axis=1), store

    def backward(self, dH_all, store, lr):

        batch, seq_len, _ = dH_all.shape

        # Initialize accumulators for parameter gradients to zeros
        dr_w = np.zeros_like(self.r_w)  # ∂L/∂R_w, shape (H, D)
        dr_u = np.zeros_like(self.r_u)  # ∂L/∂R_u, shape (H, H)
        dr_b = np.zeros_like(self.r_b)  # ∂L/∂R_b,  shape (H,)

        dz_w = np.zeros_like(self.z_w)  # ∂L/∂Z_w
        dz_u = np.zeros_like(self.z_u)  # ∂L/∂Z_u
        dz_b = np.zeros_like(self.z_b)  # ∂L/∂Z_b

        dc_w = np.zeros_like(self.c_w)  # ∂L/∂C_w
        dc_u = np.zeros_like(self.c_u)  # ∂L/∂C_u
        dc_b = np.zeros_like(self.c_b)  # ∂L/∂C_b

        # dh accumulates the gradient flowing from future time steps
        dH = np.zeros((batch, self.hidden_size)) # (N, H)
        
        # Will hold gradient w.r.t. the input embeddings at each time step
        dx = np.zeros((batch, seq_len, self.input_size))  # (N, T, D)

        # Loop backwards through time: t = seq_len-1 ... 0
        for t in reversed(range(seq_len)):
            # Unpack stored values from forward pass
            # x_t:   (N, D) input at time t
            # h_prev:(N, H) previous hidden state
            # r_t:   (N, H) reset gate
            # z_t:   (N, H) update gate
            # c_t:   (N, H) candidate hidden state
            # h_t:   (N, H) final hidden state at time t
            x_t, h_prev, r_t, z_t, c_t, h_t = store[t]

            # dh: (N, H) total gradient wrt current hidden state h_t
            # Includes gradient from output loss and from next time step dH
            dh = dH_all[:, t, :] + dH
            
            # Gradients through update gate z_t and candidate c_t
            # ∂L/∂z_t = dh ⊙ (h_prev - c_t)
            dz = dh * (h_prev - c_t) # (N, H)
            # ∂L/∂c_t = dh ⊙ (1 - z_t)
            dc = dh * (1 - z_t)      # (N, H)
            # ∂L/∂h_prev = dh ⊙ z_t, one part of ∂L/∂h_{t-1}
            dh_prev = dh * z_t       # (N, H)

            # Backprop through tanh: ∂L/∂c_t_preact = dc ⊙ (1 - c_t²)
            dc_preact = dc * (1 - c_t**2)   # (N, H)
            
            # Accumulate parameter gradients for candidate weights
            # ∂L/∂C_w = dc_preact.T @ x_t
            dc_w += dc_preact.T @ x_t              # (H, D)
            # ∂L/∂C_u = (r_t ⊙ h_prev).T @ dc_preact
            dc_u += (r_t * h_prev).T @ dc_preact   # (H, H)
            # ∂L/∂C_b = sum over batch of dc_preact
            dc_b += np.sum(dc_preact, axis=0)      # (H,)

            # Reset gate gradient from C preact's hidden side
            # ∂L/∂r_t = ∂L/(∂C preact) ⊙ ∂(C preact)/∂r_t
            # ∂L/∂r_t = (dc_preact @ C_u.T) ⊙ h_prev
            dr = (dc_preact @ self.c_u.T) * h_prev   # (N, H)
            # Backprop through sigmoid: ∂L/∂r_preact = dr ⊙ r_t ⊙ (1 - r_t)
            dr_preact = dr * (r_t * (1 - r_t))       # (N, H)
            # Accumulate Reset gate gradients
            dr_w += dr_preact.T @ x_t                # (H, D)
            dr_u += h_prev.T @ dr_preact             # (H, H)
            dr_b += np.sum(dr_preact, axis=0)        # (H,)

            # Backprop through update gate sigmoid
            dz_preact = dz * z_t * (1 - z_t)         # (N, H)

            # Accumulate update gate gradients
            dz_w += dz_preact.T @ x_t                # (H, D)
            dz_u += h_prev.T @ dz_preact             # (H, H)
            dz_b += np.sum(dz_preact, axis=0)        # (H,)

            # Add to total gradient wrt h_prev
            # dh_prev = sum of all partials wrt h_prev from C, R, Z
            dh_prev += (dc_preact @ self.c_u.T) * r_t        # (N, H)
            dh_prev += dr_preact @ self.r_u.T                # (N, H)
            dh_prev += dz_preact @ self.z_u.T                # (N, H)
            

            # Set dH for next iteration (t-1)
            dH = dh_prev  # (N, H)

            # Gradient wrt. input x_t combines contributions from each gate
            # Paths: dr_preact, dz_preact, dc_preact
            dx[:, t, :] = (
                dr_preact @ self.r_w +  # via reset gate input weights
                dz_preact @ self.z_w +  # via update gate input weights
                dc_preact @ self.c_w    # via candidate input weights
            )  # shape (N, D)


        grads = [dc_w, dc_u, dc_b, dr_w, dr_u, dr_b, dz_w, dz_u, dz_b]

        for i in range(len(grads)):
            np.clip(grads[i], -1.0, 1.0, out=grads[i])  # Gradient Clipping

        self.c_w -= lr * dc_w
        self.c_u -= lr * dc_u
        self.c_b -= lr * dc_b

        self.r_w -= lr * dr_w
        self.r_u -= lr * dr_u
        self.r_b -= lr * dr_b

        self.z_w -= lr * dz_w
        self.z_u -= lr * dz_u
        self.z_b -= lr * dz_b

        return dH, dx

# %% [markdown]
# Saving parameters function

# %%
def save_parameters(path, Encoder_GRU, Decoder_GRU, eng_embedding, jpn_embedding, o_w, o_b):

    np.savez(
        path,
        eng_embedding=eng_embedding,
        jpn_embedding=jpn_embedding,
        o_w=o_w, o_b=o_b,
        enc_r_w=Encoder_GRU.r_w, enc_r_u=Encoder_GRU.r_u, enc_r_b=Encoder_GRU.r_b,
        enc_z_w=Encoder_GRU.z_w, enc_z_u=Encoder_GRU.z_u, enc_z_b=Encoder_GRU.z_b,
        enc_c_w=Encoder_GRU.c_w, enc_c_u=Encoder_GRU.c_u, enc_c_b=Encoder_GRU.c_b,
        dec_r_w=Decoder_GRU.r_w, dec_r_u=Decoder_GRU.r_u, dec_r_b=Decoder_GRU.r_b,
        dec_z_w=Decoder_GRU.z_w, dec_z_u=Decoder_GRU.z_u, dec_z_b=Decoder_GRU.z_b,
        dec_c_w=Decoder_GRU.c_w, dec_c_u=Decoder_GRU.c_u, dec_c_b=Decoder_GRU.c_b
    )
    print("Saved Parameters")

# %%
batch_size = 8
epochs = 3000
lr = 0.008
encoder_len = 3        # English length
target_len = 12        # Japanese length
hidden_size = 128

bos_id, pad_id, eos_id = 2, 0, 3

Encoder_GRU = GRU(64, hidden_size)
Decoder_GRU = GRU(64, hidden_size)

X = np.array(eng_encoded, dtype=int)
y = np.array(jpn_encoded, dtype=int)

V_jpn = jpn_embedding.shape[0]
o_w = np.random.randn(V_jpn, hidden_size) * 0.01
o_b = np.zeros(V_jpn)

past_loss = []

for epoch in range(epochs):
    total_loss = 0

    perm = np.random.permutation(X.shape[0])
    X_train = X[perm]
    y_train = y[perm]

    for batch in range(0, X.shape[0], batch_size):
        end = min(batch + batch_size, X_train.shape[0])
        X_ids = X_train[batch:end]
        y_train_batch = y_train[batch:end]
        batch_len = X_ids.shape[0]
        
        # Encoder forward
        X_emb = eng_embedding[X_ids]
        h_enc, enc_h_all, enc_store = Encoder_GRU.forward(X_emb)

        decoder_input = np.concatenate(
            [np.full((batch_len, 1), bos_id, dtype=int), y_train_batch[:, :-1]],
            axis=1
        )
        decoder_target = y_train_batch

        dec_in_emb = jpn_embedding[decoder_input]        # (N, T, D)
        _, h_dec_all, dec_store = Decoder_GRU.forward(dec_in_emb, h_enc)

        logits_flat = (h_dec_all @ o_w.T + o_b).reshape(-1, V_jpn) # (bs*seq_len, V_jpn)
        targets_flat = decoder_target.reshape(-1)

        mask = (targets_flat != pad_id)
        probs = softmax(logits_flat)
        probs = np.clip(probs, 1e-12, 1 - 1e-12)
        
        loss = -np.sum(np.log(probs[np.where(mask)[0], targets_flat[mask]])) / mask.sum()
        total_loss += loss * batch_len

        # Backprop through softmax + cross entropy
        dlogits = probs
        dlogits[np.where(mask)[0], targets_flat[mask]] -= 1
        dlogits /= mask.sum()  # average over non pad tokens

        # Final linear layer grad
        h_dec_all_flat = h_dec_all.reshape(-1, hidden_size)
        do_w = dlogits.T @ h_dec_all_flat    # (V_jpn, H)
        do_b = np.sum(dlogits, axis=0)       # (V_jpn,)
        dh_dec = dlogits @ o_w
        dh_dec = dh_dec.reshape(batch_len, target_len, hidden_size)

        # Decoder GRU backward
        dH_enc_from_dec, dx_dec = Decoder_GRU.backward(dh_dec, dec_store, lr)

        # Update decoder embeddings and clip gradients
        for b in range(batch_len):
            for t in range(target_len):
                idx_tok = decoder_input[b, t]
                grad = np.clip(dx_dec[b, t], -1.0, 1.0)
                jpn_embedding[idx_tok] -= lr * grad

        # Encoder GRU backward
        # Build gradient tensor with only last time-step having gradient
        dH_enc_all = np.zeros_like(enc_h_all)           # (B, encoder_len, H)
        dH_enc_all[:, -1, :] = dH_enc_from_dec          # gradient only on final encoder state
        _, dx_enc = Encoder_GRU.backward(dH_enc_all, enc_store, lr)

        # Update encoder embeddings and clip gradients
        for b in range(batch_len):
            for t in range(encoder_len):
                tok = X_ids[b, t]
                grad = np.clip(dx_enc[b, t], -1.0, 1.0)
                eng_embedding[tok] -= lr * grad

        # Clip output gradients
        np.clip(do_w, -1.0, 1.0, out=do_w)
        np.clip(do_b, -1.0, 1.0, out=do_b)

        # Update output layer
        o_w -= lr * do_w
        o_b -= lr * do_b

    tl = total_loss / X_train.shape[0]
    print(f"Epoch {epoch+1} | Loss: {tl:.4f}")

    past_loss.append(tl)

    if len(past_loss) > 2:
        if past_loss[-1] > past_loss[-2] and past_loss[-2] > past_loss[-3] and past_loss[-3] > past_loss[-4] and past_loss[-4] > past_loss[-5]:
            break

save_parameters("model_params3.npz", Encoder_GRU, Decoder_GRU, eng_embedding, jpn_embedding, o_w, o_b)
# Out:
# Epoch 1 | Loss: 6.6236
# Epoch 2 | Loss: 6.0039
# Epoch 3 | Loss: 4.7982
# Epoch 4 | Loss: 4.3895
# Epoch 5 | Loss: 4.1994
# Epoch 6 | Loss: 4.0809
# Epoch 7 | Loss: 3.9969
# Epoch 8 | Loss: 3.9323
# Epoch 9 | Loss: 3.8843
# Epoch 10 | Loss: 3.8459
# Epoch 11 | Loss: 3.8140
# Epoch 12 | Loss: 3.7884
# Epoch 13 | Loss: 3.7655
# Epoch 14 | Loss: 3.7436
# Epoch 15 | Loss: 3.7236
# Epoch 16 | Loss: 3.7042
# Epoch 17 | Loss: 3.6830
# Epoch 18 | Loss: 3.6615
# Epoch 19 | Loss: 3.6393
# Epoch 20 | Loss: 3.6176
# Epoch 21 | Loss: 3.5949
# Epoch 22 | Loss: 3.5727
# Epoch 23 | Loss: 3.5515
# Epoch 24 | Loss: 3.5317
# Epoch 25 | Loss: 3.5126
# Epoch 26 | Loss: 3.4945
# Epoch 27 | Loss: 3.4772
# Epoch 28 | Loss: 3.4611
# Epoch 29 | Loss: 3.4461
# Epoch 30 | Loss: 3.4297
# Epoch 31 | Loss: 3.4143
# Epoch 32 | Loss: 3.3996
# Epoch 33 | Loss: 3.3868
# Epoch 34 | Loss: 3.3737
# Epoch 35 | Loss: 3.3615
# Epoch 36 | Loss: 3.3493
# Epoch 37 | Loss: 3.3386
# Epoch 38 | Loss: 3.3274
# Epoch 39 | Loss: 3.3168
# Epoch 40 | Loss: 3.3071
# Epoch 41 | Loss: 3.2976
# Epoch 42 | Loss: 3.2887
# Epoch 43 | Loss: 3.2800
# Epoch 44 | Loss: 3.2706
# Epoch 45 | Loss: 3.2622
# Epoch 46 | Loss: 3.2541
# Epoch 47 | Loss: 3.2460
# Epoch 48 | Loss: 3.2371
# Epoch 49 | Loss: 3.2289
# Epoch 50 | Loss: 3.2206
# Epoch 51 | Loss: 3.2136
# Epoch 52 | Loss: 3.2062
# Epoch 53 | Loss: 3.1991
# Epoch 54 | Loss: 3.1905
# Epoch 55 | Loss: 3.1834
# Epoch 56 | Loss: 3.1757
# Epoch 57 | Loss: 3.1682
# Epoch 58 | Loss: 3.1599
# Epoch 59 | Loss: 3.1548
# Epoch 60 | Loss: 3.1466
# Epoch 61 | Loss: 3.1381
# Epoch 62 | Loss: 3.1321
# Epoch 63 | Loss: 3.1252
# Epoch 64 | Loss: 3.1185
# Epoch 65 | Loss: 3.1113
# Epoch 66 | Loss: 3.1033
# Epoch 67 | Loss: 3.0977
# Epoch 68 | Loss: 3.0889
# Epoch 69 | Loss: 3.0824
# Epoch 70 | Loss: 3.0755
# Epoch 71 | Loss: 3.0666
# Epoch 72 | Loss: 3.0616
# Epoch 73 | Loss: 3.0543
# Epoch 74 | Loss: 3.0467
# Epoch 75 | Loss: 3.0386
# Epoch 76 | Loss: 3.0324
# Epoch 77 | Loss: 3.0238
# Epoch 78 | Loss: 3.0159
# Epoch 79 | Loss: 3.0079
# Epoch 80 | Loss: 3.0002
# Epoch 81 | Loss: 2.9923
# Epoch 82 | Loss: 2.9847
# Epoch 83 | Loss: 2.9768
# Epoch 84 | Loss: 2.9700
# Epoch 85 | Loss: 2.9629
# Epoch 86 | Loss: 2.9553
# Epoch 87 | Loss: 2.9494
# Epoch 88 | Loss: 2.9421
# Epoch 89 | Loss: 2.9361
# Epoch 90 | Loss: 2.9306
# Epoch 91 | Loss: 2.9232
# Epoch 92 | Loss: 2.9186
# Epoch 93 | Loss: 2.9123
# Epoch 94 | Loss: 2.9055
# Epoch 95 | Loss: 2.9003
# Epoch 96 | Loss: 2.8950
# Epoch 97 | Loss: 2.8876
# Epoch 98 | Loss: 2.8833
# Epoch 99 | Loss: 2.8774
# Epoch 100 | Loss: 2.8711
# Epoch 101 | Loss: 2.8654
# Epoch 102 | Loss: 2.8603
# Epoch 103 | Loss: 2.8547
# Epoch 104 | Loss: 2.8499
# Epoch 105 | Loss: 2.8426
# Epoch 106 | Loss: 2.8390
# Epoch 107 | Loss: 2.8339
# Epoch 108 | Loss: 2.8284
# Epoch 109 | Loss: 2.8220
# Epoch 110 | Loss: 2.8169
# Epoch 111 | Loss: 2.8122
# Epoch 112 | Loss: 2.8072
# Epoch 113 | Loss: 2.8015
# Epoch 114 | Loss: 2.7955
# Epoch 115 | Loss: 2.7912
# Epoch 116 | Loss: 2.7861
# Epoch 117 | Loss: 2.7808
# Epoch 118 | Loss: 2.7776
# Epoch 119 | Loss: 2.7712
# Epoch 120 | Loss: 2.7676
# Epoch 121 | Loss: 2.7623
# Epoch 122 | Loss: 2.7589
# Epoch 123 | Loss: 2.7535
# Epoch 124 | Loss: 2.7492
# Epoch 125 | Loss: 2.7434
# Epoch 126 | Loss: 2.7399
# Epoch 127 | Loss: 2.7355
# Epoch 128 | Loss: 2.7320
# Epoch 129 | Loss: 2.7278
# Epoch 130 | Loss: 2.7227
# Epoch 131 | Loss: 2.7178
# Epoch 132 | Loss: 2.7146
# Epoch 133 | Loss: 2.7092
# Epoch 134 | Loss: 2.7058
# Epoch 135 | Loss: 2.7017
# Epoch 136 | Loss: 2.6974
# Epoch 137 | Loss: 2.6925
# Epoch 138 | Loss: 2.6910
# Epoch 139 | Loss: 2.6860
# Epoch 140 | Loss: 2.6811
# Epoch 141 | Loss: 2.6782
# Epoch 142 | Loss: 2.6754
# Epoch 143 | Loss: 2.6698
# Epoch 144 | Loss: 2.6662
# Epoch 145 | Loss: 2.6623
# Epoch 146 | Loss: 2.6591
# Epoch 147 | Loss: 2.6549
# Epoch 148 | Loss: 2.6516
# Epoch 149 | Loss: 2.6470
# Epoch 150 | Loss: 2.6444
# Epoch 151 | Loss: 2.6405
# Epoch 152 | Loss: 2.6364
# Epoch 153 | Loss: 2.6337
# Epoch 154 | Loss: 2.6298
# Epoch 155 | Loss: 2.6252
# Epoch 156 | Loss: 2.6218
# Epoch 157 | Loss: 2.6193
# Epoch 158 | Loss: 2.6151
# Epoch 159 | Loss: 2.6120
# Epoch 160 | Loss: 2.6086
# Epoch 161 | Loss: 2.6056
# Epoch 162 | Loss: 2.6014
# Epoch 163 | Loss: 2.5978
# Epoch 164 | Loss: 2.5948
# Epoch 165 | Loss: 2.5903
# Epoch 166 | Loss: 2.5884
# Epoch 167 | Loss: 2.5838
# Epoch 168 | Loss: 2.5803
# Epoch 169 | Loss: 2.5774
# Epoch 170 | Loss: 2.5742
# Epoch 171 | Loss: 2.5711
# Epoch 172 | Loss: 2.5677
# Epoch 173 | Loss: 2.5649
# Epoch 174 | Loss: 2.5616
# Epoch 175 | Loss: 2.5584
# Epoch 176 | Loss: 2.5548
# Epoch 177 | Loss: 2.5514
# Epoch 178 | Loss: 2.5483
# Epoch 179 | Loss: 2.5455
# Epoch 180 | Loss: 2.5418
# Epoch 181 | Loss: 2.5396
# Epoch 182 | Loss: 2.5360
# Epoch 183 | Loss: 2.5331
# Epoch 184 | Loss: 2.5296
# Epoch 185 | Loss: 2.5264
# Epoch 186 | Loss: 2.5234
# Epoch 187 | Loss: 2.5202
# Epoch 188 | Loss: 2.5176
# Epoch 189 | Loss: 2.5155
# Epoch 190 | Loss: 2.5116
# Epoch 191 | Loss: 2.5088
# Epoch 192 | Loss: 2.5068
# Epoch 193 | Loss: 2.5022
# Epoch 194 | Loss: 2.5004
# Epoch 195 | Loss: 2.4964
# Epoch 196 | Loss: 2.4935
# Epoch 197 | Loss: 2.4906
# Epoch 198 | Loss: 2.4873
# Epoch 199 | Loss: 2.4846
# Epoch 200 | Loss: 2.4828
# Epoch 201 | Loss: 2.4791
# Epoch 202 | Loss: 2.4769
# Epoch 203 | Loss: 2.4735
# Epoch 204 | Loss: 2.4721
# Epoch 205 | Loss: 2.4686
# Epoch 206 | Loss: 2.4633
# Epoch 207 | Loss: 2.4622
# Epoch 208 | Loss: 2.4592
# Epoch 209 | Loss: 2.4566
# Epoch 210 | Loss: 2.4537
# Epoch 211 | Loss: 2.4493
# Epoch 212 | Loss: 2.4488
# Epoch 213 | Loss: 2.4462
# Epoch 214 | Loss: 2.4434
# Epoch 215 | Loss: 2.4403
# Epoch 216 | Loss: 2.4378
# Epoch 217 | Loss: 2.4356
# Epoch 218 | Loss: 2.4322
# Epoch 219 | Loss: 2.4295
# Epoch 220 | Loss: 2.4276
# Epoch 221 | Loss: 2.4241
# Epoch 222 | Loss: 2.4216
# Epoch 223 | Loss: 2.4190
# Epoch 224 | Loss: 2.4167
# Epoch 225 | Loss: 2.4146
# Epoch 226 | Loss: 2.4107
# Epoch 227 | Loss: 2.4072
# Epoch 228 | Loss: 2.4043
# Epoch 229 | Loss: 2.4032
# Epoch 230 | Loss: 2.4004
# Epoch 231 | Loss: 2.3971
# Epoch 232 | Loss: 2.3953
# Epoch 233 | Loss: 2.3929
# Epoch 234 | Loss: 2.3900
# Epoch 235 | Loss: 2.3880
# Epoch 236 | Loss: 2.3848
# Epoch 237 | Loss: 2.3831
# Epoch 238 | Loss: 2.3807
# Epoch 239 | Loss: 2.3769
# Epoch 240 | Loss: 2.3746
# Epoch 241 | Loss: 2.3719
# Epoch 242 | Loss: 2.3691
# Epoch 243 | Loss: 2.3665
# Epoch 244 | Loss: 2.3637
# Epoch 245 | Loss: 2.3603
# Epoch 246 | Loss: 2.3598
# Epoch 247 | Loss: 2.3567
# Epoch 248 | Loss: 2.3546
# Epoch 249 | Loss: 2.3515
# Epoch 250 | Loss: 2.3511
# Epoch 251 | Loss: 2.3471
# Epoch 252 | Loss: 2.3450
# Epoch 253 | Loss: 2.3415
# Epoch 254 | Loss: 2.3398
# Epoch 255 | Loss: 2.3369
# Epoch 256 | Loss: 2.3347
# Epoch 257 | Loss: 2.3335
# Epoch 258 | Loss: 2.3295
# Epoch 259 | Loss: 2.3271
# Epoch 260 | Loss: 2.3245
# Epoch 261 | Loss: 2.3230
# Epoch 262 | Loss: 2.3205
# Epoch 263 | Loss: 2.3189
# Epoch 264 | Loss: 2.3149
# Epoch 265 | Loss: 2.3129
# Epoch 266 | Loss: 2.3114
# Epoch 267 | Loss: 2.3086
# Epoch 268 | Loss: 2.3064
# Epoch 269 | Loss: 2.3029
# Epoch 270 | Loss: 2.3011
# Epoch 271 | Loss: 2.2990
# Epoch 272 | Loss: 2.2974
# Epoch 273 | Loss: 2.2939
# Epoch 274 | Loss: 2.2914
# Epoch 275 | Loss: 2.2903
# Epoch 276 | Loss: 2.2870
# Epoch 277 | Loss: 2.2851
# Epoch 278 | Loss: 2.2810
# Epoch 279 | Loss: 2.2812
# Epoch 280 | Loss: 2.2782
# Epoch 281 | Loss: 2.2759
# Epoch 282 | Loss: 2.2736
# Epoch 283 | Loss: 2.2715
# Epoch 284 | Loss: 2.2693
# Epoch 285 | Loss: 2.2675
# Epoch 286 | Loss: 2.2642
# Epoch 287 | Loss: 2.2627
# Epoch 288 | Loss: 2.2592
# Epoch 289 | Loss: 2.2573
# Epoch 290 | Loss: 2.2552
# Epoch 291 | Loss: 2.2530
# Epoch 292 | Loss: 2.2507
# Epoch 293 | Loss: 2.2487
# Epoch 294 | Loss: 2.2470
# Epoch 295 | Loss: 2.2450
# Epoch 296 | Loss: 2.2415
# Epoch 297 | Loss: 2.2392
# Epoch 298 | Loss: 2.2389
# Epoch 299 | Loss: 2.2344
# Epoch 300 | Loss: 2.2320
# Epoch 301 | Loss: 2.2313
# Epoch 302 | Loss: 2.2289
# Epoch 303 | Loss: 2.2263
# Epoch 304 | Loss: 2.2238
# Epoch 305 | Loss: 2.2227
# Epoch 306 | Loss: 2.2206
# Epoch 307 | Loss: 2.2180
# Epoch 308 | Loss: 2.2152
# Epoch 309 | Loss: 2.2123
# Epoch 310 | Loss: 2.2108
# Epoch 311 | Loss: 2.2084
# Epoch 312 | Loss: 2.2067
# Epoch 313 | Loss: 2.2048
# Epoch 314 | Loss: 2.2021
# Epoch 315 | Loss: 2.2005
# Epoch 316 | Loss: 2.1993
# Epoch 317 | Loss: 2.1955
# Epoch 318 | Loss: 2.1927
# Epoch 319 | Loss: 2.1918
# Epoch 320 | Loss: 2.1887
# Epoch 321 | Loss: 2.1872
# Epoch 322 | Loss: 2.1841
# Epoch 323 | Loss: 2.1832
# Epoch 324 | Loss: 2.1808
# Epoch 325 | Loss: 2.1789
# Epoch 326 | Loss: 2.1754
# Epoch 327 | Loss: 2.1741
# Epoch 328 | Loss: 2.1721
# Epoch 329 | Loss: 2.1693
# Epoch 330 | Loss: 2.1680
# Epoch 331 | Loss: 2.1659
# Epoch 332 | Loss: 2.1640
# Epoch 333 | Loss: 2.1627
# Epoch 334 | Loss: 2.1597
# Epoch 335 | Loss: 2.1570
# Epoch 336 | Loss: 2.1554
# Epoch 337 | Loss: 2.1533
# Epoch 338 | Loss: 2.1512
# Epoch 339 | Loss: 2.1485
# Epoch 340 | Loss: 2.1476
# Epoch 341 | Loss: 2.1452
# Epoch 342 | Loss: 2.1422
# Epoch 343 | Loss: 2.1409
# Epoch 344 | Loss: 2.1382
# Epoch 345 | Loss: 2.1377
# Epoch 346 | Loss: 2.1345
# Epoch 347 | Loss: 2.1329
# Epoch 348 | Loss: 2.1316
# Epoch 349 | Loss: 2.1285
# Epoch 350 | Loss: 2.1268
# Epoch 351 | Loss: 2.1243
# Epoch 352 | Loss: 2.1233
# Epoch 353 | Loss: 2.1203
# Epoch 354 | Loss: 2.1175
# Epoch 355 | Loss: 2.1169
# Epoch 356 | Loss: 2.1139
# Epoch 357 | Loss: 2.1121
# Epoch 358 | Loss: 2.1112
# Epoch 359 | Loss: 2.1093
# Epoch 360 | Loss: 2.1067
# Epoch 361 | Loss: 2.1043
# Epoch 362 | Loss: 2.1027
# Epoch 363 | Loss: 2.1001
# Epoch 364 | Loss: 2.0988
# Epoch 365 | Loss: 2.0968
# Epoch 366 | Loss: 2.0959
# Epoch 367 | Loss: 2.0925
# Epoch 368 | Loss: 2.0909
# Epoch 369 | Loss: 2.0879
# Epoch 370 | Loss: 2.0878
# Epoch 371 | Loss: 2.0849
# Epoch 372 | Loss: 2.0824
# Epoch 373 | Loss: 2.0810
# Epoch 374 | Loss: 2.0796
# Epoch 375 | Loss: 2.0767
# Epoch 376 | Loss: 2.0749
# Epoch 377 | Loss: 2.0735
# Epoch 378 | Loss: 2.0712
# Epoch 379 | Loss: 2.0694
# Epoch 380 | Loss: 2.0681
# Epoch 381 | Loss: 2.0654
# Epoch 382 | Loss: 2.0642
# Epoch 383 | Loss: 2.0624
# Epoch 384 | Loss: 2.0587
# Epoch 385 | Loss: 2.0569
# Epoch 386 | Loss: 2.0551
# Epoch 387 | Loss: 2.0535
# Epoch 388 | Loss: 2.0528
# Epoch 389 | Loss: 2.0505
# Epoch 390 | Loss: 2.0486
# Epoch 391 | Loss: 2.0491
# Epoch 392 | Loss: 2.0448
# Epoch 393 | Loss: 2.0427
# Epoch 394 | Loss: 2.0421
# Epoch 395 | Loss: 2.0383
# Epoch 396 | Loss: 2.0363
# Epoch 397 | Loss: 2.0346
# Epoch 398 | Loss: 2.0337
# Epoch 399 | Loss: 2.0313
# Epoch 400 | Loss: 2.0290
# Epoch 401 | Loss: 2.0294
# Epoch 402 | Loss: 2.0273
# Epoch 403 | Loss: 2.0241
# Epoch 404 | Loss: 2.0226
# Epoch 405 | Loss: 2.0210
# Epoch 406 | Loss: 2.0187
# Epoch 407 | Loss: 2.0158
# Epoch 408 | Loss: 2.0139
# Epoch 409 | Loss: 2.0130
# Epoch 410 | Loss: 2.0113
# Epoch 411 | Loss: 2.0090
# Epoch 412 | Loss: 2.0063
# Epoch 413 | Loss: 2.0071
# Epoch 414 | Loss: 2.0034
# Epoch 415 | Loss: 2.0018
# Epoch 416 | Loss: 2.0010
# Epoch 417 | Loss: 1.9980
# Epoch 418 | Loss: 1.9980
# Epoch 419 | Loss: 1.9948
# Epoch 420 | Loss: 1.9946
# Epoch 421 | Loss: 1.9912
# Epoch 422 | Loss: 1.9903
# Epoch 423 | Loss: 1.9862
# Epoch 424 | Loss: 1.9866
# Epoch 425 | Loss: 1.9836
# Epoch 426 | Loss: 1.9811
# Epoch 427 | Loss: 1.9811
# Epoch 428 | Loss: 1.9782
# Epoch 429 | Loss: 1.9762
# Epoch 430 | Loss: 1.9748
# Epoch 431 | Loss: 1.9733
# Epoch 432 | Loss: 1.9713
# Epoch 433 | Loss: 1.9706
# Epoch 434 | Loss: 1.9676
# Epoch 435 | Loss: 1.9665
# Epoch 436 | Loss: 1.9645
# Epoch 437 | Loss: 1.9630
# Epoch 438 | Loss: 1.9613
# Epoch 439 | Loss: 1.9590
# Epoch 440 | Loss: 1.9579
# Epoch 441 | Loss: 1.9547
# Epoch 442 | Loss: 1.9542
# Epoch 443 | Loss: 1.9511
# Epoch 444 | Loss: 1.9500
# Epoch 445 | Loss: 1.9472
# Epoch 446 | Loss: 1.9486
# Epoch 447 | Loss: 1.9451
# Epoch 448 | Loss: 1.9425
# Epoch 449 | Loss: 1.9417
# Epoch 450 | Loss: 1.9406
# Epoch 451 | Loss: 1.9371
# Epoch 452 | Loss: 1.9366
# Epoch 453 | Loss: 1.9340
# Epoch 454 | Loss: 1.9318
# Epoch 455 | Loss: 1.9327
# Epoch 456 | Loss: 1.9291
# Epoch 457 | Loss: 1.9288
# Epoch 458 | Loss: 1.9252
# Epoch 459 | Loss: 1.9249
# Epoch 460 | Loss: 1.9221
# Epoch 461 | Loss: 1.9221
# Epoch 462 | Loss: 1.9188
# Epoch 463 | Loss: 1.9161
# Epoch 464 | Loss: 1.9153
# Epoch 465 | Loss: 1.9139
# Epoch 466 | Loss: 1.9112
# Epoch 467 | Loss: 1.9100
# Epoch 468 | Loss: 1.9093
# Epoch 469 | Loss: 1.9070
# Epoch 470 | Loss: 1.9042
# Epoch 471 | Loss: 1.9021
# Epoch 472 | Loss: 1.9014
# Epoch 473 | Loss: 1.8998
# Epoch 474 | Loss: 1.8979
# Epoch 475 | Loss: 1.8960
# Epoch 476 | Loss: 1.8951
# Epoch 477 | Loss: 1.8932
# Epoch 478 | Loss: 1.8911
# Epoch 479 | Loss: 1.8893
# Epoch 480 | Loss: 1.8890
# Epoch 481 | Loss: 1.8862
# Epoch 482 | Loss: 1.8833
# Epoch 483 | Loss: 1.8825
# Epoch 484 | Loss: 1.8800
# Epoch 485 | Loss: 1.8787
# Epoch 486 | Loss: 1.8770
# Epoch 487 | Loss: 1.8753
# Epoch 488 | Loss: 1.8726
# Epoch 489 | Loss: 1.8728
# Epoch 490 | Loss: 1.8697
# Epoch 491 | Loss: 1.8684
# Epoch 492 | Loss: 1.8669
# Epoch 493 | Loss: 1.8663
# Epoch 494 | Loss: 1.8642
# Epoch 495 | Loss: 1.8617
# Epoch 496 | Loss: 1.8608
# Epoch 497 | Loss: 1.8591
# Epoch 498 | Loss: 1.8569
# Epoch 499 | Loss: 1.8543
# Epoch 500 | Loss: 1.8532
# Epoch 501 | Loss: 1.8519
# Epoch 502 | Loss: 1.8496
# Epoch 503 | Loss: 1.8508
# Epoch 504 | Loss: 1.8473
# Epoch 505 | Loss: 1.8447
# Epoch 506 | Loss: 1.8450
# Epoch 507 | Loss: 1.8417
# Epoch 508 | Loss: 1.8417
# Epoch 509 | Loss: 1.8382
# Epoch 510 | Loss: 1.8382
# Epoch 511 | Loss: 1.8349
# Epoch 512 | Loss: 1.8328
# Epoch 513 | Loss: 1.8348
# Epoch 514 | Loss: 1.8306
# Epoch 515 | Loss: 1.8291
# Epoch 516 | Loss: 1.8264
# Epoch 517 | Loss: 1.8258
# Epoch 518 | Loss: 1.8233
# Epoch 519 | Loss: 1.8215
# Epoch 520 | Loss: 1.8237
# Epoch 521 | Loss: 1.8186
# Epoch 522 | Loss: 1.8169
# Epoch 523 | Loss: 1.8138
# Epoch 524 | Loss: 1.8133
# Epoch 525 | Loss: 1.8117
# Epoch 526 | Loss: 1.8108
# Epoch 527 | Loss: 1.8097
# Epoch 528 | Loss: 1.8065
# Epoch 529 | Loss: 1.8051
# Epoch 530 | Loss: 1.8039
# Epoch 531 | Loss: 1.8017
# Epoch 532 | Loss: 1.8009
# Epoch 533 | Loss: 1.7995
# Epoch 534 | Loss: 1.7968
# Epoch 535 | Loss: 1.7959
# Epoch 536 | Loss: 1.7937
# Epoch 537 | Loss: 1.7912
# Epoch 538 | Loss: 1.7908
# Epoch 539 | Loss: 1.7892
# Epoch 540 | Loss: 1.7881
# Epoch 541 | Loss: 1.7854
# Epoch 542 | Loss: 1.7852
# Epoch 543 | Loss: 1.7814
# Epoch 544 | Loss: 1.7801
# Epoch 545 | Loss: 1.7777
# Epoch 546 | Loss: 1.7767
# Epoch 547 | Loss: 1.7771
# Epoch 548 | Loss: 1.7747
# Epoch 549 | Loss: 1.7719
# Epoch 550 | Loss: 1.7697
# Epoch 551 | Loss: 1.7689
# Epoch 552 | Loss: 1.7671
# Epoch 553 | Loss: 1.7657
# Epoch 554 | Loss: 1.7642
# Epoch 555 | Loss: 1.7624
# Epoch 556 | Loss: 1.7620
# Epoch 557 | Loss: 1.7596
# Epoch 558 | Loss: 1.7575
# Epoch 559 | Loss: 1.7567
# Epoch 560 | Loss: 1.7544
# Epoch 561 | Loss: 1.7528
# Epoch 562 | Loss: 1.7506
# Epoch 563 | Loss: 1.7509
# Epoch 564 | Loss: 1.7478
# Epoch 565 | Loss: 1.7474
# Epoch 566 | Loss: 1.7448
# Epoch 567 | Loss: 1.7450
# Epoch 568 | Loss: 1.7413
# Epoch 569 | Loss: 1.7407
# Epoch 570 | Loss: 1.7374
# Epoch 571 | Loss: 1.7396
# Epoch 572 | Loss: 1.7350
# Epoch 573 | Loss: 1.7363
# Epoch 574 | Loss: 1.7330
# Epoch 575 | Loss: 1.7311
# Epoch 576 | Loss: 1.7298
# Epoch 577 | Loss: 1.7266
# Epoch 578 | Loss: 1.7261
# Epoch 579 | Loss: 1.7226
# Epoch 580 | Loss: 1.7220
# Epoch 581 | Loss: 1.7196
# Epoch 582 | Loss: 1.7192
# Epoch 583 | Loss: 1.7170
# Epoch 584 | Loss: 1.7174
# Epoch 585 | Loss: 1.7131
# Epoch 586 | Loss: 1.7127
# Epoch 587 | Loss: 1.7100
# Epoch 588 | Loss: 1.7113
# Epoch 589 | Loss: 1.7086
# Epoch 590 | Loss: 1.7067
# Epoch 591 | Loss: 1.7037
# Epoch 592 | Loss: 1.7017
# Epoch 593 | Loss: 1.7011
# Epoch 594 | Loss: 1.7003
# Epoch 595 | Loss: 1.6983
# Epoch 596 | Loss: 1.6945
# Epoch 597 | Loss: 1.6936
# Epoch 598 | Loss: 1.6927
# Epoch 599 | Loss: 1.6911
# Epoch 600 | Loss: 1.6899
# Epoch 601 | Loss: 1.6872
# Epoch 602 | Loss: 1.6872
# Epoch 603 | Loss: 1.6854
# Epoch 604 | Loss: 1.6831
# Epoch 605 | Loss: 1.6823
# Epoch 606 | Loss: 1.6802
# Epoch 607 | Loss: 1.6794
# Epoch 608 | Loss: 1.6773
# Epoch 609 | Loss: 1.6767
# Epoch 610 | Loss: 1.6733
# Epoch 611 | Loss: 1.6736
# Epoch 612 | Loss: 1.6712
# Epoch 613 | Loss: 1.6690
# Epoch 614 | Loss: 1.6673
# Epoch 615 | Loss: 1.6649
# Epoch 616 | Loss: 1.6638
# Epoch 617 | Loss: 1.6613
# Epoch 618 | Loss: 1.6602
# Epoch 619 | Loss: 1.6594
# Epoch 620 | Loss: 1.6581
# Epoch 621 | Loss: 1.6571
# Epoch 622 | Loss: 1.6582
# Epoch 623 | Loss: 1.6528
# Epoch 624 | Loss: 1.6514
# Epoch 625 | Loss: 1.6509
# Epoch 626 | Loss: 1.6481
# Epoch 627 | Loss: 1.6467
# Epoch 628 | Loss: 1.6496
# Epoch 629 | Loss: 1.6444
# Epoch 630 | Loss: 1.6418
# Epoch 631 | Loss: 1.6387
# Epoch 632 | Loss: 1.6394
# Epoch 633 | Loss: 1.6358
# Epoch 634 | Loss: 1.6350
# Epoch 635 | Loss: 1.6332
# Epoch 636 | Loss: 1.6337
# Epoch 637 | Loss: 1.6309
# Epoch 638 | Loss: 1.6280
# Epoch 639 | Loss: 1.6295
# Epoch 640 | Loss: 1.6255
# Epoch 641 | Loss: 1.6244
# Epoch 642 | Loss: 1.6225
# Epoch 643 | Loss: 1.6218
# Epoch 644 | Loss: 1.6179
# Epoch 645 | Loss: 1.6175
# Epoch 646 | Loss: 1.6149
# Epoch 647 | Loss: 1.6133
# Epoch 648 | Loss: 1.6117
# Epoch 649 | Loss: 1.6145
# Epoch 650 | Loss: 1.6095
# Epoch 651 | Loss: 1.6079
# Epoch 652 | Loss: 1.6077
# Epoch 653 | Loss: 1.6054
# Epoch 654 | Loss: 1.6036
# Epoch 655 | Loss: 1.5995
# Epoch 656 | Loss: 1.6015
# Epoch 657 | Loss: 1.5965
# Epoch 658 | Loss: 1.5968
# Epoch 659 | Loss: 1.5944
# Epoch 660 | Loss: 1.5931
# Epoch 661 | Loss: 1.5907
# Epoch 662 | Loss: 1.5903
# Epoch 663 | Loss: 1.5891
# Epoch 664 | Loss: 1.5875
# Epoch 665 | Loss: 1.5879
# Epoch 666 | Loss: 1.5852
# Epoch 667 | Loss: 1.5825
# Epoch 668 | Loss: 1.5811
# Epoch 669 | Loss: 1.5796
# Epoch 670 | Loss: 1.5773
# Epoch 671 | Loss: 1.5772
# Epoch 672 | Loss: 1.5737
# Epoch 673 | Loss: 1.5739
# Epoch 674 | Loss: 1.5744
# Epoch 675 | Loss: 1.5699
# Epoch 676 | Loss: 1.5710
# Epoch 677 | Loss: 1.5754
# Epoch 678 | Loss: 1.5667
# Epoch 679 | Loss: 1.5665
# Epoch 680 | Loss: 1.5637
# Epoch 681 | Loss: 1.5596
# Epoch 682 | Loss: 1.5612
# Epoch 683 | Loss: 1.5577
# Epoch 684 | Loss: 1.5551
# Epoch 685 | Loss: 1.5552
# Epoch 686 | Loss: 1.5539
# Epoch 687 | Loss: 1.5528
# Epoch 688 | Loss: 1.5478
# Epoch 689 | Loss: 1.5479
# Epoch 690 | Loss: 1.5467
# Epoch 691 | Loss: 1.5461
# Epoch 692 | Loss: 1.5432
# Epoch 693 | Loss: 1.5451
# Epoch 694 | Loss: 1.5423
# Epoch 695 | Loss: 1.5406
# Epoch 696 | Loss: 1.5408
# Epoch 697 | Loss: 1.5355
# Epoch 698 | Loss: 1.5355
# Epoch 699 | Loss: 1.5330
# Epoch 700 | Loss: 1.5312
# Epoch 701 | Loss: 1.5310
# Epoch 702 | Loss: 1.5336
# Epoch 703 | Loss: 1.5271
# Epoch 704 | Loss: 1.5237
# Epoch 705 | Loss: 1.5232
# Epoch 706 | Loss: 1.5288
# Epoch 707 | Loss: 1.5228
# Epoch 708 | Loss: 1.5190
# Epoch 709 | Loss: 1.5200
# Epoch 710 | Loss: 1.5222
# Epoch 711 | Loss: 1.5170
# Epoch 712 | Loss: 1.5140
# Epoch 713 | Loss: 1.5102
# Epoch 714 | Loss: 1.5098
# Epoch 715 | Loss: 1.5069
# Epoch 716 | Loss: 1.5072
# Epoch 717 | Loss: 1.5062
# Epoch 718 | Loss: 1.5097
# Epoch 719 | Loss: 1.5047
# Epoch 720 | Loss: 1.5002
# Epoch 721 | Loss: 1.5014
# Epoch 722 | Loss: 1.4982
# Epoch 723 | Loss: 1.4961
# Epoch 724 | Loss: 1.4971
# Epoch 725 | Loss: 1.4929
# Epoch 726 | Loss: 1.4904
# Epoch 727 | Loss: 1.4917
# Epoch 728 | Loss: 1.4911
# Epoch 729 | Loss: 1.4904
# Epoch 730 | Loss: 1.4844
# Epoch 731 | Loss: 1.4840
# Epoch 732 | Loss: 1.4853
# Epoch 733 | Loss: 1.4817
# Epoch 734 | Loss: 1.4819
# Epoch 735 | Loss: 1.4787
# Epoch 736 | Loss: 1.4784
# Epoch 737 | Loss: 1.4757
# Epoch 738 | Loss: 1.4768
# Epoch 739 | Loss: 1.4742
# Epoch 740 | Loss: 1.4707
# Epoch 741 | Loss: 1.4716
# Epoch 742 | Loss: 1.4716
# Epoch 743 | Loss: 1.4686
# Epoch 744 | Loss: 1.4677
# Epoch 745 | Loss: 1.4672
# Epoch 746 | Loss: 1.4654
# Epoch 747 | Loss: 1.4612
# Epoch 748 | Loss: 1.4589
# Epoch 749 | Loss: 1.4582
# Epoch 750 | Loss: 1.4622
# Epoch 751 | Loss: 1.4582
# Epoch 752 | Loss: 1.4592
# Epoch 753 | Loss: 1.4568
# Epoch 754 | Loss: 1.4504
# Epoch 755 | Loss: 1.4573
# Epoch 756 | Loss: 1.4502
# Epoch 757 | Loss: 1.4553
# Epoch 758 | Loss: 1.4477
# Epoch 759 | Loss: 1.4445
# Epoch 760 | Loss: 1.4442
# Epoch 761 | Loss: 1.4400
# Epoch 762 | Loss: 1.4392
# Epoch 763 | Loss: 1.4386
# Epoch 764 | Loss: 1.4344
# Epoch 765 | Loss: 1.4367
# Epoch 766 | Loss: 1.4448
# Epoch 767 | Loss: 1.4349
# Epoch 768 | Loss: 1.4343
# Epoch 769 | Loss: 1.4286
# Epoch 770 | Loss: 1.4284
# Epoch 771 | Loss: 1.4297
# Epoch 772 | Loss: 1.4294
# Epoch 773 | Loss: 1.4235
# Epoch 774 | Loss: 1.4258
# Epoch 775 | Loss: 1.4234
# Epoch 776 | Loss: 1.4196
# Epoch 777 | Loss: 1.4224
# Epoch 778 | Loss: 1.4229
# Epoch 779 | Loss: 1.4153
# Epoch 780 | Loss: 1.4124
# Epoch 781 | Loss: 1.4106
# Epoch 782 | Loss: 1.4138
# Epoch 783 | Loss: 1.4147
# Epoch 784 | Loss: 1.4093
# Epoch 785 | Loss: 1.4134
# Epoch 786 | Loss: 1.4137
# Epoch 787 | Loss: 1.4059
# Epoch 788 | Loss: 1.4032
# Epoch 789 | Loss: 1.4036
# Epoch 790 | Loss: 1.4001
# Epoch 791 | Loss: 1.4001
# Epoch 792 | Loss: 1.3987
# Epoch 793 | Loss: 1.3994
# Epoch 794 | Loss: 1.3971
# Epoch 795 | Loss: 1.3980
# Epoch 796 | Loss: 1.3928
# Epoch 797 | Loss: 1.3909
# Epoch 798 | Loss: 1.3874
# Epoch 799 | Loss: 1.3882
# Epoch 800 | Loss: 1.3849
# Epoch 801 | Loss: 1.3886
# Epoch 802 | Loss: 1.3849
# Epoch 803 | Loss: 1.3849
# Epoch 804 | Loss: 1.3832
# Epoch 805 | Loss: 1.3820
# Epoch 806 | Loss: 1.3832
# Epoch 807 | Loss: 1.3786
# Epoch 808 | Loss: 1.3811
# Epoch 809 | Loss: 1.3767
# Epoch 810 | Loss: 1.3824
# Epoch 811 | Loss: 1.3781
# Epoch 812 | Loss: 1.3739
# Epoch 813 | Loss: 1.3712
# Epoch 814 | Loss: 1.3724
# Epoch 815 | Loss: 1.3693
# Epoch 816 | Loss: 1.3665
# Epoch 817 | Loss: 1.3624
# Epoch 818 | Loss: 1.3627
# Epoch 819 | Loss: 1.3624
# Epoch 820 | Loss: 1.3619
# Epoch 821 | Loss: 1.3595
# Epoch 822 | Loss: 1.3566
# Epoch 823 | Loss: 1.3550
# Epoch 824 | Loss: 1.3612
# Epoch 825 | Loss: 1.3556
# Epoch 826 | Loss: 1.3511
# Epoch 827 | Loss: 1.3595
# Epoch 828 | Loss: 1.3514
# Epoch 829 | Loss: 1.3472
# Epoch 830 | Loss: 1.3490
# Epoch 831 | Loss: 1.3470
# Epoch 832 | Loss: 1.3464
# Epoch 833 | Loss: 1.3469
# Epoch 834 | Loss: 1.3507
# Epoch 835 | Loss: 1.3432
# Epoch 836 | Loss: 1.3441
# Epoch 837 | Loss: 1.3402
# Epoch 838 | Loss: 1.3451
# Epoch 839 | Loss: 1.3461
# Epoch 840 | Loss: 1.3381
# Epoch 841 | Loss: 1.3318
# Epoch 842 | Loss: 1.3296
# Epoch 843 | Loss: 1.3291
# Epoch 844 | Loss: 1.3267
# Epoch 845 | Loss: 1.3308
# Epoch 846 | Loss: 1.3312
# Epoch 847 | Loss: 1.3328
# Epoch 848 | Loss: 1.3266
# Epoch 849 | Loss: 1.3240
# Epoch 850 | Loss: 1.3222
# Epoch 851 | Loss: 1.3281
# Epoch 852 | Loss: 1.3223
# Epoch 853 | Loss: 1.3170
# Epoch 854 | Loss: 1.3196
# Epoch 855 | Loss: 1.3142
# Epoch 856 | Loss: 1.3115
# Epoch 857 | Loss: 1.3128
# Epoch 858 | Loss: 1.3142
# Epoch 859 | Loss: 1.3172
# Epoch 860 | Loss: 1.3151
# Epoch 861 | Loss: 1.3118
# Epoch 862 | Loss: 1.3079
# Epoch 863 | Loss: 1.3025
# Epoch 864 | Loss: 1.3039
# Epoch 865 | Loss: 1.3039
# Epoch 866 | Loss: 1.3011
# Epoch 867 | Loss: 1.2994
# Epoch 868 | Loss: 1.3054
# Epoch 869 | Loss: 1.2993
# Epoch 870 | Loss: 1.2983
# Epoch 871 | Loss: 1.3057
# Epoch 872 | Loss: 1.2997
# Epoch 873 | Loss: 1.2946
# Epoch 874 | Loss: 1.2908
# Epoch 875 | Loss: 1.2886
# Epoch 876 | Loss: 1.2904
# Epoch 877 | Loss: 1.2881
# Epoch 878 | Loss: 1.2856
# Epoch 879 | Loss: 1.2866
# Epoch 880 | Loss: 1.2931
# Epoch 881 | Loss: 1.2899
# Epoch 882 | Loss: 1.2883
# Epoch 883 | Loss: 1.2832
# Epoch 884 | Loss: 1.2796
# Epoch 885 | Loss: 1.2796
# Epoch 886 | Loss: 1.2816
# Epoch 887 | Loss: 1.2812
# Epoch 888 | Loss: 1.2746
# Epoch 889 | Loss: 1.2747
# Epoch 890 | Loss: 1.2742
# Epoch 891 | Loss: 1.2741
# Epoch 892 | Loss: 1.2783
# Epoch 893 | Loss: 1.2747
# Epoch 894 | Loss: 1.2729
# Epoch 895 | Loss: 1.2690
# Epoch 896 | Loss: 1.2661
# Epoch 897 | Loss: 1.2666
# Epoch 898 | Loss: 1.2697
# Epoch 899 | Loss: 1.2688
# Epoch 900 | Loss: 1.2592
# Epoch 901 | Loss: 1.2591
# Epoch 902 | Loss: 1.2602
# Epoch 903 | Loss: 1.2652
# Epoch 904 | Loss: 1.2590
# Epoch 905 | Loss: 1.2567
# Epoch 906 | Loss: 1.2523
# Epoch 907 | Loss: 1.2535
# Epoch 908 | Loss: 1.2507
# Epoch 909 | Loss: 1.2492
# Epoch 910 | Loss: 1.2474
# Epoch 911 | Loss: 1.2483
# Epoch 912 | Loss: 1.2428
# Epoch 913 | Loss: 1.2475
# Epoch 914 | Loss: 1.2459
# Epoch 915 | Loss: 1.2455
# Epoch 916 | Loss: 1.2437
# Epoch 917 | Loss: 1.2510
# Epoch 918 | Loss: 1.2445
# Epoch 919 | Loss: 1.2457
# Epoch 920 | Loss: 1.2462
# Epoch 921 | Loss: 1.2518
# Epoch 922 | Loss: 1.2389
# Epoch 923 | Loss: 1.2500
# Epoch 924 | Loss: 1.2433
# Epoch 925 | Loss: 1.2354
# Epoch 926 | Loss: 1.2279
# Epoch 927 | Loss: 1.2347
# Epoch 928 | Loss: 1.2313
# Epoch 929 | Loss: 1.2300
# Epoch 930 | Loss: 1.2339
# Epoch 931 | Loss: 1.2256
# Epoch 932 | Loss: 1.2229
# Epoch 933 | Loss: 1.2232
# Epoch 934 | Loss: 1.2190
# Epoch 935 | Loss: 1.2212
# Epoch 936 | Loss: 1.2186
# Epoch 937 | Loss: 1.2217
# Epoch 938 | Loss: 1.2194
# Epoch 939 | Loss: 1.2157
# Epoch 940 | Loss: 1.2149
# Epoch 941 | Loss: 1.2160
# Epoch 942 | Loss: 1.2267
# Epoch 943 | Loss: 1.2170
# Epoch 944 | Loss: 1.2145
# Epoch 945 | Loss: 1.2209
# Epoch 946 | Loss: 1.2146
# Epoch 947 | Loss: 1.2059
# Epoch 948 | Loss: 1.2177
# Epoch 949 | Loss: 1.2135
# Epoch 950 | Loss: 1.2078
# Epoch 951 | Loss: 1.2031
# Epoch 952 | Loss: 1.2015
# Epoch 953 | Loss: 1.1985
# Epoch 954 | Loss: 1.2079
# Epoch 955 | Loss: 1.1986
# Epoch 956 | Loss: 1.1980
# Epoch 957 | Loss: 1.1948
# Epoch 958 | Loss: 1.1982
# Epoch 959 | Loss: 1.1941
# Epoch 960 | Loss: 1.2021
# Epoch 961 | Loss: 1.1979
# Epoch 962 | Loss: 1.1944
# Epoch 963 | Loss: 1.1944
# Epoch 964 | Loss: 1.1914
# Epoch 965 | Loss: 1.1916
# Epoch 966 | Loss: 1.1901
# Epoch 967 | Loss: 1.1976
# Epoch 968 | Loss: 1.1971
# Epoch 969 | Loss: 1.1919
# Epoch 970 | Loss: 1.1842
# Epoch 971 | Loss: 1.1791
# Epoch 972 | Loss: 1.1862
# Epoch 973 | Loss: 1.1938
# Epoch 974 | Loss: 1.1855
# Epoch 975 | Loss: 1.1831
# Epoch 976 | Loss: 1.1722
# Epoch 977 | Loss: 1.1767
# Epoch 978 | Loss: 1.1770
# Epoch 979 | Loss: 1.1995
# Epoch 980 | Loss: 1.1900
# Epoch 981 | Loss: 1.1734
# Epoch 982 | Loss: 1.1702
# Epoch 983 | Loss: 1.1627
# Epoch 984 | Loss: 1.1688
# Epoch 985 | Loss: 1.1717
# Epoch 986 | Loss: 1.1647
# Epoch 987 | Loss: 1.1708
# Epoch 988 | Loss: 1.1645
# Epoch 989 | Loss: 1.1653
# Epoch 990 | Loss: 1.1722
# Epoch 991 | Loss: 1.1682
# Epoch 992 | Loss: 1.1644
# Epoch 993 | Loss: 1.1668
# Epoch 994 | Loss: 1.1561
# Epoch 995 | Loss: 1.1597
# Epoch 996 | Loss: 1.1568
# Epoch 997 | Loss: 1.1608
# Epoch 998 | Loss: 1.1501
# Epoch 999 | Loss: 1.1588
# Epoch 1000 | Loss: 1.1531
# Epoch 1001 | Loss: 1.1509
# Epoch 1002 | Loss: 1.1488
# Epoch 1003 | Loss: 1.1545
# Epoch 1004 | Loss: 1.1503
# Epoch 1005 | Loss: 1.1473
# Epoch 1006 | Loss: 1.1478
# Epoch 1007 | Loss: 1.1388
# Epoch 1008 | Loss: 1.1573
# Epoch 1009 | Loss: 1.1550
# Epoch 1010 | Loss: 1.1384
# Epoch 1011 | Loss: 1.1364
# Epoch 1012 | Loss: 1.1632
# Epoch 1013 | Loss: 1.1523
# Epoch 1014 | Loss: 1.1371
# Epoch 1015 | Loss: 1.1457
# Epoch 1016 | Loss: 1.1350
# Epoch 1017 | Loss: 1.1340
# Epoch 1018 | Loss: 1.1358
# Epoch 1019 | Loss: 1.1488
# Epoch 1020 | Loss: 1.1314
# Epoch 1021 | Loss: 1.1265
# Epoch 1022 | Loss: 1.1339
# Epoch 1023 | Loss: 1.1358
# Epoch 1024 | Loss: 1.1289
# Epoch 1025 | Loss: 1.1257
# Epoch 1026 | Loss: 1.1255
# Epoch 1027 | Loss: 1.1381
# Epoch 1028 | Loss: 1.1554
# Epoch 1029 | Loss: 1.1358
# Epoch 1030 | Loss: 1.1274
# Epoch 1031 | Loss: 1.1207
# Epoch 1032 | Loss: 1.1234
# Epoch 1033 | Loss: 1.1223
# Epoch 1034 | Loss: 1.1265
# Epoch 1035 | Loss: 1.1159
# Epoch 1036 | Loss: 1.1100
# Epoch 1037 | Loss: 1.1104
# Epoch 1038 | Loss: 1.1131
# Epoch 1039 | Loss: 1.1134
# Epoch 1040 | Loss: 1.1209
# Saved Parameters

# %%
def predict(Encoder_GRU, Decoder_GRU, input_seq,
            eng_to_ind, eng_embedding,
            jpn_embedding, o_w, o_b,
            pad_id=0, unk_id=1, bos_id=2, eos_id=3,
            max_len=20, encoder_len=3):
    """
    Greedy decode.

    Returns list of predicted token ids excluding <eos>.
    """
    # Preprocess encoder input
    import re, numpy as np
    seq = re.sub(r"[^a-z0-9\s]", "", input_seq.strip().lower())
    src_tokens = [eng_to_ind.get(w, unk_id) for w in seq.split()]
    if not src_tokens:
        src_tokens = [pad_id]
    while len(src_tokens) < encoder_len:
        src_tokens.append(pad_id)
    src_tokens = src_tokens[:encoder_len]

    enc_embed = eng_embedding[src_tokens][None, ...]  # (1,T,D)
    h_enc, _, _ = Encoder_GRU.forward(enc_embed)      # (1,H)

    h = h_enc
    prev_token = bos_id
    preds = []

    for step in range(max_len):
        # Embed previous token
        y_embed = jpn_embedding[prev_token][None, :]   # (1,D)

        r = sigmoid(y_embed @ Decoder_GRU.r_w.T + h @ Decoder_GRU.r_u + Decoder_GRU.r_b)
        z = sigmoid(y_embed @ Decoder_GRU.z_w.T + h @ Decoder_GRU.z_u + Decoder_GRU.z_b)
        c = tanh(y_embed @ Decoder_GRU.c_w.T + (r * h) @ Decoder_GRU.c_u + Decoder_GRU.c_b)
        h = z * h + (1 - z) * c # (1,H)

        logits = h @ o_w.T + o_b # (1,V_jpn)

        # Prevent <pad> and <bos> from being chosen
        logits[0, pad_id] = -1e9
        logits[0, bos_id] = -1e9

        next_token = int(np.argmax(logits, axis=1)[0])

        if next_token == eos_id:
            break

        preds.append(next_token)
        prev_token = next_token

    return preds

# %% [markdown]
# Translates to "Tom is good" Not a great prediction. It tried its hardest.
