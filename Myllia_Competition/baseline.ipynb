# %% [markdown]
# Mylia competition baseline.

# %%
import os
import re
import numpy as np
import pandas as pd
from pathlib import Path

from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.linear_model import Ridge

import anndata as ad
import scanpy as sc
from scipy import sparse
import sys

# %%
SEED = 6
EMBED_DIM = 128        # gene embedding size from control cells
OUT_PCA_K = 64         # number of output PCA components
RIDGE_ALPHA = 1.0      # ridge strength
CTRL_CELL_SAMPLE = 15000  # sample control cells for speed/memory
np.random.seed(SEED)

# %%
df_means = pd.read_csv('data/training_data_means.csv')
df_valmap = pd.read_csv("data/pert_ids_val.csv")

# %%
gene_columns = [c for c in df_means.columns if c != "pert_symbol"]
baseline_mask = df_means["pert_symbol"] == "non-targeting"
x_base = df_means.iloc[80, 1:].to_numpy(dtype=np.float32)
x_base
# Out:
# array([0.47406167, 0.02579673, 0.09324449, ..., 0.7198073 , 0.7073531 ,
#        0.681142  ], shape=(5127,), dtype=float32)

# %%
df_train = df_means.loc[~baseline_mask].reset_index(drop=True)
train_genes = df_train["pert_symbol"].astype(str).values
missing_train = sorted({g for g in train_genes if g not in gene_columns})

# %%
X_train_means = df_train[gene_columns].to_numpy(dtype=np.float32) # Only gene columns
D_train = X_train_means - x_base[None, :] # Subtract baseline
n_train = D_train.shape[0] # Training perturbations

# %%
X_train_means, x_base[None, :]
# Out:
# (array([[0.3116421 , 0.02210249, 0.10094855, ..., 0.64772666, 0.720461  ,
#          0.6035719 ],
#         [0.627445  , 0.04396126, 0.09433507, ..., 0.8013022 , 0.5453445 ,
#          0.55356663],
#         [0.4671139 , 0.0307136 , 0.09090973, ..., 0.70924103, 0.6747466 ,
#          0.6677914 ],
#         ...,
#         [0.44308463, 0.04487351, 0.12330244, ..., 0.76513106, 0.63349336,
#          0.65966415],
#         [0.49848914, 0.00916384, 0.09652278, ..., 0.6987103 , 0.69961   ,
#          0.6349703 ],
#         [0.48189428, 0.02340364, 0.08553333, ..., 0.6939983 , 0.7037828 ,
#          0.72695136]], shape=(80, 5127), dtype=float32),
#  array([[0.47406167, 0.02579673, 0.09324449, ..., 0.7198073 , 0.7073531 ,
#          0.681142  ]], shape=(1, 5127), dtype=float32))

# %%
delta_baseline = D_train.mean(axis=0)
val_map = dict(zip(df_valmap["pert_id"].astype(str), df_valmap["pert"].astype(str)))

# %%
adata = ad.read_h5ad("Data/training_cells.h5ad")
adata.obs
# Out:
#                        nCount_RNA  nFeature_RNA  percent.mt          sgrna_id  \
# AAACCAAAGACGCGAA_ch_1     16395.0          4191    4.306191          INSIG1_3
# AAACCAAAGCAAATGA_ch_1     12000.0          3631    3.133333            FLNA_2
# AAACCAAAGCAGTCTA_ch_1     55050.0          7061    5.193460           EIF3H_2
# AAACCAAAGGGCATAG_ch_1     19586.0          5010    6.494435           DZIP3_4
# AAACCATTCCAATCGA_ch_1     18744.0          4697    4.604140  non-targeting_25
# ...                           ...           ...         ...               ...
# GTTGTCCGTCCAGTGA_ch_4     21242.0          4904    4.057998          METTL3_4
# GTTGTCCGTGGGTTTG_ch_4     17462.0          4674    3.928531  non-targeting_25
# GTTGTCTTCCCCAACC_ch_4     10459.0          3350    6.922268           IKBKG_1
# GTTGTCTTCCCTTCTC_ch_4     29779.0          5709    3.680446            EGFR_2
# GTTGTGCAGCGCCACA_ch_4     29557.0          5683    0.003383            TFAM_4
#
#                         sgrna_symbol channel
# AAACCAAAGACGCGAA_ch_1         INSIG1    ch_1
# AAACCAAAGCAAATGA_ch_1           FLNA    ch_1
# AAACCAAAGCAGTCTA_ch_1          EIF3H    ch_1
# AAACCAAAGGGCATAG_ch_1          DZIP3    ch_1
# AAACCATTCCAATCGA_ch_1  non-targeting    ch_1
# ...                              ...     ...
# GTTGTCCGTCCAGTGA_ch_4         METTL3    ch_4
# GTTGTCCGTGGGTTTG_ch_4  non-targeting    ch_4
# GTTGTCTTCCCCAACC_ch_4          IKBKG    ch_4
# GTTGTCTTCCCTTCTC_ch_4           EGFR    ch_4
# GTTGTGCAGCGCCACA_ch_4           TFAM    ch_4
#
# [17882 rows x 6 columns]

# %%
ctrl_mask = adata.obs["sgrna_symbol"] == "non-targeting"
adata_ctrl = adata[ctrl_mask].copy()
print(f"Control cells: {adata_ctrl.n_obs:,}")
# Out:
# Control cells: 1,026

# %%
varnames = adata_ctrl.var_names.astype(str)
gene_set = set(gene_columns)
keep_mask = np.array([g in gene_set for g in varnames], dtype=bool)
adata_ctrl = adata_ctrl[:, keep_mask].copy()
adata_ctrl.obs
# Out:
#                        nCount_RNA  nFeature_RNA  percent.mt          sgrna_id  \
# AAACCATTCCAATCGA_ch_1     18744.0          4697    4.604140  non-targeting_25
# AAACCCATCCACAGGT_ch_1     15884.0          4091    4.312516  non-targeting_16
# AAACGGTAGAGTATTC_ch_1     16384.0          4530    6.927490   non-targeting_3
# AAAGCTCGTCATTATC_ch_1     11459.0          3549    7.984990  non-targeting_23
# AAAGTTACAGTACGCC_ch_1     15468.0          4271    5.559866   non-targeting_4
# ...                           ...           ...         ...               ...
# GTTCATCTCAACCAAT_ch_4     21801.0          5063    5.880464  non-targeting_12
# GTTCATTGTGGTTGGC_ch_4     16503.0          4525    4.593104   non-targeting_1
# GTTCTACTCCCTAGGG_ch_4     16918.0          4403    5.177917  non-targeting_12
# GTTGGAACAAAAGGCC_ch_4     27303.0          5495    6.182471  non-targeting_16
# GTTGTCCGTGGGTTTG_ch_4     17462.0          4674    3.928531  non-targeting_25
#
#                         sgrna_symbol channel
# AAACCATTCCAATCGA_ch_1  non-targeting    ch_1
# AAACCCATCCACAGGT_ch_1  non-targeting    ch_1
# AAACGGTAGAGTATTC_ch_1  non-targeting    ch_1
# AAAGCTCGTCATTATC_ch_1  non-targeting    ch_1
# AAAGTTACAGTACGCC_ch_1  non-targeting    ch_1
# ...                              ...     ...
# GTTCATCTCAACCAAT_ch_4  non-targeting    ch_4
# GTTCATTGTGGTTGGC_ch_4  non-targeting    ch_4
# GTTCTACTCCCTAGGG_ch_4  non-targeting    ch_4
# GTTGGAACAAAAGGCC_ch_4  non-targeting    ch_4
# GTTGTCCGTGGGTTTG_ch_4  non-targeting    ch_4
#
# [1026 rows x 6 columns]

# %%
gene_to_idx = {}
for i, gene in enumerate(adata_ctrl.var_names.astype(str)):
    gene_to_idx[gene] = i

gene_to_idx
# Out:
# {'A1BG': 0,
#  'A1CF': 1,
#  'AADAC': 2,
#  'AAK1': 3,
#  'AARS1': 4,
#  'AASS': 5,
#  'ABCA1': 6,
#  'ABCA12': 7,
#  'ABCA5': 8,
#  'ABCB5': 9,
#  'ABCC1': 10,
#  'ABCC2': 11,
#  'ABCC3': 12,
#  'ABCC4': 13,
#  'ABCG2': 14,
#  'ABHD12B': 15,
#  'ABHD17C': 16,
#  'ABHD2': 17,
#  'ABHD3': 18,
#  'ABHD4': 19,
#  'ABI3BP': 20,
#  'ABLIM1': 21,
#  'ABLIM3': 22,
#  'ABRACL': 23,
#  'ABTB2': 24,
#  'ABTB3': 25,
#  'ACAD8': 26,
#  'ACADVL': 27,
#  'ACAT2': 28,
#  'ACER2': 29,
#  'ACKR3': 30,
#  'ACLY': 31,
#  'ACO1': 32,
#  'ACOT13': 33,
#  'ACOT2': 34,
#  'ACOX2': 35,
#  'ACP6': 36,
#  'ACSBG1': 37,
#  'ACSL4': 38,
#  'ACSM2A': 39,
#  'ACSS3': 40,
#  'ACTA2': 41,
#  'ACTB': 42,
#  'ACTG1': 43,
#  'ACTG2': 44,
#  'ACTL6A': 45,
#  'ACTL8': 46,
#  'ACTN1': 47,
#  'ACTN4': 48,
#  'ACTR2': 49,
#  'ACTR3': 50,
#  'ACVR1B': 51,
#  'ACYP2': 52,
#  'ADAM10': 53,
#  'ADAM12': 54,
#  'ADAM19': 55,
#  'ADAM21': 56,
#  'ADAM22': 57,
#  'ADAM23': 58,
#  'ADAM32': 59,
#  'ADAM9': 60,
#  'ADAMTS10': 61,
#  'ADAMTS12': 62,
#  'ADAMTS13': 63,
#  'ADAMTS16': 64,
#  'ADAMTS18': 65,
#  'ADAMTS2': 66,
#  'ADAMTS20': 67,
#  'ADAMTS6': 68,
#  'ADAMTS7': 69,
#  'ADAMTS8': 70,
#  'ADAMTS9': 71,
#  'ADAMTSL3': 72,
#  'ADAP2': 73,
#  'ADARB1': 74,
#  'ADCY9': 75,
#  'ADD2': 76,
#  'ADD3': 77,
#  'ADGRB3': 78,
#  'ADGRE1': 79,
#  'ADGRE3': 80,
#  'ADGRE5': 81,
#  'ADGRG1': 82,
#  'ADGRG6': 83,
#  'ADGRL3': 84,
#  'ADGRL4': 85,
#  'ADI1': 86,
#  'ADISSP': 87,
#  'ADK': 88,
#  'ADM': 89,
#  'ADM2': 90,
#  'ADM5': 91,
#  'ADORA1': 92,
#  'ADORA2B': 93,
#  'ADRB2': 94,
#  'AEN': 95,
#  'AFAP1': 96,
#  'AFAP1L2': 97,
#  'AFF1': 98,
#  'AFF3': 99,
#  'AFG2A': 100,
#  'AFP': 101,
#  'AGAP1': 102,
#  'AGBL4': 103,
#  'AGFG1': 104,
#  'AGMAT': 105,
#  'AGMO': 106,
#  'AGPAT3': 107,
#  'AGR2': 108,
#  'AGRN': 109,
#  'AGT': 110,
#  'AGTR1': 111,
#  'AHCY': 112,
#  'AHCYL2': 113,
#  'AHNAK': 114,
#  'AHNAK2': 115,
#  'AHR': 116,
#  'AHSA1': 117,
#  'AHSG': 118,
#  'AIFM2': 119,
#  'AIMP2': 120,
#  'AJUBA': 121,
#  'AK4': 122,
#  'AK5': 123,
#  'AKAP12': 124,
#  'AKAP13': 125,
#  'AKAP3': 126,
#  'AKAP6': 127,
#  'AKR1A1': 128,
#  'AKR1B1': 129,
#  'AKR1B10': 130,
#  'AKR1C1': 131,
#  'AKR1C2': 132,
#  'AKR1C3': 133,
#  'AKR1C4': 134,
#  'AKT1': 135,
#  'AKT2': 136,
#  'AKT3': 137,
#  'ALCAM': 138,
#  'ALDH16A1': 139,
#  'ALDH1A1': 140,
#  'ALDH1A2': 141,
#  'ALDH1A3': 142,
#  'ALDH1B1': 143,
#  'ALDH1L2': 144,
#  'ALDH2': 145,
#  'ALDH3A1': 146,
#  'ALDH3A2': 147,
#  'ALDH3B1': 148,
#  'ALDH6A1': 149,
#  'ALDH8A1': 150,
#  'ALDH9A1': 151,
#  'ALDOA': 152,
#  'ALDOC': 153,
#  'ALKBH6': 154,
#  'ALKBH7': 155,
#  'ALOX12B': 156,
#  'ALOX5': 157,
#  'ALOX5AP': 158,
#  'ALPK1': 159,
#  'ALPK2': 160,
#  'ALPL': 161,
#  'ALX1': 162,
#  'ALYREF': 163,
#  'AMBP': 164,
#  'AMER1': 165,
#  'AMHR2': 166,
#  'AMIGO2': 167,
#  'AMN1': 168,
#  'AMOTL2': 169,
#  'AMPH': 170,
#  'ANAPC15': 171,
#  'ANAPC5': 172,
#  'ANG': 173,
#  'ANGPT1': 174,
#  'ANGPTL1': 175,
#  'ANGPTL4': 176,
#  'ANK2': 177,
#  'ANK3': 178,
#  'ANKEF1': 179,
#  'ANKFN1': 180,
#  'ANKLE2': 181,
#  'ANKRD1': 182,
#  'ANKRD10': 183,
#  'ANKRD2': 184,
#  'ANKRD28': 185,
#  'ANKRD29': 186,
#  'ANKRD30A': 187,
#  'ANKRD33B': 188,
#  'ANKRD34B': 189,
#  'ANKRD44': 190,
#  'ANKRD55': 191,
#  'ANKS1B': 192,
#  'ANKS4B': 193,
#  'ANKUB1': 194,
#  'ANLN': 195,
#  'ANO4': 196,
#  'ANO6': 197,
#  'ANP32A': 198,
#  'ANP32B': 199,
#  'ANP32E': 200,
#  'ANTXR1': 201,
#  'ANTXR2': 202,
#  'ANXA1': 203,
#  'ANXA10': 204,
#  'ANXA11': 205,
#  'ANXA13': 206,
#  'ANXA2': 207,
#  'ANXA3': 208,
#  'ANXA4': 209,
#  'ANXA5': 210,
#  'ANXA6': 211,
#  'ANXA7': 212,
#  'ANXA8': 213,
#  'ANXA8L1': 214,
#  'ANXA9': 215,
#  'AOC3': 216,
#  'AOPEP': 217,
#  'AOX1': 218,
#  'AP1M2': 219,
#  'AP1S1': 220,
#  'AP2A1': 221,
#  'AP2B1': 222,
#  'AP2S1': 223,
#  'AP3B2': 224,
#  'AP3S1': 225,
#  'APAF1': 226,
#  'APBB1IP': 227,
#  'APBB2': 228,
#  'APH1B': 229,
#  'APIP': 230,
#  'APLP1': 231,
#  'APLP2': 232,
#  'APMAP': 233,
#  'APOC1': 234,
#  'APOD': 235,
#  'APOE': 236,
#  'APOH': 237,
#  'APOL1': 238,
#  'APOL2': 239,
#  'APOLD1': 240,
#  'APP': 241,
#  'APRT': 242,
#  'AQP11': 243,
#  'AQP3': 244,
#  'AQP7B': 245,
#  'AR': 246,
#  'ARAP1': 247,
#  'ARAP3': 248,
#  'ARC': 249,
#  'AREG': 250,
#  'ARF4': 251,
#  'ARF6': 252,
#  'ARFGEF3': 253,
#  'ARG2': 254,
#  'ARHGAP11A': 255,
#  'ARHGAP15': 256,
#  'ARHGAP17': 257,
#  'ARHGAP18': 258,
#  'ARHGAP23': 259,
#  'ARHGAP24': 260,
#  'ARHGAP25': 261,
#  'ARHGAP26': 262,
#  'ARHGAP28': 263,
#  'ARHGAP29': 264,
#  'ARHGAP30': 265,
#  'ARHGAP31': 266,
#  'ARHGAP42': 267,
#  'ARHGAP5': 268,
#  'ARHGAP6': 269,
#  'ARHGAP8': 270,
#  'ARHGDIB': 271,
#  'ARHGEF1': 272,
#  'ARHGEF28': 273,
#  'ARHGEF38': 274,
#  'ARHGEF39': 275,
#  'ARHGEF4': 276,
#  'ARID1A': 277,
#  'ARID2': 278,
#  'ARID5B': 279,
#  'ARK2C': 280,
#  'ARL13B': 281,
#  'ARL14': 282,
#  'ARL15': 283,
#  'ARL3': 284,
#  'ARL4A': 285,
#  'ARL4C': 286,
#  'ARL4D': 287,
#  'ARL6IP1': 288,
#  'ARL6IP5': 289,
#  'ARMH1': 290,
#  'ARPC1B': 291,
#  'ARPC2': 292,
#  'ARPC3': 293,
#  'ARPC4-TTLL3': 294,
#  'ARPC5': 295,
#  'ARRB1': 296,
#  'ARRDC3': 297,
#  'ARRDC4': 298,
#  'ARSJ': 299,
#  'ARTN': 300,
#  'ARX': 301,
#  'ASAH1': 302,
#  'ASAH2': 303,
#  'ASAP1': 304,
#  'ASAP2': 305,
#  'ASB18': 306,
#  'ASB2': 307,
#  'ASB8': 308,
#  'ASCC3': 309,
#  'ASF1B': 310,
#  'ASIC2': 311,
#  'ASIC3': 312,
#  'ASIC5': 313,
#  'ASNS': 314,
#  'ASPH': 315,
#  'ASPHD1': 316,
#  'ASPM': 317,
#  'ASS1': 318,
#  'ASTN2': 319,
#  'ATAD2': 320,
#  'ATAD5': 321,
#  'ATCAY': 322,
#  'ATE1': 323,
#  'ATF3': 324,
#  'ATF4': 325,
#  'ATF5': 326,
#  'ATF7IP': 327,
#  'ATG12': 328,
#  'ATG16L1': 329,
#  'ATG4A': 330,
#  'ATG5': 331,
#  'ATG7': 332,
#  'ATL1': 333,
#  'ATM': 334,
#  'ATMIN': 335,
#  'ATOH8': 336,
#  'ATOSA': 337,
#  'ATOSB': 338,
#  'ATOX1': 339,
#  'ATP10A': 340,
#  'ATP10D': 341,
#  'ATP1B1': 342,
#  'ATP1B3': 343,
#  'ATP2A1': 344,
#  'ATP2A2': 345,
#  'ATP2B1': 346,
#  'ATP2B4': 347,
#  'ATP5F1A': 348,
#  'ATP5F1B': 349,
#  'ATP5F1E': 350,
#  'ATP5IF1': 351,
#  'ATP5MC1': 352,
#  'ATP5MC2': 353,
#  'ATP5MC3': 354,
#  'ATP5MJ': 355,
#  'ATP6AP1': 356,
#  'ATP6AP2': 357,
#  'ATP6V0B': 358,
#  'ATP6V0C': 359,
#  'ATP6V0D1': 360,
#  'ATP6V0E1': 361,
#  'ATP6V1A': 362,
#  'ATP6V1C1': 363,
#  'ATP6V1E1': 364,
#  'ATP8A1': 365,
#  'ATP8A2': 366,
#  'ATP8B1': 367,
#  'ATP8B4': 368,
#  'ATP9A': 369,
#  'ATRAID': 370,
#  'ATRNL1': 371,
#  'ATXN1': 372,
#  'ATXN7L1': 373,
#  'AURKA': 374,
#  'AURKB': 375,
#  'AUTS2': 376,
#  'AVIL': 377,
#  'AVPI1': 378,
#  'AXDND1': 379,
#  'AXL': 380,
#  'B2M': 381,
#  'B3GALT1': 382,
#  'B3GNT3': 383,
#  'B4GALNT3': 384,
#  'B4GALT1': 385,
#  'B4GALT4': 386,
#  'BAAT': 387,
#  'BABAM2': 388,
#  'BACE2': 389,
#  'BACH1': 390,
#  'BACH2': 391,
#  'BAD': 392,
#  'BAG1': 393,
#  'BAIAP2': 394,
#  'BAIAP2L2': 395,
#  'BAK1': 396,
#  'BAMBI': 397,
#  'BANF1': 398,
#  'BANK1': 399,
#  'BARD1': 400,
#  'BASP1': 401,
#  'BATF3': 402,
#  'BAX': 403,
#  'BAZ2B': 404,
#  'BBC3': 405,
#  'BBLN': 406,
#  'BBS5': 407,
#  'BBS9': 408,
#  'BBX': 409,
#  'BCAM': 410,
#  'BCAR1': 411,
#  'BCAR3': 412,
#  'BCAS1': 413,
#  'BCAS3': 414,
#  'BCAT1': 415,
#  'BCCIP': 416,
#  'BCHE': 417,
#  'BCL11B': 418,
#  'BCL2': 419,
#  'BCL2A1': 420,
#  'BCL2L1': 421,
#  'BCL2L12': 422,
#  'BCL3': 423,
#  'BCL6': 424,
#  'BCL7C': 425,
#  'BDH1': 426,
#  'BDKRB2': 427,
#  'BDNF': 428,
#  'BDP1': 429,
#  'BECN1': 430,
#  'BEST1': 431,
#  'BEST3': 432,
#  'BEX2': 433,
#  'BEX3': 434,
#  'BHLHE40': 435,
#  'BICC1': 436,
#  'BICDL1': 437,
#  'BID': 438,
#  'BIN1': 439,
#  'BIRC2': 440,
#  'BIRC3': 441,
#  'BIRC5': 442,
#  'BLM': 443,
#  'BLOC1S2': 444,
#  'BLOC1S3': 445,
#  'BLVRB': 446,
#  'BLZF1': 447,
#  'BMAL2': 448,
#  'BMERB1': 449,
#  'BMI1': 450,
#  'BMP1': 451,
#  'BMP2': 452,
#  'BMP4': 453,
#  'BMP5': 454,
#  'BMP6': 455,
#  'BMP7': 456,
#  'BMPER': 457,
#  'BMPR1B': 458,
#  'BMPR2': 459,
#  'BNC2': 460,
#  'BNIP3': 461,
#  'BNIP3L': 462,
#  'BOD1L1': 463,
#  'BOLA3': 464,
#  'BORA': 465,
#  'BORCS7-ASMT': 466,
#  'BPGM': 467,
#  'BPIFC': 468,
#  'BPNT1': 469,
#  'BPTF': 470,
#  'BRCA1': 471,
#  'BRCA2': 472,
#  'BRD8': 473,
#  'BRD9': 474,
#  'BRI3': 475,
#  'BRINP1': 476,
#  'BRIP1': 477,
#  'BRK1': 478,
#  'BSG': 479,
#  'BST1': 480,
#  'BST2': 481,
#  'BTBD1': 482,
#  'BTBD9': 483,
#  'BTC': 484,
#  'BTF3': 485,
#  'BTF3L4': 486,
#  'BTG1': 487,
#  'BTG2': 488,
#  'BTG3': 489,
#  'BTNL9': 490,
#  'BUB1': 491,
#  'BUB1B': 492,
#  'BUB3': 493,
#  'BUD23': 494,
#  'BYSL': 495,
#  'BZW1': 496,
#  'C10orf90': 497,
#  'C11orf68': 498,
#  'C11orf86': 499,
#  'C11orf91': 500,
#  'C12orf57': 501,
#  'C12orf75': 502,
#  'C13orf46': 503,
#  'C14orf39': 504,
#  'C14orf93': 505,
#  'C15orf48': 506,
#  'C16orf46': 507,
#  'C16orf74': 508,
#  'C17orf100': 509,
#  'C17orf75': 510,
#  'C19orf33': 511,
#  'C19orf53': 512,
#  'C1orf116': 513,
#  'C1orf122': 514,
#  'C1orf162': 515,
#  'C1orf21': 516,
#  'C1orf50': 517,
#  'C1orf53': 518,
#  'C1QBP': 519,
#  'C1QL3': 520,
#  'C1QL4': 521,
#  'C1QTNF1': 522,
#  'C1QTNF2': 523,
#  'C1QTNF3': 524,
#  'C1QTNF3-AMACR': 525,
#  'C1R': 526,
#  'C1RL': 527,
#  'C1S': 528,
#  'C21orf58': 529,
#  'C2CD3': 530,
#  'C2orf81': 531,
#  'C3': 532,
#  'C3orf49': 533,
#  'C3orf52': 534,
#  'C3orf62': 535,
#  'C3orf80': 536,
#  'C4BPB': 537,
#  'C4orf3': 538,
#  'C4orf36': 539,
#  'C4orf36.1': 540,
#  'C4orf51': 541,
#  'C5': 542,
#  'C6orf132': 543,
#  'C6orf141': 544,
#  'C7orf57': 545,
#  'C8orf48': 546,
#  'C9orf43': 547,
#  'CA12': 548,
#  'CA2': 549,
#  'CA8': 550,
#  'CA9': 551,
#  'CABCOCO1': 552,
#  'CABLES1': 553,
#  'CABP1': 554,
#  'CABYR': 555,
#  'CACNA1A': 556,
#  'CACNA1B': 557,
#  'CACNA1D': 558,
#  'CACNA1E': 559,
#  'CACNA1G': 560,
#  'CACNA1H': 561,
#  'CACNA2D1': 562,
#  'CACNA2D3': 563,
#  'CACNB2': 564,
#  'CACNB4': 565,
#  'CACNG2': 566,
#  'CACNG6': 567,
#  'CACNG7': 568,
#  'CACNG8': 569,
#  'CACYBP': 570,
#  'CAD': 571,
#  'CADM1': 572,
#  'CADM2': 573,
#  'CADM3': 574,
#  'CADPS2': 575,
#  'CALB2': 576,
#  'CALCR': 577,
#  'CALD1': 578,
#  'CALM1': 579,
#  'CALM2': 580,
#  'CALM3': 581,
#  'CALN1': 582,
#  'CALR': 583,
#  'CALU': 584,
#  'CALY': 585,
#  'CAMK1D': 586,
#  'CAMK2D': 587,
#  'CAMK2G': 588,
#  'CAMK2N1': 589,
#  'CAMK4': 590,
#  'CAMKMT': 591,
#  'CAMSAP2': 592,
#  'CAMTA1': 593,
#  'CANT1': 594,
#  'CANX': 595,
#  'CAP1': 596,
#  'CAP2': 597,
#  'CAPG': 598,
#  'CAPN12': 599,
#  'CAPN2': 600,
#  'CAPN3': 601,
#  'CAPN5': 602,
#  'CAPNS1': 603,
#  'CAPS2': 604,
#  'CAPZB': 605,
#  'CARD11': 606,
#  'CARD18': 607,
#  'CARD6': 608,
#  'CARMIL2': 609,
#  'CARMIL3': 610,
#  'CARS1': 611,
#  'CASKIN2': 612,
#  'CASP1': 613,
#  'CASP10': 614,
#  'CASP2': 615,
#  'CASP3': 616,
#  'CASP4': 617,
#  'CASP6': 618,
#  'CAST': 619,
#  'CASTOR2': 620,
#  'CATSPER1': 621,
#  'CATSPERB': 622,
#  'CATSPERE': 623,
#  'CAV1': 624,
#  'CAV2': 625,
#  'CAV3': 626,
#  'CAVIN1': 627,
#  'CAVIN2': 628,
#  'CAVIN3': 629,
#  'CBLB': 630,
#  'CBR1': 631,
#  'CBR3': 632,
#  'CBS': 633,
#  'CBX3': 634,
#  'CBX5': 635,
#  'CCAR2': 636,
#  'CCBE1': 637,
#  'CCDC102B': 638,
#  'CCDC127': 639,
#  'CCDC146': 640,
#  'CCDC148': 641,
#  'CCDC150': 642,
#  'CCDC168': 643,
#  'CCDC171': 644,
#  'CCDC18': 645,
#  'CCDC181': 646,
#  'CCDC184': 647,
#  'CCDC186': 648,
#  'CCDC198': 649,
#  'CCDC200': 650,
#  'CCDC28B': 651,
#  'CCDC34': 652,
#  'CCDC47': 653,
#  'CCDC50': 654,
#  'CCDC68': 655,
#  'CCDC7': 656,
#  'CCDC77': 657,
#  'CCDC80': 658,
#  'CCDC83': 659,
#  'CCDC85A': 660,
#  'CCDC85B': 661,
#  'CCDC85C': 662,
#  'CCDC88A': 663,
#  'CCDC9': 664,
#  'CCDC92B': 665,
#  'CCK': 666,
#  'CCL2': 667,
#  'CCL20': 668,
#  'CCL26': 669,
#  'CCM2L': 670,
#  'CCN1': 671,
#  'CCN2': 672,
#  'CCN3': 673,
#  'CCN5': 674,
#  'CCNA2': 675,
#  'CCNB1': 676,
#  'CCNB1IP1': 677,
#  'CCNB2': 678,
#  'CCND1': 679,
#  'CCND3': 680,
#  'CCNE1': 681,
#  'CCNE2': 682,
#  'CCNF': 683,
#  'CCNG1': 684,
#  'CCNYL1': 685,
#  'CCPG1': 686,
#  'CCSER1': 687,
#  'CCT2': 688,
#  'CCT4': 689,
#  'CCT5': 690,
#  'CCT6A': 691,
#  'CCT7': 692,
#  'CD109': 693,
#  'CD14': 694,
#  'CD151': 695,
#  'CD1D': 696,
#  'CD200R1': 697,
#  'CD22': 698,
#  'CD24': 699,
#  'CD247': 700,
#  'CD274': 701,
#  'CD320': 702,
#  'CD33': 703,
#  'CD36': 704,
#  'CD38': 705,
#  'CD40': 706,
#  'CD44': 707,
#  'CD46': 708,
#  'CD55': 709,
#  'CD59': 710,
#  'CD6': 711,
#  'CD63': 712,
#  'CD68': 713,
#  'CD70': 714,
#  'CD72': 715,
#  'CD81': 716,
#  'CD82': 717,
#  'CD8A': 718,
#  'CD9': 719,
#  'CD96': 720,
#  'CDA': 721,
#  'CDC14A': 722,
#  'CDC14B': 723,
#  'CDC20': 724,
#  'CDC25B': 725,
#  'CDC25C': 726,
#  'CDC27': 727,
#  'CDC37L1': 728,
#  'CDC42BPA': 729,
#  'CDC42EP3': 730,
#  'CDC45': 731,
#  'CDC6': 732,
#  'CDCA2': 733,
#  'CDCA3': 734,
#  'CDCA4': 735,
#  'CDCA5': 736,
#  'CDCA7L': 737,
#  'CDCA8': 738,
#  'CDCP1': 739,
#  'CDH1': 740,
#  'CDH10': 741,
#  'CDH11': 742,
#  'CDH16': 743,
#  'CDH17': 744,
#  'CDH2': 745,
#  'CDH4': 746,
#  'CDH6': 747,
#  'CDH7': 748,
#  'CDK1': 749,
#  'CDK14': 750,
#  'CDK18': 751,
#  'CDK19': 752,
#  'CDK2': 753,
#  'CDK2AP1': 754,
#  'CDK5RAP2': 755,
#  'CDK6': 756,
#  'CDKL2': 757,
#  'CDKN1A': 758,
#  'CDKN1B': 759,
#  'CDKN2C': 760,
#  'CDKN2D': 761,
#  'CDKN3': 762,
#  'CDT1': 763,
#  'CEACAM1': 764,
#  'CEACAM5': 765,
#  'CEACAM6': 766,
#  'CEACAM7': 767,
#  'CEBPA': 768,
#  'CEBPB': 769,
#  'CEBPD': 770,
#  'CECR2': 771,
#  'CELSR2': 772,
#  'CEMIP': 773,
#  'CEMIP2': 774,
#  'CENATAC': 775,
#  'CEND1': 776,
#  'CENPA': 777,
#  'CENPB': 778,
#  'CENPC': 779,
#  'CENPE': 780,
#  'CENPF': 781,
#  'CENPH': 782,
#  'CENPI': 783,
#  'CENPJ': 784,
#  'CENPK': 785,
#  'CENPL': 786,
#  'CENPN': 787,
#  'CENPO': 788,
#  'CENPP': 789,
#  'CENPU': 790,
#  'CENPW': 791,
#  'CENPX': 792,
#  'CEP112': 793,
#  'CEP126': 794,
#  'CEP128': 795,
#  'CEP131': 796,
#  'CEP15': 797,
#  'CEP152': 798,
#  'CEP250': 799,
#  'CEP55': 800,
#  'CEP70': 801,
#  'CEP72': 802,
#  'CEP85L': 803,
#  'CEP89': 804,
#  'CERS3': 805,
#  'CERT1': 806,
#  'CES1': 807,
#  'CETN2': 808,
#  'CFAP44': 809,
#  'CFAP47': 810,
#  'CFAP68': 811,
#  'CFAP73': 812,
#  'CFAP74': 813,
#  'CFAP95': 814,
#  'CFAP96': 815,
#  'CFB': 816,
#  'CFD': 817,
#  'CFH': 818,
#  'CFHR1': 819,
#  'CFI': 820,
#  'CFL1': 821,
#  'CFL2': 822,
#  'CFLAR': 823,
#  'CGB5': 824,
#  'CGB7': 825,
#  'CGB8': 826,
#  'CGNL1': 827,
#  'CHAC1': 828,
#  'CHAF1A': 829,
#  'CHCHD1': 830,
#  'CHCHD10': 831,
#  'CHCHD2': 832,
#  'CHCHD7': 833,
#  'CHD2': 834,
#  'CHD3': 835,
#  'CHD5': 836,
#  'CHD6': 837,
#  'CHD7': 838,
#  'CHD9': 839,
#  'CHGA': 840,
#  'CHGB': 841,
#  'CHIC2': 842,
#  'CHL1': 843,
#  'CHMP1B': 844,
#  'CHMP2A': 845,
#  'CHMP2B': 846,
#  'CHMP3': 847,
#  'CHMP4B': 848,
#  'CHMP4C': 849,
#  'CHMP5': 850,
#  'CHN2': 851,
#  'CHPF': 852,
#  'CHPF2': 853,
#  'CHRM3': 854,
#  'CHRNA10': 855,
#  'CHRNB4': 856,
#  'CHST11': 857,
#  'CHST14': 858,
#  'CHST9': 859,
#  'CHSY3': 860,
#  'CIAO2A': 861,
#  'CIAO2B': 862,
#  'CIB1': 863,
#  'CIC': 864,
#  'CIDEC': 865,
#  'CIMAP1C': 866,
#  'CIP2A': 867,
#  'CIRBP': 868,
#  'CISD1': 869,
#  'CIT': 870,
#  'CITED2': 871,
#  'CITED4': 872,
#  'CKAP2': 873,
#  'CKAP2L': 874,
#  'CKAP4': 875,
#  'CKAP5': 876,
#  'CKB': 877,
#  'CKS1B': 878,
#  'CKS2': 879,
#  'CLCF1': 880,
#  'CLDN1': 881,
#  'CLDN2': 882,
#  'CLDN3': 883,
#  'CLDN4': 884,
#  'CLDN6': 885,
#  'CLDN7': 886,
#  'CLEC19A': 887,
#  'CLEC2A': 888,
#  'CLEC2B': 889,
#  'CLIC1': 890,
#  'CLIC3': 891,
#  'CLIC4': 892,
#  'CLIP2': 893,
#  'CLMN': 894,
#  'CLMP': 895,
#  'CLN8': 896,
#  'CLNK': 897,
#  'CLPTM1L': 898,
#  'CLSPN': 899,
#  'CLSTN1': 900,
#  'CLSTN2': 901,
#  'CLTA': 902,
#  'CLTB': 903,
#  'CLTC': 904,
#  'CLTCL1': 905,
#  'CLTRN': 906,
#  'CLU': 907,
#  'CLUH': 908,
#  'CLVS1': 909,
#  'CMBL': 910,
#  'CMC1': 911,
#  'CMIP': 912,
#  'CMKLR2': 913,
#  'CMTM3': 914,
#  'CMTM6': 915,
#  'CMYA5': 916,
#  'CNBD1': 917,
#  'CNBP': 918,
#  'CNGB1': 919,
#  'CNKSR2': 920,
#  'CNN1': 921,
#  'CNN2': 922,
#  'CNN3': 923,
#  'CNR1': 924,
#  'CNTN1': 925,
#  'CNTNAP3': 926,
#  'CNTNAP3B': 927,
#  'CNTNAP3C': 928,
#  'CNTNAP5': 929,
#  'CNTRL': 930,
#  'COA3': 931,
#  'COA4': 932,
#  'COA5': 933,
#  'COBL': 934,
#  'COCH': 935,
#  'COG6': 936,
#  'COL11A1': 937,
#  'COL12A1': 938,
#  'COL18A1': 939,
#  'COL1A1': 940,
#  'COL21A1': 941,
#  'COL22A1': 942,
#  'COL26A1': 943,
#  'COL27A1': 944,
#  'COL28A1': 945,
#  'COL4A1': 946,
#  'COL4A2': 947,
#  'COL4A3': 948,
#  'COL4A4': 949,
#  'COL4A5': 950,
#  'COL4A6': 951,
#  'COL5A1': 952,
#  'COL5A2': 953,
#  'COL5A3': 954,
#  'COL6A1': 955,
#  'COL6A2': 956,
#  'COL7A1': 957,
#  'COL8A1': 958,
#  'COMMD2': 959,
#  'COMMD6': 960,
#  'COMMD9': 961,
#  'COPA': 962,
#  'COPB1': 963,
#  'COPB2': 964,
#  'COPG1': 965,
#  'COPZ1': 966,
#  'COQ8B': 967,
#  'CORO1B': 968,
#  'CORO1C': 969,
#  'CORO2A': 970,
#  'CORO6': 971,
#  'COTL1': 972,
#  'COX17': 973,
#  'COX20': 974,
#  'COX4I1': 975,
#  'COX5A': 976,
#  'COX5B': 977,
#  'COX6B1': 978,
#  'COX6C': 979,
#  'COX7A2': 980,
#  'COX7B': 981,
#  'COX7C': 982,
#  'COX8A': 983,
#  'CP': 984,
#  'CPA4': 985,
#  'CPA6': 986,
#  'CPE': 987,
#  'CPEB2': 988,
#  'CPEB3': 989,
#  'CPEB4': 990,
#  'CPLANE1': 991,
#  'CPLX2': 992,
#  'CPM': 993,
#  'CPN1': 994,
#  'CPNE4': 995,
#  'CPNE7': 996,
#  'CPNE9': 997,
#  'CPPED1': 998,
#  'CPS1': 999,
#  ...}

# %%
ordered_idx = [gene_to_idx[g] for g in gene_columns]
adata_ctrl = adata_ctrl[:, ordered_idx].copy()

# %%
sc.pp.normalize_total(adata_ctrl, target_sum=1e4, inplace=True)

# %%
X = adata_ctrl.X

# %%
sparse.issparse(X)
# Out:
# True

# %%
X = X.tocsr(copy=True)
X.data = np.log2(X.data + 1.0).astype(np.float32)

# %%
svd = TruncatedSVD(n_components=EMBED_DIM, random_state=SEED)
svd.fit(X)  # X: (n_cells, 5127)
# Out:
# TruncatedSVD(n_components=128, random_state=6)

# %%
svd.components_.shape   # shape = (k, genes)
# Out:
# (128, 5127)

# %%
import matplotlib.pyplot as plt
import numpy as np

evr = svd.explained_variance_ratio_

plt.plot(np.cumsum(evr))
plt.xlabel("Components")
plt.ylabel("Cumulative explained variance")
plt.title("SVD cumulative explained variance")
plt.show()

# %% [markdown]
# High dimensional and messy. Using 128 TruncatedSVD components captures about 37% of the total variance.

# %%
Z = svd.transform(X)
plt.scatter(Z[:,0], Z[:,1], s=5, alpha=0.5)
plt.xlabel("SVD1")
plt.ylabel("SVD2")
plt.title("Cells in SVD space")
plt.show()

# %% [markdown]
# Pretty big outlier in the bottom left corner.

# %%
Z = svd.transform(X)
obs = adata_ctrl.obs

import numpy as np
print("corr(SVD1, nCount_RNA):", np.corrcoef(Z[:,0], obs["nCount_RNA"].values)[0,1])
print("corr(SVD1, percent.mt):", np.corrcoef(Z[:,0], obs["percent.mt"].values)[0,1])
# Out:
# corr(SVD1, nCount_RNA): 0.624054295601635
# corr(SVD1, percent.mt): -0.2631010184372857

# %%
gene_emb = svd.components_.T   # (genes × k)
G = gene_emb

plt.scatter(G[:,0], G[:,1], s=5, alpha=0.5)
plt.xlabel("Gene SVD dim 1")
plt.ylabel("Gene SVD dim 2")
plt.title("Gene embeddings (SVD)")
plt.show()

# %%
comp = svd.components_[0]   # first component weights
idx = np.argsort(np.abs(comp))[-30:]

plt.barh(range(30), comp[idx])
plt.yticks(range(30), np.array(gene_columns)[idx])
plt.title("Top genes in SVD component 1")
plt.show()

# %%
Z = svd.transform(X)

plt.scatter(Z[:,0], Z[:,1], c=adata_ctrl.obs["nCount_RNA"], s=6)
plt.colorbar(label="nCount_RNA")
plt.title("Cells in SVD space colored by nCount_RNA")
plt.show()

plt.scatter(Z[:,0], Z[:,1], c=adata_ctrl.obs["percent.mt"], s=6)
plt.colorbar(label="percent.mt")
plt.title("Cells in SVD space colored by percent.mt")
plt.show()

# %%
gene_emb = svd.components_.T.astype(np.float32)
gene2emb = {g: gene_emb[i] for i, g in enumerate(gene_columns)}
emb_fallback = gene_emb.mean(axis=0)

# %%
out_pca = PCA(n_components=min(OUT_PCA_K, n_train - 1), random_state=SEED)
C_train = out_pca.fit_transform(D_train)  # (n_train, K)
K = C_train.shape[1]
print(f"Output PCA components used: K={K}")
# Out:
# Output PCA components used: K=64

# %%
X_feat = np.vstack([gene2emb.get(g, emb_fallback) for g in train_genes]).astype(np.float32)
reg = Ridge(alpha=RIDGE_ALPHA, random_state=SEED)
reg.fit(X_feat, C_train)
# Out:
# Ridge(random_state=6)

# %%
def soft_threshold(x: np.ndarray, t: float) -> np.ndarray:
    # elementwise: sign(x) * max(|x| - t, 0)
    return np.sign(x) * np.maximum(np.abs(x) - t, 0.0)

def predict_delta_for_gene(gene_symbol: str, scale: float = 1.0, thresh: float = 0.0) -> np.ndarray:
    e = gene2emb.get(gene_symbol, emb_fallback)[None, :]
    c_hat = reg.predict(e)  # (1, K)
    d_hat = out_pca.inverse_transform(c_hat).astype(np.float32)[0]  # (5127,)
    d_hat = (scale * d_hat).astype(np.float32)
    if thresh > 0:
        d_hat = soft_threshold(d_hat, thresh).astype(np.float32)
    return d_hat

# %%
rows = []
n_fallbacks = 0
for i in range(1, 121):
    pert_id = f"pert_{i}"
    if pert_id in val_map:
        gene = val_map[pert_id]
        delta = predict_delta_for_gene(gene, scale=1.0, thresh=0.0)
    else:
        n_fallbacks += 1
        delta = delta_baseline.astype(np.float32)

    row = {"pert_id": pert_id}
    row.update({g: float(delta[j]) for j, g in enumerate(gene_columns)})
    rows.append(row)

sub = pd.DataFrame(rows, columns=["pert_id"] + gene_columns)
sub.to_csv("baseline.csv", index=False)
print("created baseline.csv")
sub.head(), n_fallbacks
# Out:
# created baseline.csv
# (  pert_id      A1BG      A1CF     AADAC      AAK1     AARS1      AASS  \
#  0  pert_1  0.014166  0.001061 -0.002978 -0.001056 -0.005681  0.000045
#  1  pert_2  0.013828  0.000822 -0.002350 -0.001730 -0.007126 -0.000151
#  2  pert_3  0.009746  0.001111 -0.003481 -0.001067 -0.007852 -0.000027
#  3  pert_4  0.012778  0.000747 -0.002920 -0.000790 -0.007361  0.000107
#  4  pert_5  0.012192  0.001059 -0.002939 -0.001362 -0.005588 -0.000085
#
#        ABCA1    ABCA12     ABCA5  ...       ZP3      ZPBP    ZRANB3   ZSCAN18  \
#  0 -0.001503 -0.000604  0.011331  ...  0.027852 -0.000225  0.000610  0.002354
#  1 -0.001874 -0.000527  0.010332  ...  0.027776 -0.000246  0.002705  0.002261
#  2 -0.002810 -0.000317  0.011430  ...  0.026186 -0.000289  0.001514  0.002468
#  3 -0.002746 -0.000448  0.010827  ...  0.026919 -0.000163 -0.000425  0.002534
#  4 -0.000392 -0.000043  0.011048  ...  0.026556 -0.000255  0.001970  0.002284
#
#      ZSCAN31    ZSWIM5    ZSWIM6    ZSWIM7     ZWINT       ZYX
#  0  0.008081  0.011367 -0.018974 -0.021198 -0.017119 -0.008021
#  1  0.007885  0.012390 -0.016629 -0.022621 -0.014920 -0.010160
#  2  0.007201  0.012533 -0.018011 -0.025752 -0.015318 -0.006198
#  3  0.007489  0.010560 -0.019321 -0.019347 -0.018358 -0.008309
#  4  0.007119  0.012437 -0.018609 -0.022585 -0.014221 -0.007817
#
#  [5 rows x 5128 columns],
#  60)

# %% [markdown]
# Achieved a score of 0.05213 on public leaderboard. Metric is some weird Weighted Mean Absolute Error Ratio and Weighted Cosine Similarity. There are 60 fallbacks which is a problem.

# %%
print("Train genes:", len(train_genes))
print("Train genes missing from gene_columns:", len(missing_train))
print("Missing list:", missing_train)
# Out:
# Train genes: 80
# Train genes missing from gene_columns: 8
# Missing list: ['BRD4', 'CHD4', 'DNAJA3', 'INO80', 'KAT8', 'KDM4A', 'PMEL', 'SETD1A']

# %% [markdown]
# 8 perturbation genes have no embeddings. These missing genes do exist in the h5ad. They're just not in the output gene set. So I need to add embeddings for all perturbation genes, not just output genes.

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge

from myllia_metric import myllia_score


def cv_eval_ridge_pca(
    E: np.ndarray,          # (N, d) gene embeddings for the N training perturbation genes
    D: np.ndarray,          # (N, G) true delta expression for those genes
    *,
    out_pca_k: int = 64,
    ridge_alpha: float = 1.0,
    n_splits: int = 5,
    seed: int = 6,
):
    """
    Cross-validate Ridge(E -> PCA(D)) and report Myllia metric components per fold.
    Critical detail: PCA must be fit ONLY on the fold training set (no leakage).
    """
    E = np.asarray(E, dtype=np.float32)
    D = np.asarray(D, dtype=np.float32)

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=seed)

    fold_rows = []
    for fold, (tr_idx, va_idx) in enumerate(kf.split(E), start=1):
        E_tr, E_va = E[tr_idx], E[va_idx]
        D_tr, D_va = D[tr_idx], D[va_idx]

        k = min(out_pca_k, D_tr.shape[0] - 1)
        if k < 1:
            raise ValueError("Fold too small for PCA. Reduce n_splits or out_pca_k.")

        pca = PCA(n_components=k, random_state=seed)
        C_tr = pca.fit_transform(D_tr)

        reg = Ridge(alpha=ridge_alpha, random_state=seed)
        reg.fit(E_tr, C_tr)

        C_hat = reg.predict(E_va)
        D_hat = pca.inverse_transform(C_hat).astype(np.float32)

        m = myllia_score(D_va, D_hat)

        fold_rows.append({
            "fold": fold,
            "score": m.score,
            "wcos": m.wcos,
            "pred_wmae": m.pred_wmae,
            "base_wmae": m.base_wmae,
            "wmae_ratio": m.wmae_ratio,
            "mean_term": m.mean_term,
            "sum_terms": m.sum_terms,
            "n_train": int(len(tr_idx)),
            "n_val": int(len(va_idx)),
            "pca_k": int(k),
        })

    def _mean_std(key):
        vals = np.array([r[key] for r in fold_rows], dtype=np.float32)
        return float(vals.mean()), float(vals.std(ddof=1)) if len(vals) > 1 else 0.0

    summary = {k: _mean_std(k) for k in ["score", "wcos", "pred_wmae", "wmae_ratio", "mean_term"]}
    return fold_rows, summary

# %%
def norm_gene(g):
    return str(g).strip().upper()

# Normalize embedding dict keys once
gene2embN = {norm_gene(k): v for k, v in gene2emb.items()}
train_genesN = [norm_gene(g) for g in train_genes]

missing = sorted({g for g in train_genesN if g not in gene2embN})
print(f"Missing embeddings: {len(missing)} / {len(train_genesN)}")
print("First 30 missing:", missing[:30])
# Out:
# Missing embeddings: 8 / 80
# First 30 missing: ['BRD4', 'CHD4', 'DNAJA3', 'INO80', 'KAT8', 'KDM4A', 'PMEL', 'SETD1A']

# %%
keep_idx = [i for i, g in enumerate(train_genesN) if g in gene2embN]
drop_idx = [i for i, g in enumerate(train_genesN) if g not in gene2embN]

print(f"Keeping {len(keep_idx)} genes, dropping {len(drop_idx)} genes due to missing embeddings.")

E = np.vstack([gene2embN[train_genesN[i]] for i in keep_idx]).astype(np.float32)
D = D_train[keep_idx].astype(np.float32)   # critical: keep rows aligned
# Out:
# Keeping 72 genes, dropping 8 genes due to missing embeddings.

# %%
folds, summary = cv_eval_ridge_pca(
    E, D,
    out_pca_k=OUT_PCA_K,
    ridge_alpha=RIDGE_ALPHA,
    n_splits=5,
    seed=SEED,
)

print("Per-fold:")
for r in folds:
    print(r)

print("\nSummary (mean, std):")
for k, (mu, sd) in summary.items():
    print(f"{k:10s} = {mu:+.5f} ± {sd:.5f}")
# Out:
# Per-fold:
# {'fold': 1, 'score': 0.07718589089840133, 'wcos': 0.4320843517780304, 'pred_wmae': 0.08452610671520233, 'base_wmae': 0.0966968759894371, 'wmae_ratio': 0.860573410987854, 'mean_term': 0.17863616347312927, 'sum_terms': 2.6795425415039062, 'n_train': 57, 'n_val': 15, 'pca_k': 56}
# {'fold': 2, 'score': 0.04316650686685097, 'wcos': 0.34541022777557373, 'pred_wmae': 0.08689386397600174, 'base_wmae': 0.09710831195116043, 'wmae_ratio': 0.8898285031318665, 'mean_term': 0.12497171014547348, 'sum_terms': 1.8745756149291992, 'n_train': 57, 'n_val': 15, 'pca_k': 56}
# {'fold': 3, 'score': 0.040544977324363796, 'wcos': 0.35044416785240173, 'pred_wmae': 0.08101332932710648, 'base_wmae': 0.0911138728260994, 'wmae_ratio': 0.8866974115371704, 'mean_term': 0.11569596827030182, 'sum_terms': 1.6197435855865479, 'n_train': 58, 'n_val': 14, 'pca_k': 57}
# {'fold': 4, 'score': 0.08008042403777704, 'wcos': 0.43752509355545044, 'pred_wmae': 0.07673352211713791, 'base_wmae': 0.08780796825885773, 'wmae_ratio': 0.8604769110679626, 'mean_term': 0.18303047120571136, 'sum_terms': 2.5624265670776367, 'n_train': 58, 'n_val': 14, 'pca_k': 57}
# {'fold': 5, 'score': 0.06644331136622261, 'wcos': 0.4168952405452728, 'pred_wmae': 0.08136887103319168, 'base_wmae': 0.09245260059833527, 'wmae_ratio': 0.8678017258644104, 'mean_term': 0.15937651693820953, 'sum_terms': 2.231271266937256, 'n_train': 58, 'n_val': 14, 'pca_k': 57}
#
# Summary (mean, std):
# score      = +0.06148 ± 0.01865
# wcos       = +0.39647 ± 0.04499
# pred_wmae  = +0.08211 ± 0.00385
# wmae_ratio = +0.87308 ± 0.01422
# mean_term  = +0.15234 ± 0.03072
