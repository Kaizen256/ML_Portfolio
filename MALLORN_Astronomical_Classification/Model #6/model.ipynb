# %% [markdown]
# Will comment this one later.

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score
from sklearn.metrics import average_precision_score
from sklearn.model_selection import StratifiedGroupKFold
from xgboost import XGBClassifier
from extinction import fitzpatrick99
import lightgbm as lgb
from lightgbm import LGBMClassifier
import optuna
from scipy.optimize import curve_fit
import xgboost as xgb
from pathlib import Path

FILTERS = ["u", "g", "r", "i", "z", "y"]

EFF_WL_AA = {
    "u": 3641.0,
    "g": 4704.0,
    "r": 6155.0,
    "i": 7504.0,
    "z": 8695.0,
    "y": 10056.0,
}

R_V = 3.1
PRE_BASE_FRAC = 0.20
MIN_BAND_POINTS = 5
PEAK_SIGMA_K = 3.0
REBRIGHT_FRAC = 0.30
EPS = 1e-8

SEASON_GAP_DAYS = 90.0

SF_LAGS = [5.0, 10.0, 20.0, 50.0, 100.0]

# %%
def safe_float(x, default=np.nan):
    try:
        if x is None:
            return default
        x = float(x)
        if np.isnan(x):
            return default
        return x
    except Exception:
        return default


def trapz_safe(y, x):
    if hasattr(np, "trapezoid"):
        return float(np.trapezoid(y, x))
    y = np.asarray(y)
    x = np.asarray(x)
    if len(x) < 2:
        return np.nan
    return float(np.sum((x[1:] - x[:-1]) * (y[1:] + y[:-1]) * 0.5))


def median_abs_dev(x):
    x = np.asarray(x)
    if len(x) == 0:
        return np.nan
    med = np.median(x)
    return float(np.median(np.abs(x - med)))


def iqr(x):
    x = np.asarray(x)
    if len(x) < 2:
        return np.nan
    q75, q25 = np.percentile(x, [75, 25])
    return float(q75 - q25)


def skewness(x):
    x = np.asarray(x)
    n = len(x)
    if n < 3:
        return np.nan
    mu = np.mean(x)
    s = np.std(x)
    if s < 1e-12:
        return 0.0
    m3 = np.mean((x - mu) ** 3)
    return float(m3 / (s ** 3))


def kurtosis_excess(x):
    x = np.asarray(x)
    n = len(x)
    if n < 4:
        return np.nan
    mu = np.mean(x)
    s = np.std(x)
    if s < 1e-12:
        return 0.0
    m4 = np.mean((x - mu) ** 4)
    return float(m4 / (s ** 4) - 3.0)


def von_neumann_eta(x):
    x = np.asarray(x)
    n = len(x)
    if n < 3:
        return np.nan
    v = np.var(x)
    if v < 1e-12:
        return 0.0
    dif = np.diff(x)
    return float(np.mean(dif ** 2) / v)


def max_slope(t, f):
    t = np.asarray(t)
    f = np.asarray(f)
    if len(t) < 3:
        return np.nan
    dt = np.diff(t)
    df = np.diff(f)
    good = dt > 0
    if not np.any(good):
        return np.nan
    slopes = df[good] / dt[good]
    return float(np.max(np.abs(slopes)))


def median_abs_slope(t, f):
    t = np.asarray(t)
    f = np.asarray(f)
    if len(t) < 3:
        return np.nan
    dt = np.diff(t)
    df = np.diff(f)
    good = dt > 0
    if not np.any(good):
        return np.nan
    slopes = df[good] / dt[good]
    return float(np.median(np.abs(slopes)))


def linear_slope(t, f):
    t = np.asarray(t)
    f = np.asarray(f)
    if len(t) < 3:
        return np.nan
    try:
        a, b = np.polyfit(t, f, 1)
        return float(a)
    except Exception:
        return np.nan


def chi2_to_constant(f, ferr):
    f = np.asarray(f)
    ferr = np.asarray(ferr)
    n = len(f)
    if n < 3:
        return np.nan
    mu = np.median(f)
    denom = (ferr + EPS) ** 2
    chi2 = np.sum((f - mu) ** 2 / denom)
    dof = max(1, n - 1)
    return float(chi2 / dof)


def interp_flux_at_time(tb, fb, t0):
    tb = np.asarray(tb)
    fb = np.asarray(fb)
    if len(tb) < 2:
        return np.nan
    if (t0 < tb.min()) or (t0 > tb.max()):
        return np.nan
    return float(np.interp(t0, tb, fb))


def interp_err_at_time(tb, eb, t0):
    tb = np.asarray(tb)
    eb = np.asarray(eb)
    if len(tb) < 2:
        return np.nan
    if (t0 < tb.min()) or (t0 > tb.max()):
        return np.nan
    return float(np.interp(t0, tb, eb))


def fractional_variability(f, ferr):
    f = np.asarray(f, float)
    ferr = np.asarray(ferr, float)
    n = len(f)
    if n < 3:
        return np.nan
    mu = np.mean(f)
    if np.abs(mu) < 1e-8:
        return np.nan
    s2 = np.var(f, ddof=1)
    mean_err2 = np.mean(ferr ** 2)
    excess = max(0.0, s2 - mean_err2)
    return float(np.sqrt(excess) / np.abs(mu))


def stetson_J_consecutive(t, f, ferr):
    t = np.asarray(t)
    f = np.asarray(f)
    ferr = np.asarray(ferr)
    n = len(t)
    if n < 4:
        return np.nan
    mu = np.mean(f)
    scale = np.sqrt(n / max(1, n - 1))
    delta = scale * (f - mu) / (ferr + EPS)
    vals = []
    for i in range(n - 1):
        P = delta[i] * delta[i + 1]
        vals.append(np.sign(P) * np.sqrt(np.abs(P)))
    return float(np.mean(vals))


def pre_peak_baseline(tb, fb, eb, frac=PRE_BASE_FRAC):
    tb = np.asarray(tb)
    fb = np.asarray(fb)
    eb = np.asarray(eb)
    n = len(tb)
    if n < 3:
        return np.nan, np.nan, np.nan
    k = max(2, int(np.ceil(frac * n)))
    k = min(k, n)
    base = float(np.median(fb[:k]))
    mad_pre = median_abs_dev(fb[:k])
    mederr_pre = float(np.median(eb[:k])) if k > 0 else np.nan
    return base, mad_pre, mederr_pre


def count_significant_peaks(tb, fb, eb, baseline_pre, k_sigma=PEAK_SIGMA_K):
    tb = np.asarray(tb)
    fb = np.asarray(fb)
    eb = np.asarray(eb)
    n = len(fb)
    if n < 5:
        return 0
    mederr = float(np.median(eb)) if np.isfinite(np.median(eb)) else 0.0
    thresh = baseline_pre + k_sigma * mederr
    peaks = 0
    for i in range(1, n - 1):
        if (fb[i] > fb[i - 1]) and (fb[i] > fb[i + 1]) and (fb[i] > thresh):
            peaks += 1
    return int(peaks)


def postpeak_monotonicity(tb, fb, pidx):
    tb = np.asarray(tb)
    fb = np.asarray(fb)
    if pidx is None or pidx >= len(fb) - 2:
        return np.nan
    t2 = tb[pidx:]
    f2 = fb[pidx:]
    if len(f2) < 3:
        return np.nan
    dt = np.diff(t2)
    df = np.diff(f2)
    good = dt > 0
    if not np.any(good):
        return np.nan
    frac_neg = float(np.mean((df[good] / dt[good]) < 0))
    return frac_neg


def count_rebrighten(tb, fb, baseline_pre, amp, pidx, frac=REBRIGHT_FRAC):
    if pidx is None or pidx >= len(fb) - 2:
        return 0
    level = baseline_pre + frac * amp
    post = fb[pidx:]
    if len(post) < 3:
        return 0
    above = post > level
    crossings = np.sum((~above[:-1]) & (above[1:]))
    return int(crossings)


def fall_time_to_level(tb, fb, baseline_pre, amp, pidx, frac):
    if amp <= 0 or pidx is None:
        return np.nan
    level = baseline_pre + frac * amp
    t_dec = tb[pidx:]
    f_dec = fb[pidx:]
    if len(f_dec) < 2:
        return np.nan
    idx = np.where(f_dec <= level)[0]
    if len(idx) == 0:
        return np.nan
    return float(t_dec[idx[0]] - t_dec[0])


def rise_time_to_level(tb, fb, baseline_pre, amp, pidx, frac):
    if amp <= 0 or pidx is None or pidx < 2:
        return np.nan
    level = baseline_pre + frac * amp
    t_pre = tb[:pidx + 1]
    f_pre = fb[:pidx + 1]
    idx = np.where(f_pre >= level)[0]
    if len(idx) == 0:
        return np.nan
    return float(t_pre[-1] - t_pre[idx[0]])


def decay_powerlaw_fit(tb, fb, baseline_pre, pidx, tmax=300.0):
    if pidx is None or pidx >= len(fb) - 3:
        return np.nan, np.nan, 0
    t0 = tb[pidx]
    t_dec = tb[pidx:]
    f_dec = fb[pidx:]
    dt = t_dec - t0
    m = (dt > 0.0) & (dt <= tmax)
    dt = dt[m]
    fd = f_dec[m] - baseline_pre
    m2 = fd > 0.0
    dt = dt[m2]
    fd = fd[m2]
    if len(dt) < 4:
        return np.nan, np.nan, int(len(dt))
    x = np.log(dt + EPS)
    y = np.log(fd + EPS)
    try:
        b, a = np.polyfit(x, y, 1)
    except Exception:
        return np.nan, np.nan, int(len(dt))
    yhat = a + b * x
    ss_res = float(np.sum((y - yhat) ** 2))
    ss_tot = float(np.sum((y - np.mean(y)) ** 2)) + EPS
    r2 = 1.0 - ss_res / ss_tot
    return float(b), float(r2), int(len(dt))


def signed_log1p(x):
    x = float(x)
    return float(np.sign(x) * np.log1p(np.abs(x)))


def deextinct_band(flux, flux_err, ebv, band, r_v=R_V):
    if ebv is None or (isinstance(ebv, float) and np.isnan(ebv)):
        return flux, flux_err
    A_V = float(ebv) * float(r_v)
    wave = np.array([EFF_WL_AA[band]], dtype=float)
    A_lambda = float(fitzpatrick99(wave, A_V, r_v=r_v, unit="aa")[0])
    fac = 10.0 ** (0.4 * A_lambda)
    return flux * fac, flux_err * fac


def deextinct_lightcurve(lc, ebv):
    flux = lc["Flux"].to_numpy().astype(float)
    ferr = lc["Flux_err"].to_numpy().astype(float)
    filt = lc["Filter"].to_numpy()
    flux_corr = flux.copy()
    ferr_corr = ferr.copy()
    for b in FILTERS:
        m = (filt == b)
        if not np.any(m):
            continue
        flux_corr[m], ferr_corr[m] = deextinct_band(flux_corr[m], ferr_corr[m], ebv, b)
    return flux_corr, ferr_corr


def band_corr(tt_a, ff_a, tt_b, ff_b, n_grid=30):
    tt_a = np.asarray(tt_a, float)
    ff_a = np.asarray(ff_a, float)
    tt_b = np.asarray(tt_b, float)
    ff_b = np.asarray(ff_b, float)

    if len(tt_a) < 3 or len(tt_b) < 3:
        return np.nan

    tmin = max(tt_a.min(), tt_b.min())
    tmax = min(tt_a.max(), tt_b.max())
    if (tmax - tmin) < 5.0:
        return np.nan

    grid = np.linspace(tmin, tmax, n_grid)
    fa = np.interp(grid, tt_a, ff_a)
    fb = np.interp(grid, tt_b, ff_b)

    sa = np.std(fa)
    sb = np.std(fb)
    if sa < 1e-12 or sb < 1e-12:
        return 0.0
    return float(np.corrcoef(fa, fb)[0, 1])

# %%
def seasonality_features(tb):
    tb = np.asarray(tb, float)
    if len(tb) < 2:
        return np.nan, np.nan, np.nan
    dt = np.diff(tb)
    breaks = np.where(dt > SEASON_GAP_DAYS)[0]
    seg_starts = [0] + (breaks + 1).tolist()
    seg_ends = breaks.tolist() + [len(tb) - 1]
    spans = []
    for s, e in zip(seg_starts, seg_ends):
        spans.append(tb[e] - tb[s])
    spans = np.asarray(spans, float)
    n_seasons = float(len(spans))
    return n_seasons, float(np.max(spans)), float(np.mean(spans))


def structure_function_lags(tb, fb, lags=SF_LAGS):
    tb = np.asarray(tb, float)
    fb = np.asarray(fb, float)
    n = len(tb)
    out = {}
    if n < 6:
        for lag in lags:
            out[f"sf_medabs_{int(lag)}"] = np.nan
            out[f"sf_n_{int(lag)}"] = 0.0
        return out

    for lag in lags:
        tol = max(2.0, 0.2 * lag)
        vals = []
        for i in range(n - 1):
            dt = tb[i + 1:] - tb[i]
            m = (dt >= (lag - tol)) & (dt <= (lag + tol))
            if np.any(m):
                dif = np.abs(fb[i + 1:][m] - fb[i])
                vals.extend(dif.tolist())
        if len(vals) == 0:
            out[f"sf_medabs_{int(lag)}"] = np.nan
            out[f"sf_n_{int(lag)}"] = 0.0
        else:
            out[f"sf_medabs_{int(lag)}"] = float(np.median(vals))
            out[f"sf_n_{int(lag)}"] = float(len(vals))
    return out


def peak_vs_wavelength_slope(tpeak_by_band, val_by_band, z=0.0):
    xs = []
    ys = []
    for b in FILTERS:
        v = val_by_band.get(b, np.nan)
        t = tpeak_by_band.get(b, np.nan)
        if np.isfinite(v):
            lam = float(EFF_WL_AA[b] / (1.0 + float(z)))
            xs.append(lam)
            ys.append(float(v))
    xs = np.asarray(xs, float)
    ys = np.asarray(ys, float)
    if len(xs) < 2:
        return np.nan, np.nan, np.nan
    try:
        slope, intercept = np.polyfit(xs, ys, 1)
        yhat = slope * xs + intercept
        ss_res = float(np.sum((ys - yhat) ** 2))
        ss_tot = float(np.sum((ys - np.mean(ys)) ** 2)) + EPS
        r2 = 1.0 - ss_res / ss_tot
        return float(slope), float(intercept), float(r2)
    except Exception:
        return np.nan, np.nan, np.nan


def sed_logflux_vs_loglambda_at_time(band_tb, band_fb, band_eb, t0, z=0.0):
    xs = []
    ys = []
    ws = []
    for b in FILTERS:
        tb = band_tb.get(b, None)
        fb = band_fb.get(b, None)
        eb = band_eb.get(b, None)
        if tb is None or fb is None or eb is None:
            continue
        f = interp_flux_at_time(tb, fb, t0)
        e = interp_err_at_time(tb, eb, t0)
        if not np.isfinite(f) or not np.isfinite(e):
            continue
        if f <= 0:
            continue
        lam_rest = float(EFF_WL_AA[b] / (1.0 + float(z)))
        xs.append(np.log(lam_rest + EPS))
        ys.append(np.log(f + EPS))
        ws.append(1.0 / ((e / (f + EPS)) ** 2 + EPS))  # weight by relative error
    if len(xs) < 2:
        return np.nan, np.nan, np.nan, float(len(xs))
    xs = np.asarray(xs, float)
    ys = np.asarray(ys, float)
    ws = np.asarray(ws, float)

    try:
        W = np.sum(ws)
        xbar = np.sum(ws * xs) / (W + EPS)
        ybar = np.sum(ws * ys) / (W + EPS)
        cov = np.sum(ws * (xs - xbar) * (ys - ybar))
        var = np.sum(ws * (xs - xbar) ** 2) + EPS
        slope = cov / var
        intercept = ybar - slope * xbar
        yhat = slope * xs + intercept
        ss_res = float(np.sum(ws * (ys - yhat) ** 2))
        ss_tot = float(np.sum(ws * (ys - ybar) ** 2)) + EPS
        r2 = 1.0 - ss_res / ss_tot
        return float(slope), float(intercept), float(r2), float(len(xs))
    except Exception:
        return np.nan, np.nan, np.nan, float(len(xs))

# %%
from scipy.optimize import curve_fit

EPS = 1e-8

def sigmoid(x):
    x = np.clip(x, -60.0, 60.0)
    return 1.0 / (1.0 + np.exp(-x))


def bazin_stable(t, A, t0, trise, tfall, B, eps=EPS):
    """
    Numerically stable Bazin-like function:
        f(t) = A * exp(-(t-t0)/tfall) * sigmoid((t-t0)/trise) + B
    """
    trise = np.maximum(trise, eps)
    tfall = np.maximum(tfall, eps)

    x = (t - t0) / trise
    exp_term = np.exp(np.clip(-(t - t0) / tfall, -60.0, 60.0))
    return A * exp_term * sigmoid(x) + B


def should_fit_bazin(tb, fb, eb, min_points=8, amp_sigma=3.0):
    """
    Gate: only fit when there is enough data and a detectable transient-like signal.
    """
    tb = np.asarray(tb, float)
    fb = np.asarray(fb, float)
    eb = np.asarray(eb, float)

    if len(tb) < min_points:
        return False

    mederr = float(np.median(eb)) if np.isfinite(np.median(eb)) else np.inf
    if not np.isfinite(mederr) or mederr <= 0:
        return False

    amp = float(np.percentile(fb, 95) - np.percentile(fb, 5))
    if not np.isfinite(amp) or amp < amp_sigma * mederr:
        return False

    if float(np.std(fb)) < 1e-10:
        return False

    return True


def fit_bazin(tb, fb, eb):
    """
    Returns (A, t0, trise, tfall, B, chi2_red) on success.
    Returns (nan...nan) on failure or if scipy missing / gate fails.
    """
    nan_out = (np.nan, np.nan, np.nan, np.nan, np.nan, np.nan)


    tb = np.asarray(tb, float)
    fb = np.asarray(fb, float)
    eb = np.asarray(eb, float)

    order = np.argsort(tb)
    t = tb[order]
    f = fb[order]
    e = eb[order]

    m = np.isfinite(t) & np.isfinite(f) & np.isfinite(e)
    t, f, e = t[m], f[m], e[m]
    if len(t) < 3:
        return nan_out

    e = np.maximum(e, 1e-6)

    if not should_fit_bazin(t, f, e, min_points=8, amp_sigma=3.0):
        return nan_out

    B0 = float(np.median(f))
    A0 = float(max(1e-6, np.percentile(f, 95) - B0))
    t0_0 = float(t[int(np.argmax(f))])
    tr0 = 20.0
    tf0 = 60.0
    p0 = [A0, t0_0, tr0, tf0, B0]

    tmin, tmax = float(t.min()), float(t.max())
    iqr = float(np.percentile(f, 75) - np.percentile(f, 25))
    amp = float(max(1e-6, np.percentile(f, 95) - np.percentile(f, 5)))

    lo = [0.0, tmin - 50.0, 0.5, 1.0, B0 - 5.0 * (iqr + 1e-6)]
    hi = [10.0 * amp, tmax + 50.0, 200.0, 600.0, B0 + 5.0 * (iqr + 1e-6)]

    try:
        popt, _ = curve_fit(
            bazin_stable, t, f,
            p0=p0,
            sigma=e,
            absolute_sigma=True,
            bounds=(lo, hi),
            maxfev=5000
        )

        fhat = bazin_stable(t, *popt)
        resid = (f - fhat) / e
        chi2 = float(np.sum(resid * resid))
        dof = max(1, len(t) - len(popt))
        chi2_red = chi2 / dof

        A, t0, trise, tfall, B = [float(x) for x in popt]
        return (A, t0, trise, tfall, B, float(chi2_red))

    except Exception:
        return nan_out

# %%
def extract_features_for_object(lc_raw, z, z_err, ebv):
    feats = {}
    lc = lc_raw.sort_values("Time (MJD)").reset_index(drop=True)

    t = lc["Time (MJD)"].to_numpy().astype(float)
    filt = lc["Filter"].to_numpy()

    if len(t) == 0:
        feats["n_obs"] = 0
        return feats

    z = safe_float(z, default=0.0)
    z_err = safe_float(z_err, default=0.0)
    ebv = safe_float(ebv, default=np.nan)

    t_rel = t - t.min()
    t_rest = t_rel / (1.0 + z)

    flux_raw = lc["Flux"].to_numpy().astype(float)
    err_raw = lc["Flux_err"].to_numpy().astype(float)
    flux_corr, err_corr = deextinct_lightcurve(lc, ebv)

    feats["n_obs"] = int(len(t))
    feats["total_time_obs"] = float(t_rel.max() - t_rel.min())
    feats["total_time_rest"] = float(t_rest.max() - t_rest.min())

    feats["flux_mean"] = float(np.mean(flux_corr))
    feats["flux_median"] = float(np.median(flux_corr))
    feats["flux_std"] = float(np.std(flux_corr))
    feats["flux_min"] = float(np.min(flux_corr))
    feats["flux_max"] = float(np.max(flux_corr))

    feats["flux_mad"] = median_abs_dev(flux_corr)
    feats["flux_iqr"] = iqr(flux_corr)
    feats["flux_skew"] = skewness(flux_corr)
    feats["flux_kurt_excess"] = kurtosis_excess(flux_corr)

    p5, p25, p75, p95 = np.percentile(flux_corr, [5, 25, 75, 95])
    feats["flux_p5"] = float(p5)
    feats["flux_p25"] = float(p25)
    feats["flux_p75"] = float(p75)
    feats["flux_p95"] = float(p95)
    feats["robust_amp_global"] = float(p95 - p5)

    feats["neg_flux_frac"] = float(np.mean(flux_corr < 0))

    snr = np.abs(flux_corr) / (err_corr + EPS)
    feats["snr_median"] = float(np.median(snr))
    feats["snr_max"] = float(np.max(snr))

    feats["flux_mean_raw"] = float(np.mean(flux_raw))
    feats["flux_std_raw"] = float(np.std(flux_raw))
    feats["snr_max_raw"] = float(np.max(np.abs(flux_raw) / (err_raw + EPS)))
    feats["fvar_raw"] = fractional_variability(flux_raw, err_raw)

    feats["flux_mean_deext_minus_raw"] = float(feats["flux_mean"] - feats["flux_mean_raw"])
    feats["snrmax_deext_minus_raw"] = float(feats["snr_max"] - feats["snr_max_raw"])

    if len(t_rel) >= 2:
        dt = np.diff(t_rel)
        feats["median_dt"] = float(np.median(dt))
        feats["max_gap"] = float(np.max(dt))
        feats["n_seasons_global"] = float(np.sum(dt > SEASON_GAP_DAYS) + 1)
        feats["gap_frac_gt90"] = float(np.mean(dt > SEASON_GAP_DAYS))
        feats["gap_frac_gt30"] = float(np.mean(dt > 30.0))
    else:
        feats["median_dt"] = np.nan
        feats["max_gap"] = np.nan
        feats["n_seasons_global"] = np.nan
        feats["gap_frac_gt90"] = np.nan
        feats["gap_frac_gt30"] = np.nan

    feats["eta_von_neumann"] = von_neumann_eta(flux_corr)
    feats["chi2_const_global"] = chi2_to_constant(flux_corr, err_corr)
    feats["stetsonJ_global_obs"] = stetson_J_consecutive(t_rel, flux_corr, err_corr)
    feats["stetsonJ_global_rest"] = stetson_J_consecutive(t_rest, flux_corr, err_corr)

    feats["max_slope_global_obs"] = max_slope(t_rel, flux_corr)
    feats["max_slope_global_rest"] = max_slope(t_rest, flux_corr)

    feats["med_abs_slope_global_obs"] = median_abs_slope(t_rel, flux_corr)
    feats["med_abs_slope_global_rest"] = median_abs_slope(t_rest, flux_corr)

    feats["slope_global_obs"] = linear_slope(t_rel, flux_corr)
    feats["slope_global_rest"] = linear_slope(t_rest, flux_corr)

    feats["fvar_global"] = fractional_variability(flux_corr, err_corr)

    feats["Z"] = float(z)
    feats["log1pZ"] = float(np.log1p(max(0.0, z)))
    feats["Z_err"] = float(max(0.0, z_err))
    feats["log1pZerr"] = float(np.log1p(max(0.0, feats["Z_err"])))
    feats["EBV"] = ebv

    feats["n_filters_present"] = 0
    feats["total_obs"] = 0

    band_tpeak_obs = {}
    band_tpeak_rest = {}
    band_peak_flux = {}

    band_tb_obs = {}
    band_tb_rest = {}
    band_fb = {}
    band_eb = {}

    for b in FILTERS:
        m = (filt == b)
        nb = int(np.sum(m))
        feats[f"n_{b}"] = nb
        feats["total_obs"] += nb

        keys = [
            f"amp_{b}",
            f"amp_pre_{b}",
            f"baseline_pre_{b}",
            f"robust_amp_{b}",
            f"tpeak_{b}_obs",
            f"tpeak_{b}_rest",
            f"width50_{b}_obs",
            f"width50_{b}_rest",
            f"width80_{b}_obs",
            f"width80_{b}_rest",
            f"auc_pos_{b}_obs",
            f"auc_pos_{b}_rest",
            f"snrmax_{b}",
            f"eta_{b}",
            f"chi2_const_{b}",
            f"slope_{b}_obs",
            f"slope_{b}_rest",
            f"maxslope_{b}_obs",
            f"maxslope_{b}_rest",
            f"stetsonJ_{b}_obs",
            f"stetsonJ_{b}_rest",
            f"p5_{b}",
            f"p25_{b}",
            f"p75_{b}",
            f"p95_{b}",
            f"mad_{b}",
            f"iqr_{b}",
            f"mad_over_std_{b}",
            f"fvar_{b}",
            f"t_fall50_{b}_obs",
            f"t_fall20_{b}_obs",
            f"t_fall50_{b}_rest",
            f"t_fall20_{b}_rest",
            f"t_rise50_{b}_obs",
            f"t_rise20_{b}_obs",
            f"t_rise50_{b}_rest",
            f"t_rise20_{b}_rest",
            f"asym50_{b}_obs",
            f"asym50_{b}_rest",
            f"sharp50_{b}_obs",
            f"sharp50_{b}_rest",
            f"peak_dominance_{b}",
            f"std_ratio_prepost_{b}",
            f"n_peaks_{b}",
            f"postpeak_monotone_frac_{b}",
            f"n_rebrighten_{b}",
            f"decay_pl_slope_{b}_obs",
            f"decay_pl_r2_{b}_obs",
            f"decay_pl_npts_{b}_obs",
            f"decay_pl_slope_{b}_rest",
            f"decay_pl_r2_{b}_rest",
            f"decay_pl_npts_{b}_rest",

            # seasonality and structure function per band
            f"n_seasons_{b}",
            f"season_maxspan_{b}",
            f"season_meanspan_{b}",
            f"sf_medabs_5_{b}",
            f"sf_n_5_{b}",
            f"sf_medabs_10_{b}",
            f"sf_n_10_{b}",
            f"sf_medabs_20_{b}",
            f"sf_n_20_{b}",
            f"sf_medabs_50_{b}",
            f"sf_n_50_{b}",
            f"sf_medabs_100_{b}",
            f"sf_n_100_{b}",

            # Bazin shape fit
            f"bazin_A_{b}",
            f"bazin_t0_{b}_obs",
            f"bazin_trise_{b}_obs",
            f"bazin_tfall_{b}_obs",
            f"bazin_B_{b}",
            f"bazin_chi2red_{b}_obs",
            f"bazin_trise_{b}_rest",
            f"bazin_tfall_{b}_rest",
        ]
        for k in keys:
            feats[k] = np.nan

        if nb == 0:
            continue

        feats["n_filters_present"] += 1

        tb_obs = t_rel[m]
        fb = flux_corr[m]
        eb = err_corr[m]

        order = np.argsort(tb_obs)
        tb_obs = tb_obs[order]
        fb = fb[order]
        eb = eb[order]
        tb_rest = tb_obs / (1.0 + z)

        band_tb_obs[b] = tb_obs
        band_tb_rest[b] = tb_rest
        band_fb[b] = fb
        band_eb[b] = eb

        ns, maxsp, meansp = seasonality_features(tb_obs)
        feats[f"n_seasons_{b}"] = ns
        feats[f"season_maxspan_{b}"] = maxsp
        feats[f"season_meanspan_{b}"] = meansp

        sf = structure_function_lags(tb_obs, fb, lags=SF_LAGS)
        for lag in SF_LAGS:
            feats[f"sf_medabs_{int(lag)}_{b}"] = sf.get(f"sf_medabs_{int(lag)}", np.nan)
            feats[f"sf_n_{int(lag)}_{b}"] = sf.get(f"sf_n_{int(lag)}", 0.0)

        p5b, p25b, p75b, p95b = np.percentile(fb, [5, 25, 75, 95])
        feats[f"p5_{b}"] = float(p5b)
        feats[f"p25_{b}"] = float(p25b)
        feats[f"p75_{b}"] = float(p75b)
        feats[f"p95_{b}"] = float(p95b)
        feats[f"robust_amp_{b}"] = float(p95b - p5b)

        feats[f"mad_{b}"] = median_abs_dev(fb)
        feats[f"iqr_{b}"] = iqr(fb)
        stdb = float(np.std(fb))
        feats[f"mad_over_std_{b}"] = float(feats[f"mad_{b}"] / (stdb + EPS))

        base_pre, mad_pre, mederr_pre = pre_peak_baseline(tb_obs, fb, eb, frac=PRE_BASE_FRAC)
        feats[f"baseline_pre_{b}"] = float(base_pre) if np.isfinite(base_pre) else np.nan

        pidx = int(np.argmax(fb))
        peak_flux = float(fb[pidx])
        tpeak_obs = float(tb_obs[pidx])
        tpeak_rest = float(tb_rest[pidx])

        amp_median = peak_flux - float(np.median(fb))
        amp_pre = peak_flux - base_pre if np.isfinite(base_pre) else np.nan

        feats[f"amp_{b}"] = float(amp_median)
        feats[f"amp_pre_{b}"] = float(amp_pre) if np.isfinite(amp_pre) else np.nan

        feats[f"tpeak_{b}_obs"] = tpeak_obs
        feats[f"tpeak_{b}_rest"] = tpeak_rest
        feats[f"snrmax_{b}"] = float(np.max(np.abs(fb) / (eb + EPS)))

        feats[f"eta_{b}"] = von_neumann_eta(fb)
        feats[f"chi2_const_{b}"] = chi2_to_constant(fb, eb)

        feats[f"slope_{b}_obs"] = linear_slope(tb_obs, fb)
        feats[f"slope_{b}_rest"] = linear_slope(tb_rest, fb)

        feats[f"maxslope_{b}_obs"] = max_slope(tb_obs, fb)
        feats[f"maxslope_{b}_rest"] = max_slope(tb_rest, fb)

        feats[f"stetsonJ_{b}_obs"] = stetson_J_consecutive(tb_obs, fb, eb)
        feats[f"stetsonJ_{b}_rest"] = stetson_J_consecutive(tb_rest, fb, eb)

        feats[f"fvar_{b}"] = fractional_variability(fb, eb)

        A, t0, trise, tfall, B, chi2 = fit_bazin(tb_obs, fb, eb)
        feats[f"bazin_A_{b}"] = A
        feats[f"bazin_t0_{b}_obs"] = t0
        feats[f"bazin_trise_{b}_obs"] = trise
        feats[f"bazin_tfall_{b}_obs"] = tfall
        feats[f"bazin_B_{b}"] = B
        feats[f"bazin_chi2red_{b}_obs"] = chi2

        feats[f"bazin_trise_{b}_rest"] = trise / (1.0 + z) if np.isfinite(trise) else np.nan
        feats[f"bazin_tfall_{b}_rest"] = tfall / (1.0 + z) if np.isfinite(tfall) else np.nan

        if np.isfinite(amp_pre) and amp_pre > 0:
            feats[f"peak_dominance_{b}"] = float(amp_pre / (mad_pre + EPS))

            pre_seg = fb[:max(2, pidx)]
            post_seg = fb[pidx:]
            std_pre = float(np.std(pre_seg)) if len(pre_seg) >= 2 else np.nan
            std_post = float(np.std(post_seg)) if len(post_seg) >= 2 else np.nan
            if np.isfinite(std_pre) and np.isfinite(std_post):
                feats[f"std_ratio_prepost_{b}"] = float(std_pre / (std_post + EPS))

            feats[f"postpeak_monotone_frac_{b}"] = float(postpeak_monotonicity(tb_obs, fb, pidx))
            feats[f"n_peaks_{b}"] = float(count_significant_peaks(tb_obs, fb, eb, base_pre, k_sigma=PEAK_SIGMA_K))
            feats[f"n_rebrighten_{b}"] = float(count_rebrighten(tb_obs, fb, base_pre, amp_pre, pidx, frac=REBRIGHT_FRAC))

            feats[f"t_fall50_{b}_obs"] = float(fall_time_to_level(tb_obs, fb, base_pre, amp_pre, pidx, frac=0.50))
            feats[f"t_fall20_{b}_obs"] = float(fall_time_to_level(tb_obs, fb, base_pre, amp_pre, pidx, frac=0.20))
            feats[f"t_fall50_{b}_rest"] = float(fall_time_to_level(tb_rest, fb, base_pre, amp_pre, pidx, frac=0.50))
            feats[f"t_fall20_{b}_rest"] = float(fall_time_to_level(tb_rest, fb, base_pre, amp_pre, pidx, frac=0.20))

            feats[f"t_rise50_{b}_obs"] = float(rise_time_to_level(tb_obs, fb, base_pre, amp_pre, pidx, frac=0.50))
            feats[f"t_rise20_{b}_obs"] = float(rise_time_to_level(tb_obs, fb, base_pre, amp_pre, pidx, frac=0.20))
            feats[f"t_rise50_{b}_rest"] = float(rise_time_to_level(tb_rest, fb, base_pre, amp_pre, pidx, frac=0.50))
            feats[f"t_rise20_{b}_rest"] = float(rise_time_to_level(tb_rest, fb, base_pre, amp_pre, pidx, frac=0.20))

            tr50o = feats[f"t_rise50_{b}_obs"]
            tf50o = feats[f"t_fall50_{b}_obs"]
            tr50r = feats[f"t_rise50_{b}_rest"]
            tf50r = feats[f"t_fall50_{b}_rest"]
            feats[f"asym50_{b}_obs"] = float(tf50o / (tr50o + EPS)) if np.isfinite(tf50o) and np.isfinite(tr50o) else np.nan
            feats[f"asym50_{b}_rest"] = float(tf50r / (tr50r + EPS)) if np.isfinite(tf50r) and np.isfinite(tr50r) else np.nan

            feats[f"auc_pos_{b}_obs"] = float(trapz_safe(np.maximum(fb - base_pre, 0.0), tb_obs))
            feats[f"auc_pos_{b}_rest"] = float(trapz_safe(np.maximum(fb - base_pre, 0.0), tb_rest))

            def width_at_level(tt, ff, base, amp, frac):
                if amp <= 0 or len(ff) < 3:
                    return np.nan
                level = base + frac * amp
                above = ff >= level
                if not np.any(above):
                    return np.nan
                idx = np.where(above)[0]
                return float(tt[idx[-1]] - tt[idx[0]])

            w50_obs = width_at_level(tb_obs, fb, base_pre, amp_pre, 0.50)
            w80_obs = width_at_level(tb_obs, fb, base_pre, amp_pre, 0.80)
            w50_rest = width_at_level(tb_rest, fb, base_pre, amp_pre, 0.50)
            w80_rest = width_at_level(tb_rest, fb, base_pre, amp_pre, 0.80)

            feats[f"width50_{b}_obs"] = w50_obs
            feats[f"width80_{b}_obs"] = w80_obs
            feats[f"width50_{b}_rest"] = w50_rest
            feats[f"width80_{b}_rest"] = w80_rest

            feats[f"sharp50_{b}_obs"] = float(amp_pre / (w50_obs + EPS)) if np.isfinite(w50_obs) else np.nan
            feats[f"sharp50_{b}_rest"] = float(amp_pre / (w50_rest + EPS)) if np.isfinite(w50_rest) else np.nan

            b_obs, r2_obs, npts_obs = decay_powerlaw_fit(tb_obs, fb, base_pre, pidx, tmax=300.0)
            b_rest, r2_rest, npts_rest = decay_powerlaw_fit(tb_rest, fb, base_pre, pidx, tmax=300.0)

            feats[f"decay_pl_slope_{b}_obs"] = b_obs
            feats[f"decay_pl_r2_{b}_obs"] = r2_obs
            feats[f"decay_pl_npts_{b}_obs"] = float(npts_obs)

            feats[f"decay_pl_slope_{b}_rest"] = b_rest
            feats[f"decay_pl_r2_{b}_rest"] = r2_rest
            feats[f"decay_pl_npts_{b}_rest"] = float(npts_rest)

        band_tpeak_obs[b] = tpeak_obs
        band_tpeak_rest[b] = tpeak_rest
        band_peak_flux[b] = peak_flux

    tpeaks_obs = np.array([band_tpeak_obs.get(b, np.nan) for b in FILTERS], float)
    tpeaks_rest = np.array([band_tpeak_rest.get(b, np.nan) for b in FILTERS], float)
    tpeaks_obs = np.array([x for x in tpeaks_obs if np.isfinite(x)], float)
    tpeaks_rest = np.array([x for x in tpeaks_rest if np.isfinite(x)], float)
    feats["tpeak_std_obs"] = float(np.std(tpeaks_obs)) if len(tpeaks_obs) >= 2 else np.nan
    feats["tpeak_std_rest"] = float(np.std(tpeaks_rest)) if len(tpeaks_rest) >= 2 else np.nan

    pairs = [("u", "g"), ("g", "r"), ("r", "i"), ("i", "z"), ("z", "y")]
    for a, b in pairs:
        ta_obs = band_tpeak_obs.get(a, np.nan)
        tb_obs2 = band_tpeak_obs.get(b, np.nan)
        ta_rest = band_tpeak_rest.get(a, np.nan)
        tb_rest2 = band_tpeak_rest.get(b, np.nan)
        pa = band_peak_flux.get(a, np.nan)
        pb = band_peak_flux.get(b, np.nan)

        feats[f"tpeakdiff_{a}{b}_obs"] = (ta_obs - tb_obs2) if (np.isfinite(ta_obs) and np.isfinite(tb_obs2)) else np.nan
        feats[f"tpeakdiff_{a}{b}_rest"] = (ta_rest - tb_rest2) if (np.isfinite(ta_rest) and np.isfinite(tb_rest2)) else np.nan
        feats[f"peakratio_{a}{b}"] = (pa / (pb + EPS)) if (np.isfinite(pa) and np.isfinite(pb)) else np.nan

    def ratio_feature(name, num, den):
        if np.isfinite(num) and np.isfinite(den):
            feats[name] = float(num / (den + EPS))
        else:
            feats[name] = np.nan

    for a, b in pairs:
        ratio_feature(f"amppreratio_{a}{b}", feats.get(f"amp_pre_{a}", np.nan), feats.get(f"amp_pre_{b}", np.nan))
        ratio_feature(f"aucratio_{a}{b}_obs", feats.get(f"auc_pos_{a}_obs", np.nan), feats.get(f"auc_pos_{b}_obs", np.nan))
        ratio_feature(f"width50ratio_{a}{b}_obs", feats.get(f"width50_{a}_obs", np.nan), feats.get(f"width50_{b}_obs", np.nan))
        ratio_feature(f"asym50ratio_{a}{b}_obs", feats.get(f"asym50_{a}_obs", np.nan), feats.get(f"asym50_{b}_obs", np.nan))

    for a, b in [("g", "r"), ("r", "i"), ("i", "z")]:
        if (a in band_tb_obs) and (b in band_tb_obs):
            feats[f"corr_{a}{b}_obs"] = band_corr(
                band_tb_obs[a], band_fb[a],
                band_tb_obs[b], band_fb[b]
            )
        else:
            feats[f"corr_{a}{b}_obs"] = np.nan

    slope_t, intercept_t, r2_t = peak_vs_wavelength_slope(band_tpeak_obs, band_tpeak_obs, z=z)
    feats["tpeak_vs_lambda_slope_obs"] = slope_t
    feats["tpeak_vs_lambda_intercept_obs"] = intercept_t
    feats["tpeak_vs_lambda_r2_obs"] = r2_t

    slope_pf, intercept_pf, r2_pf = peak_vs_wavelength_slope(band_tpeak_obs, band_peak_flux, z=z)
    feats["peakflux_vs_lambda_slope"] = slope_pf
    feats["peakflux_vs_lambda_intercept"] = intercept_pf
    feats["peakflux_vs_lambda_r2"] = r2_pf

    tpr_obs = feats.get("tpeak_r_obs", np.nan)
    if np.isfinite(tpr_obs):
        def colors_at_time(t0):
            fr = interp_flux_at_time(band_tb_obs.get("r", np.array([])), band_fb.get("r", np.array([])), t0)
            fg = interp_flux_at_time(band_tb_obs.get("g", np.array([])), band_fb.get("g", np.array([])), t0)
            fi = interp_flux_at_time(band_tb_obs.get("i", np.array([])), band_fb.get("i", np.array([])), t0)
            cgr = (signed_log1p(fg) - signed_log1p(fr)) if (np.isfinite(fg) and np.isfinite(fr)) else np.nan
            cri = (signed_log1p(fr) - signed_log1p(fi)) if (np.isfinite(fr) and np.isfinite(fi)) else np.nan
            return cgr, cri

        cgr0, cri0 = colors_at_time(tpr_obs)
        feats["color_gr_at_rpeak_obs"] = cgr0
        feats["color_ri_at_rpeak_obs"] = cri0

        cgr20, cri20 = colors_at_time(tpr_obs + 20.0)
        cgr40, cri40 = colors_at_time(tpr_obs + 40.0)

        feats["color_gr_rpeak_p20_obs"] = cgr20
        feats["color_ri_rpeak_p20_obs"] = cri20
        feats["color_gr_rpeak_p40_obs"] = cgr40
        feats["color_ri_rpeak_p40_obs"] = cri40

        def slope(c1, c2, dt):
            if np.isfinite(c1) and np.isfinite(c2):
                return float((c2 - c1) / dt)
            return np.nan

        feats["color_gr_slope20_obs"] = slope(cgr0, cgr20, 20.0)
        feats["color_ri_slope20_obs"] = slope(cri0, cri20, 20.0)
        feats["color_gr_slope40_obs"] = slope(cgr0, cgr40, 40.0)
        feats["color_ri_slope40_obs"] = slope(cri0, cri40, 40.0)
    else:
        feats["color_gr_at_rpeak_obs"] = np.nan
        feats["color_ri_at_rpeak_obs"] = np.nan
        feats["color_gr_rpeak_p20_obs"] = np.nan
        feats["color_ri_rpeak_p20_obs"] = np.nan
        feats["color_gr_rpeak_p40_obs"] = np.nan
        feats["color_ri_rpeak_p40_obs"] = np.nan
        feats["color_gr_slope20_obs"] = np.nan
        feats["color_ri_slope20_obs"] = np.nan
        feats["color_gr_slope40_obs"] = np.nan
        feats["color_ri_slope40_obs"] = np.nan

    if np.isfinite(tpr_obs):
        sed_slope, sed_int, sed_r2, sed_n = sed_logflux_vs_loglambda_at_time(
            band_tb_obs, band_fb, band_eb, tpr_obs, z=z
        )
        feats["sed_logflux_loglambda_slope_rpeak"] = sed_slope
        feats["sed_logflux_loglambda_r2_rpeak"] = sed_r2
        feats["sed_logflux_loglambda_nbands_rpeak"] = sed_n

        sed_slope20, sed_int20, sed_r2_20, sed_n20 = sed_logflux_vs_loglambda_at_time(
            band_tb_obs, band_fb, band_eb, tpr_obs + 20.0, z=z
        )
        feats["sed_slope_rpeak_p20"] = sed_slope20
        feats["sed_r2_rpeak_p20"] = sed_r2_20
        feats["sed_nbands_rpeak_p20"] = sed_n20
    else:
        feats["sed_logflux_loglambda_slope_rpeak"] = np.nan
        feats["sed_logflux_loglambda_r2_rpeak"] = np.nan
        feats["sed_logflux_loglambda_nbands_rpeak"] = np.nan
        feats["sed_slope_rpeak_p20"] = np.nan
        feats["sed_r2_rpeak_p20"] = np.nan
        feats["sed_nbands_rpeak_p20"] = np.nan

    return feats

# %%
def build_lightcurve_cache(splits, base_dir, kind="train"):
    base_dir = Path(base_dir)
    lc_cache = {}
    idx_cache = {}

    for s in splits:
        path = base_dir / str(s) / f"{kind}_full_lightcurves.csv"
        lc = pd.read_csv(path)
        lc["object_id"] = lc["object_id"].astype(str)
        groups = lc.groupby("object_id").indices
        lc_cache[s] = lc
        idx_cache[s] = groups

    return lc_cache, idx_cache


def get_lightcurve(lc_cache, idx_cache, split, object_id):
    object_id = str(object_id)
    idx = idx_cache[split].get(object_id, None)
    if idx is None:
        return None
    return lc_cache[split].iloc[idx]

# %%
def build_feature_table(
    log_df,
    lc_cache,
    idx_cache,
    augment_photoz=False,
    test_zerr_pool=None,
    n_aug=2,
    seed=6
):
    rng = np.random.default_rng(seed)
    rows = []

    if test_zerr_pool is not None:
        test_zerr_pool = np.asarray(test_zerr_pool, float)
        test_zerr_pool = test_zerr_pool[np.isfinite(test_zerr_pool)]
        test_zerr_pool = test_zerr_pool[test_zerr_pool > 0]

    for i in range(len(log_df)):
        r = log_df.iloc[i]
        obj = str(r["object_id"])
        split = r["split"]

        lc = get_lightcurve(lc_cache, idx_cache, split, obj)
        if lc is None:
            feats = {"n_obs": 0}
            feats["object_id"] = obj
            feats["split"] = split
            feats["photoz_aug"] = 0
            if "target" in log_df.columns:
                feats["target"] = int(r["target"])
            rows.append(feats)
            continue

        feats = extract_features_for_object(
            lc_raw=lc,
            z=r["Z"],
            z_err=r.get("Z_err", 0.0),
            ebv=r["EBV"],
        )
        feats["object_id"] = obj
        feats["split"] = split
        feats["photoz_aug"] = 0
        if "target" in log_df.columns:
            feats["target"] = int(r["target"])
        rows.append(feats)

        if augment_photoz and ("target" in log_df.columns) and (test_zerr_pool is not None) and (len(test_zerr_pool) > 0):
            z0 = safe_float(r["Z"], default=0.0)
            for _ in range(n_aug):
                sigma = float(rng.choice(test_zerr_pool))
                z_sim = max(0.0, z0 + float(rng.normal(0.0, sigma)))
                feats2 = extract_features_for_object(
                    lc_raw=lc,
                    z=z_sim,
                    z_err=sigma,
                    ebv=r["EBV"],
                )
                feats2["object_id"] = obj
                feats2["split"] = split
                feats2["target"] = int(r["target"])
                feats2["photoz_aug"] = 1
                rows.append(feats2)

    return pd.DataFrame(rows)

def clean_features(df, drop_cols, add_missing_flags=True):
    X = df.drop(columns=drop_cols).copy()
    X = X.replace([np.inf, -np.inf], np.nan)

    if add_missing_flags:
        miss = X.isna().astype(np.uint8)
        miss.columns = [c + "_isnan" for c in miss.columns]
        X = pd.concat([X, miss], axis=1)

    return X

# %% [markdown]
# Improved threshold

# %%
def best_threshold_f1(y_true, probs, eps=1e-12):
    y = np.asarray(y_true).astype(int)
    p = np.asarray(probs).astype(float)

    ok = np.isfinite(p)
    y = y[ok]
    p = p[ok]

    n = len(p)
    if n == 0:
        return 0.5, 0.0

    order = np.argsort(-p)
    p_sorted = p[order]
    y_sorted = y[order]

    P = int(y_sorted.sum())
    if P == 0:
        return 0.5, 0.0

    tp = np.cumsum(y_sorted)
    fp = np.arange(1, n + 1) - tp
    fn = P - tp

    denom = (2 * tp + fp + fn)
    f1 = np.where(denom > 0, 2 * tp / denom, 0.0)

    k = int(np.argmax(f1))  # 0-based index
    best_f1 = float(f1[k])

    pk = p_sorted[k]
    if k + 1 < n:
        pk1 = p_sorted[k + 1]
        if pk1 < pk:
            th = float(0.5 * (pk + pk1))
        else:
            th = float(pk - eps)
    else:
        th = float(pk - eps)

    return th, best_f1


def make_splitter(n_splits, random_state=6):
    return StratifiedGroupKFold(n_splits=n_splits, shuffle=True, random_state=random_state)

# %%
import numpy as np
import lightgbm as lgb
from lightgbm import LGBMClassifier

def add_spectype_teacher_features(
    train_feat,
    train_log,
    test_feat,
    n_splits=10,
    seed=6,
    seeds=(6, 67, 6767),
    aug_col="photoz_aug",
    aug_weight=0.33,   # downweight augmented clones; set to 1.0 to disable
):
    train_feat = train_feat.copy()
    test_feat  = test_feat.copy()

    df = train_feat.merge(train_log[["object_id", "SpecType"]], on="object_id", how="left")
    spec = df["SpecType"].fillna("Unknown").astype(str)

    def map_group(s):
        s2 = s.strip()
        if s2 == "TDE":
            return "TDE"
        if s2 == "AGN":
            return "AGN"
        if "SLSN" in s2:
            return "SLSN"
        if s2 == "SN Ia" or s2.startswith("SN Ia"):
            return "SNIa"
        if s2.startswith("SN II") or ("SN II" in s2):
            return "SNII"
        if s2.startswith("SN"):
            return "SNother"
        return "Other"

    spec_group = spec.map(map_group).astype(str)

    classes = sorted(spec_group.unique())
    class_to_idx = {c: i for i, c in enumerate(classes)}
    y_mc = spec_group.map(class_to_idx).to_numpy()

    # Features
    X_tr = clean_features(df, drop_cols=["object_id", "split", "target", "SpecType"], add_missing_flags=True)
    X_te = clean_features(test_feat, drop_cols=["object_id", "split"], add_missing_flags=True)

    # Hard align columns (robustness)
    X_te = X_te.reindex(columns=X_tr.columns, fill_value=0.0)

    groups = df["split"].to_numpy()

    # Optional: downweight augmented rows
    if aug_col in df.columns:
        aug = df[aug_col].fillna(0).astype(int).to_numpy()
        sample_weight = np.where(aug == 1, float(aug_weight), 1.0)
    else:
        sample_weight = None

    splitter = make_splitter(n_splits, random_state=seed)
    split_iter = list(splitter.split(X_tr, y_mc, groups))

    oof = np.zeros((len(X_tr), len(classes)), dtype=float)
    best_iters = []

    base = dict(
        objective="multiclass",
        num_class=len(classes),
        metric="multi_logloss",
        n_estimators=20000,
        learning_rate=0.03,
        num_leaves=63,
        min_child_samples=5,
        subsample=0.8,
        subsample_freq=1,
        colsample_bytree=0.8,
        reg_alpha=0.0,
        reg_lambda=0.0,
        n_jobs=-1,
        verbosity=-1,
        force_col_wise=True,
    )

    # CV OOF with multi-seed averaging
    for fold, (tr_idx, va_idx) in enumerate(split_iter, 1):
        probs_va = []
        for sd in seeds:
            model = LGBMClassifier(**base, random_state=sd)
            model.fit(
                X_tr.iloc[tr_idx], y_mc[tr_idx],
                sample_weight=None if sample_weight is None else sample_weight[tr_idx],
                eval_set=[(X_tr.iloc[va_idx], y_mc[va_idx])],
                eval_metric="multi_logloss",
                callbacks=[lgb.early_stopping(200, verbose=False)]
            )

            bi = int(getattr(model, "best_iteration_", base["n_estimators"]))
            best_iters.append(bi)

            pva = model.predict_proba(X_tr.iloc[va_idx], num_iteration=bi)
            probs_va.append(pva)

        oof[va_idx] = np.mean(probs_va, axis=0)

    # Use median best_iter for full fit so final model matches CV behavior
    n_est_final = int(np.median(best_iters)) if len(best_iters) else base["n_estimators"]
    n_est_final = max(200, n_est_final)

    probs_test = []
    base_full = dict(base)
    base_full["n_estimators"] = n_est_final

    for sd in seeds:
        model_full = LGBMClassifier(**base_full, random_state=sd)
        model_full.fit(X_tr, y_mc, sample_weight=sample_weight)
        probs_test.append(model_full.predict_proba(X_te))

    p_test = np.mean(probs_test, axis=0)

    def entropy(p):
        p = np.clip(p, 1e-12, 1.0)
        return -np.sum(p * np.log(p), axis=1)

    def margin(p):
        # top1 - top2 confidence margin
        p_sorted = np.sort(p, axis=1)
        return p_sorted[:, -1] - p_sorted[:, -2] if p.shape[1] >= 2 else p_sorted[:, -1]

    for i, c in enumerate(classes):
        train_feat[f"p_spec_{c}"] = oof[:, i]
        test_feat[f"p_spec_{c}"] = p_test[:, i]

    train_feat["spec_entropy"] = entropy(oof)
    test_feat["spec_entropy"] = entropy(p_test)

    train_feat["spec_topprob"] = np.max(oof, axis=1)
    test_feat["spec_topprob"] = np.max(p_test, axis=1)

    train_feat["spec_margin"] = margin(oof)
    test_feat["spec_margin"] = margin(p_test)

    return train_feat, test_feat

# %%
def feature_select_gain_topk(train_feat, k=350, n_splits=10, seed=6):
    y = train_feat["target"].astype(int).to_numpy()
    groups = train_feat["split"].to_numpy()
    X = clean_features(train_feat, drop_cols=["object_id", "split", "target"], add_missing_flags=True)

    splitter = make_splitter(n_splits, random_state=seed)
    split_iter = splitter.split(X, y, groups)

    gains = {c: 0.0 for c in X.columns}

    base_params = dict(
        objective="binary:logistic",
        eval_metric="aucpr",
        random_state=seed,
        n_jobs=-1,
        tree_method="hist",
        device="cuda",
        n_estimators=6000,
        learning_rate=0.02,
        max_depth=6,
        min_child_weight=10,
        subsample=0.9,
        colsample_bytree=0.9,
        reg_alpha=2.0,
        reg_lambda=2.0,
        gamma=0.0,
        max_bin=256,
    )

    for tr_idx, va_idx in split_iter:
        X_tr, y_tr = X.iloc[tr_idx], y[tr_idx]
        neg = np.sum(y_tr == 0)
        pos = np.sum(y_tr == 1)
        spw = float(neg / max(1, pos))

        model = XGBClassifier(**{**base_params, "scale_pos_weight": spw})
        model.fit(X_tr, y_tr, verbose=False)

        score = model.get_booster().get_score(importance_type="gain")
        for feat, g in score.items():
            if feat in gains:
                gains[feat] += float(g)

    ranked = sorted(gains.items(), key=lambda x: x[1], reverse=True)
    top = [f for f, _ in ranked[:k]]
    return top

# %%
import numpy as np

def xgb_predict_proba_best(model, X):
    """Predict using best_iteration if available, otherwise default."""
    best_it = getattr(model, "best_iteration", None)
    if best_it is None:
        return model.predict_proba(X)[:, 1]
    try:
        return model.predict_proba(X, iteration_range=(0, best_it + 1))[:, 1]
    except TypeError:
        return model.predict_proba(X)[:, 1]

# %%
import numpy as np
import optuna
from xgboost import XGBClassifier

def run_optuna_xgb_f1(train_feat, feature_cols, n_folds_tune=10, timeout_sec=28800, seed=6):
    y = train_feat["target"].astype(int).to_numpy()
    groups = train_feat["split"].to_numpy()

    X_all = clean_features(train_feat, drop_cols=["object_id", "split", "target"], add_missing_flags=True)
    X = X_all[feature_cols].copy()

    splitter = make_splitter(n_folds_tune, random_state=seed)
    split_iter_all = list(splitter.split(X, y, groups))

    def predict_best(model, X_):
        best_it = getattr(model, "best_iteration", None)
        if best_it is None:
            return model.predict_proba(X_)[:, 1]
        try:
            return model.predict_proba(X_, iteration_range=(0, best_it + 1))[:, 1]
        except TypeError:
            return model.predict_proba(X_)[:, 1]

    def objective(trial):
        params = {
            "objective": "binary:logistic",
            "eval_metric": "aucpr",
            "random_state": seed,
            "n_jobs": -1,
            "tree_method": "hist",
            "device": "cuda",
            "verbosity": 0,
            "n_estimators": trial.suggest_int("n_estimators", 1500, 14000),
            "learning_rate": trial.suggest_float("learning_rate", 0.002, 0.08, log=True),
            "max_depth": trial.suggest_int("max_depth", 2, 10),
            "min_child_weight": trial.suggest_int("min_child_weight", 1, 80),
            "subsample": trial.suggest_float("subsample", 0.5, 1.0),
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 1.0),
            "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.5, 1.0),
            "colsample_bynode": trial.suggest_float("colsample_bynode", 0.5, 1.0),
            "max_bin": trial.suggest_int("max_bin", 128, 512),
            "gamma": trial.suggest_float("gamma", 0.0, 12.0),
            "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 35.0),
            "reg_lambda": trial.suggest_float("reg_lambda", 0.05, 50.0),
            "max_delta_step": trial.suggest_int("max_delta_step", 0, 10),
            "grow_policy": trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"]),
            "early_stopping_rounds": 200,
        }

        if params["grow_policy"] == "lossguide":
            params["max_leaves"] = trial.suggest_int("max_leaves", 16, 512)

        oof = np.zeros(len(X), dtype=float)
        f1_progress = []

        for fold, (tr_idx, va_idx) in enumerate(split_iter_all, 1):
            X_tr, y_tr = X.iloc[tr_idx], y[tr_idx]
            X_va, y_va = X.iloc[va_idx], y[va_idx]

            neg = np.sum(y_tr == 0)
            pos = np.sum(y_tr == 1)
            spw = float(neg / max(1, pos))

            model = XGBClassifier(**params, scale_pos_weight=spw)
            model.fit(
                X_tr, y_tr,
                eval_set=[(X_va, y_va)],
                verbose=False
            )

            oof[va_idx] = predict_best(model, X_va)

            _, f1_fold = best_threshold_f1(y_va, oof[va_idx])
            f1_progress.append(float(f1_fold))

            trial.report(float(np.mean(f1_progress)), step=fold)
            if trial.should_prune():
                raise optuna.TrialPruned()

        _, f1 = best_threshold_f1(y, oof)
        return float(f1)

    sampler = optuna.samplers.TPESampler(seed=seed, multivariate=True, group=True)
    pruner = optuna.pruners.MedianPruner(n_startup_trials=40, n_warmup_steps=3)

    study = optuna.create_study(
        direction="maximize",
        sampler=sampler,
        pruner=pruner,
        study_name="xgb_oof_f1_splitcv_gpu_selected",
        storage="sqlite:///optuna_xgb_oof_f1_gpu_selected.db",
        load_if_exists=True
    )

    study.optimize(objective, n_trials=999999, timeout=timeout_sec)

    print("\nOptuna best OOF F1:", study.best_value)
    print("Best params:")
    for k, v in study.best_params.items():
        print(k, "=", v)

    return study.best_params

# %%
def xgb_fit_kaggle(model, X_tr, y_tr, X_va=None, y_va=None, verbose=False, early_stopping_rounds=None):
    if X_va is not None and y_va is not None and early_stopping_rounds is not None:
        model.set_params(early_stopping_rounds=int(early_stopping_rounds))
        model.fit(
            X_tr, y_tr,
            eval_set=[(X_va, y_va)],
            verbose=verbose
        )
    elif X_va is not None and y_va is not None:
        model.fit(X_tr, y_tr, eval_set=[(X_va, y_va)], verbose=verbose)
    else:
        model.fit(X_tr, y_tr, verbose=verbose)

    return model

# %%
from sklearn.metrics import average_precision_score

def predict_xgb_multiseed_augtrain(
    train_feat, test_feat, best_params, feature_cols,
    n_splits_oof=20, seeds=(6, 67, 6767),
    aug_col="photoz_aug"
):
    y_all = train_feat["target"].astype(int).to_numpy()
    g_all = train_feat["split"].to_numpy()

    base_mask = (train_feat[aug_col].fillna(0).astype(int).to_numpy() == 0) if aug_col in train_feat.columns else np.ones(len(train_feat), bool)

    X_all = clean_features(train_feat, drop_cols=["object_id", "split", "target"], add_missing_flags=True)[feature_cols]
    X_test = clean_features(test_feat, drop_cols=["object_id", "split"], add_missing_flags=True)[feature_cols]

    y_base = y_all[base_mask]
    g_base = g_all[base_mask]
    X_base = X_all.loc[base_mask].reset_index(drop=True)

    splitter = make_splitter(n_splits_oof, random_state=6)
    split_iter = list(splitter.split(X_base, y_base, g_base))

    oof_base = np.zeros(len(X_base), dtype=float)
    best_its = []

    for fold, (tr_idx, va_idx) in enumerate(split_iter, 1):
        val_groups = np.unique(g_base[va_idx])
        tr_mask = ~np.isin(g_all, val_groups)

        X_tr = X_all.loc[tr_mask]
        y_tr = y_all[tr_mask]

        X_va = X_base.iloc[va_idx]
        y_va = y_base[va_idx]

        neg = np.sum(y_tr == 0)
        pos = np.sum(y_tr == 1)
        spw = float(neg / max(1, pos))

        probs_va = []
        for sd in seeds:
            model = XGBClassifier(
                objective="binary:logistic",
                eval_metric="aucpr",
                random_state=sd,
                n_jobs=-1,
                tree_method="hist",
                device="cuda",
                scale_pos_weight=spw,
                **best_params
            )
            xgb_fit_kaggle(model, X_tr, y_tr, X_va, y_va, verbose=False, early_stopping_rounds=200)

            best_it = getattr(model, "best_iteration", None)
            if best_it is not None:
                best_its.append(int(best_it) + 1)
                pva = model.predict_proba(X_va, iteration_range=(0, best_it + 1))[:, 1]
            else:
                pva = model.predict_proba(X_va)[:, 1]

            probs_va.append(pva)

        oof_base[va_idx] = np.mean(probs_va, axis=0)

    th, f1 = best_threshold_f1(y_base, oof_base)
    ap = average_precision_score(y_base, oof_base)
    print("\nXGB base-OOF best_th:", th)
    print("XGB base-OOF best_F1:", f1)
    print("XGB base-OOF AP:", ap)

    n_est_final = int(np.median(best_its)) if len(best_its) else int(best_params.get("n_estimators", 4000))
    n_est_final = max(200, n_est_final)

    probs_test = []
    neg_full = np.sum(y_all == 0)
    pos_full = np.sum(y_all == 1)
    spw_full = float(neg_full / max(1, pos_full))

    for sd in seeds:
        model = XGBClassifier(
            objective="binary:logistic",
            eval_metric="aucpr",
            random_state=sd,
            n_jobs=-1,
            tree_method="hist",
            device="cuda",
            scale_pos_weight=spw_full,
            n_estimators=n_est_final,
            **{k: v for k, v in best_params.items() if k != "n_estimators"}
        )
        xgb_fit_kaggle(model, X_all, y_all, verbose=False)
        probs_test.append(model.predict_proba(X_test)[:, 1])

    p_test = np.mean(probs_test, axis=0)
    return p_test, th, oof_base

# %%
import lightgbm as lgb
from lightgbm import LGBMClassifier
from sklearn.metrics import average_precision_score

def predict_lgb_multiseed_augtrain(
    train_feat, test_feat, lgb_params, feature_cols,
    n_splits_oof=20, seeds=(6, 67, 6767),
    aug_col="photoz_aug"
):
    y_all = train_feat["target"].astype(int).to_numpy()
    g_all = train_feat["split"].to_numpy()

    base_mask = (train_feat[aug_col].fillna(0).astype(int).to_numpy() == 0) if aug_col in train_feat.columns else np.ones(len(train_feat), bool)

    X_all = clean_features(train_feat, drop_cols=["object_id", "split", "target"], add_missing_flags=True)[feature_cols]
    X_test = clean_features(test_feat, drop_cols=["object_id", "split"], add_missing_flags=True)[feature_cols]

    y_base = y_all[base_mask]
    g_base = g_all[base_mask]
    X_base = X_all.loc[base_mask].reset_index(drop=True)

    splitter = make_splitter(n_splits_oof, random_state=6)
    split_iter = list(splitter.split(X_base, y_base, g_base))

    oof_base = np.zeros(len(X_base), dtype=float)
    best_its = []

    for fold, (tr_idx, va_idx) in enumerate(split_iter, 1):
        val_groups = np.unique(g_base[va_idx])
        tr_mask = ~np.isin(g_all, val_groups)

        X_tr = X_all.loc[tr_mask]
        y_tr = y_all[tr_mask]

        X_va = X_base.iloc[va_idx]
        y_va = y_base[va_idx]

        neg = np.sum(y_tr == 0)
        pos = np.sum(y_tr == 1)
        spw = float(neg / max(1, pos))

        probs_va = []
        for sd in seeds:
            model = LGBMClassifier(
                objective="binary",
                n_jobs=-1,
                random_state=sd,
                scale_pos_weight=spw,
                **lgb_params
            )
            model.fit(
                X_tr, y_tr,
                eval_set=[(X_va, y_va)],
                eval_metric="average_precision",
                callbacks=[lgb.early_stopping(200, verbose=False)]
            )
            bi = int(model.best_iteration_) if getattr(model, "best_iteration_", None) else int(lgb_params.get("n_estimators", 4000))
            best_its.append(bi)
            pva = model.predict_proba(X_va, num_iteration=bi)[:, 1]
            probs_va.append(pva)

        oof_base[va_idx] = np.mean(probs_va, axis=0)

    th, f1 = best_threshold_f1(y_base, oof_base)
    ap = average_precision_score(y_base, oof_base)
    print("\nLGB base-OOF best_th:", th)
    print("LGB base-OOF best_F1:", f1)
    print("LGB base-OOF AP:", ap)

    n_est_final = int(np.median(best_its)) if len(best_its) else int(lgb_params.get("n_estimators", 4000))
    n_est_final = max(200, n_est_final)

    probs_test = []
    neg_full = np.sum(y_all == 0)
    pos_full = np.sum(y_all == 1)
    spw_full = float(neg_full / max(1, pos_full))

    for sd in seeds:
        model = LGBMClassifier(
            objective="binary",
            n_jobs=-1,
            random_state=sd,
            scale_pos_weight=spw_full,
            n_estimators=n_est_final,
            **{k: v for k, v in lgb_params.items() if k != "n_estimators"}
        )
        model.fit(X_all, y_all)
        probs_test.append(model.predict_proba(X_test)[:, 1])

    p_test = np.mean(probs_test, axis=0)
    return p_test, th, oof_base

# %%
N_AUG = 2
FS_TOPK = 380
FS_FOLDS = 10
OPTUNA_FOLDS = 10
OPTUNA_TIMEOUT_SEC = 28800
FINAL_OOF_FOLDS = 20
SEEDS = (6, 67, 6767)

ROOT = Path.cwd().parents[0]
DATA_DIR = ROOT / "data"

train_log = pd.read_csv(DATA_DIR / "train_log.csv")
test_log  = pd.read_csv(DATA_DIR / "test_log.csv")

train_log["object_id"] = train_log["object_id"].astype(str)
test_log["object_id"] = test_log["object_id"].astype(str)

if "Z_err" not in train_log.columns:
    train_log["Z_err"] = 0.0
train_log["Z_err"] = train_log["Z_err"].fillna(0.0)

if "Z_err" not in test_log.columns:
    test_log["Z_err"] = 0.0
test_log["Z_err"] = test_log["Z_err"].fillna(0.0)

train_splits = sorted(train_log["split"].unique())
test_splits = sorted(test_log["split"].unique())


train_lc_cache, train_idx_cache = build_lightcurve_cache(
    train_splits, base_dir=DATA_DIR, kind="train"
)

test_lc_cache, test_idx_cache = build_lightcurve_cache(
    test_splits, base_dir=DATA_DIR, kind="test"
)

test_zerr_pool = test_log["Z_err"].dropna().values

train_feat = build_feature_table(
    train_log, train_lc_cache, train_idx_cache,
    augment_photoz=True,
    test_zerr_pool=test_zerr_pool,
    n_aug=N_AUG,
    seed=6
)

test_feat = build_feature_table(
    test_log, test_lc_cache, test_idx_cache,
    augment_photoz=False
)
print(f"train shape: {train_feat.shape}")
print(f"test shape: {test_feat.shape}")

# %%
SEASON_GAP_DAYS = 90.0
DET_SIGMA = 3.0
BASE_FRAC = 0.30
CLUSTER_GAP_ALLOW = 20.0
QUIET_BUFFER_DAYS = 30.0

def season_ids(t_obs, gap=SEASON_GAP_DAYS):
    if len(t_obs) == 0:
        return np.array([], dtype=int)
    dt = np.diff(t_obs)
    sid = np.zeros(len(t_obs), dtype=int)
    sid[1:] = np.cumsum(dt > gap)
    return sid

def robust_baseline(flux, frac=BASE_FRAC):
    flux = np.asarray(flux, float)
    if len(flux) == 0:
        return np.nan
    q = np.quantile(flux, frac)
    low = flux[flux <= q]
    return float(np.median(low)) if len(low) else float(np.median(flux))

def det_cluster_stats(t_obs, det_mask, gap_allow=CLUSTER_GAP_ALLOW):
    if len(t_obs) == 0 or not np.any(det_mask):
        return 0.0, 0.0
    td = np.sort(t_obs[det_mask])
    if len(td) == 1:
        return 1.0, 1.0
    dtd = np.diff(td)
    breaks = np.where(dtd > gap_allow)[0]
    starts = np.r_[0, breaks + 1]
    ends   = np.r_[breaks, len(td) - 1]
    sizes = ends - starts + 1
    return float(len(sizes)), float(np.max(sizes))

def von_neumann_eta(x):
    x = np.asarray(x, float)
    if len(x) < 3:
        return np.nan
    num = np.sum(np.diff(x)**2)
    den = np.sum((x - np.mean(x))**2) + EPS
    return float(num / den)

def fractional_variability(flux, err):
    f = np.asarray(flux, float)
    e = np.asarray(err, float)
    if len(f) < 3:
        return np.nan
    mu = np.mean(f)
    if not np.isfinite(mu) or abs(mu) < EPS:
        return np.nan
    s2 = np.var(f, ddof=1)
    n2 = np.mean(e**2)
    val = s2 - n2
    if val <= 0:
        return 0.0
    return float(np.sqrt(val) / (abs(mu) + EPS))

def quiet_mask_from_detections(t_obs, det_mask, buffer_days=QUIET_BUFFER_DAYS):
    t_obs = np.asarray(t_obs, float)
    if len(t_obs) == 0:
        return np.array([], dtype=bool)
    if not np.any(det_mask):
        return np.ones(len(t_obs), dtype=bool)

    td = np.sort(t_obs[det_mask])
    idx = np.searchsorted(td, t_obs)
    left = np.clip(idx - 1, 0, len(td) - 1)
    right = np.clip(idx, 0, len(td) - 1)
    dleft = np.abs(t_obs - td[left])
    dright = np.abs(t_obs - td[right])
    dmin = np.minimum(dleft, dright)
    return dmin > buffer_days

def localization_feats_from_lc(lc):
    lc = lc.sort_values("Time (MJD)")
    t = lc["Time (MJD)"].to_numpy(float)
    f = lc["Flux"].to_numpy(float)
    e = lc["Flux_err"].to_numpy(float)
    b = lc["Filter"].to_numpy(str)

    out = {}
    out["n_obs_total_loc"] = float(len(t))
    if len(t) == 0:
        return out

    out["tspan_obs_global_loc"] = float(t.max() - t.min())
    out["neg_flux_frac_global_raw_loc"] = float(np.mean(f < 0))

    base_g = robust_baseline(f)
    det3_g = ((f - base_g) / (np.abs(e) + EPS) > DET_SIGMA) & ((f - base_g) > 0)

    out["baseline_global_loc"] = float(base_g)
    out["n_det3_global_loc"] = float(np.sum(det3_g))
    out["frac_det3_global_loc"] = float(np.mean(det3_g))

    if np.sum(det3_g) >= 2:
        span = float(t[det3_g].max() - t[det3_g].min())
    else:
        span = np.nan
    out["span_det3_global_obs_loc"] = span

    sid = season_ids(t)
    if np.any(det3_g):
        det_sids = sid[det3_g]
        out["n_det3_seasons_global_loc"] = float(len(np.unique(det_sids)))
        _, cnt = np.unique(det_sids, return_counts=True)
        out["det3_topseason_frac_global_loc"] = float(np.max(cnt) / (np.sum(det3_g) + EPS))
    else:
        out["n_det3_seasons_global_loc"] = 0.0
        out["det3_topseason_frac_global_loc"] = np.nan

    c_count, c_max = det_cluster_stats(t, det3_g)
    out["det3_cluster_count_global_loc"] = c_count
    out["det3_cluster_maxlen_global_loc"] = c_max

    out["burstiness_global_loc"] = float(span / (out["tspan_obs_global_loc"] + EPS)) if np.isfinite(span) else np.nan
    out["det_density_global_loc"] = float(out["n_det3_global_loc"] / (span + EPS)) if np.isfinite(span) and span > 0 else np.nan

    qmask = quiet_mask_from_detections(t, det3_g)
    fq = f[qmask]; eq = e[qmask]
    out["n_quiet_global_loc"] = float(len(fq))
    out["eta_quiet_global_loc"] = von_neumann_eta(fq) if len(fq) >= 3 else np.nan
    out["fvar_quiet_global_loc"] = fractional_variability(fq, eq) if len(fq) >= 3 else np.nan

    for fb in FILTERS:
        m = (b == fb)
        tb = t[m]; ff = f[m]; ee = e[m]
        out[f"n_{fb}_loc"] = float(len(tb))
        if len(tb) == 0:
            out[f"frac_det3_{fb}_loc"] = np.nan
            out[f"span_det3_{fb}_obs_loc"] = np.nan
            out[f"fvar_quiet_{fb}_loc"] = np.nan
            out[f"eta_quiet_{fb}_loc"] = np.nan
            continue

        order = np.argsort(tb)
        tb, ff, ee = tb[order], ff[order], ee[order]

        base_b = robust_baseline(ff)
        det3_b = ((ff - base_b) / (np.abs(ee) + EPS) > DET_SIGMA) & ((ff - base_b) > 0)

        out[f"frac_det3_{fb}_loc"] = float(np.mean(det3_b))
        out[f"span_det3_{fb}_obs_loc"] = float(tb[det3_b].max() - tb[det3_b].min()) if np.sum(det3_b) >= 2 else np.nan

        qmask_b = quiet_mask_from_detections(tb, det3_b)
        fqb = ff[qmask_b]; eqb = ee[qmask_b]
        out[f"eta_quiet_{fb}_loc"] = von_neumann_eta(fqb) if len(fqb) >= 3 else np.nan
        out[f"fvar_quiet_{fb}_loc"] = fractional_variability(fqb, eqb) if len(fqb) >= 3 else np.nan

    return out

def build_localization_table(log_df, lc_cache, idx_cache):
    rows = []
    for _, r in log_df.iterrows():
        obj = str(r["object_id"])
        split = r["split"]
        lc = get_lightcurve(lc_cache, idx_cache, split, obj)
        d = {"object_id": obj, "split": split}
        if lc is not None and len(lc) > 0:
            d.update(localization_feats_from_lc(lc))
        rows.append(d)
    return pd.DataFrame(rows)

# %%
loc_train = build_localization_table(train_log, train_lc_cache, train_idx_cache)
loc_test  = build_localization_table(test_log,  test_lc_cache,  test_idx_cache)

train_feat = train_feat.merge(loc_train, on=["object_id","split"], how="left")
test_feat  = test_feat.merge(loc_test,  on=["object_id","split"], how="left")

print(f"after loc merge train shape: {train_feat.shape}")
print(f"after loc merge test shape : {test_feat.shape}")
# Out:
# after loc merge train shape: (9129, 605)
# after loc merge test shape : (7135, 604)

# %%
from sklearn.model_selection import GroupKFold

def add_locstack_feature(train_feat, test_feat, seed=6, n_splits=10):
    aug_col = "photoz_aug"
    if aug_col in train_feat.columns:
        base_mask = (train_feat[aug_col].fillna(0).astype(int) == 0)
    else:
        base_mask = np.ones(len(train_feat), dtype=bool)

    base = train_feat.loc[base_mask].copy()

    y = base["target"].astype(int).to_numpy()
    groups = base["split"].astype(str).to_numpy()

    loc_cols = [c for c in base.columns if c.endswith("_loc")]
    Xb = base[loc_cols].fillna(0.0)
    Xt = test_feat[loc_cols].fillna(0.0)

    gkf = GroupKFold(n_splits=n_splits)
    oof = np.zeros(len(base), dtype=float)
    ptest = np.zeros(len(test_feat), dtype=float)

    for fold, (tr, va) in enumerate(gkf.split(Xb, y, groups), 1):
        y_tr = y[tr]
        neg = np.sum(y_tr == 0)
        pos = np.sum(y_tr == 1)
        spw = float(neg / max(1, pos))

        m = XGBClassifier(
            n_estimators=4000,
            learning_rate=0.03,
            max_depth=5,
            min_child_weight=10,
            subsample=0.85,
            colsample_bytree=0.75,
            reg_alpha=1.0,
            reg_lambda=6.0,
            gamma=0.0,
            objective="binary:logistic",
            eval_metric="aucpr",
            tree_method="hist",
            device="cuda",
            n_jobs=-1,
            scale_pos_weight=spw,
            random_state=seed + 1000*fold,
        )
        m.fit(Xb.iloc[tr], y_tr, verbose=False)
        oof[va] = m.predict_proba(Xb.iloc[va])[:, 1]
        ptest += m.predict_proba(Xt)[:, 1] / n_splits

    tmp = base[["object_id", "split"]].copy()
    tmp["p_locstack"] = oof

    train_feat = train_feat.merge(tmp, on=["object_id", "split"], how="left")
    test_feat["p_locstack"] = ptest

    ths = np.linspace(0.01, 0.99, 199)
    best = (0.0, None)
    for th in ths:
        f1 = f1_score(y, (oof > th).astype(int))
        if f1 > best[0]:
            best = (f1, th)
    print("locstack-only base OOF F1:", best[0], "best_th:", best[1])

    return train_feat, test_feat

train_feat, test_feat = add_locstack_feature(train_feat, test_feat, seed=6, n_splits=10)
# Out:
# c:\Users\rowes\Documents\GitHub\2026-ML-Projects\.venv\Lib\site-packages\xgboost\core.py:774: UserWarning: [17:52:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\common\error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# locstack-only base OOF F1: 0.32167832167832167 best_th: 0.2772727272727273

# %%
train_feat, test_feat = add_spectype_teacher_features(train_feat, train_log, test_feat, n_splits=10, seed=6)

# %%
if "photoz_aug" in train_feat.columns:
    base_train = train_feat[train_feat["photoz_aug"].fillna(0).astype(int) == 0].copy()
else:
    base_train = train_feat.copy()

selected_cols = feature_select_gain_topk(base_train, k=FS_TOPK, n_splits=FS_FOLDS, seed=6)

# %%
best_params = run_optuna_xgb_f1(
    base_train,
    feature_cols=selected_cols,
    n_folds_tune=OPTUNA_FOLDS,
    timeout_sec=12600,
    seed=6
)
# Out:
# c:\Users\rowes\Documents\GitHub\2026-ML-Projects\.venv\Lib\site-packages\optuna\_experimental.py:33: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   optuna_warn(
# c:\Users\rowes\Documents\GitHub\2026-ML-Projects\.venv\Lib\site-packages\optuna\_experimental.py:33: ExperimentalWarning: Argument ``group`` is an experimental feature. The interface can change in the future.
#   optuna_warn(
# [I 2026-01-28 19:55:11,622] Using an existing study with name 'xgb_oof_f1_splitcv_gpu_selected' instead of creating a new one.
# [I 2026-01-28 19:55:45,176] Trial 11 finished with value: 0.48743718592964824 and parameters: {'n_estimators': 12661, 'learning_rate': 0.006805837253045404, 'max_depth': 9, 'min_child_weight': 4, 'subsample': 0.553828339967984, 'colsample_bytree': 0.7570312385237441, 'colsample_bylevel': 0.7649086810964107, 'colsample_bynode': 0.7094037142783272, 'max_bin': 257, 'gamma': 7.470233186353083, 'reg_alpha': 15.334949913810593, 'reg_lambda': 36.80731121211708, 'max_delta_step': 5, 'grow_policy': 'lossguide', 'max_leaves': 508}. Best is trial 4 with value: 0.5730659025787965.
# [I 2026-01-28 19:56:00,584] Trial 12 finished with value: 0.5292307692307693 and parameters: {'n_estimators': 3334, 'learning_rate': 0.07591438453252873, 'max_depth': 7, 'min_child_weight': 40, 'subsample': 0.6775610564216067, 'colsample_bytree': 0.6304559930379282, 'colsample_bylevel': 0.6209319873252017, 'colsample_bynode': 0.7926505941925547, 'max_bin': 143, 'gamma': 5.300853492582661, 'reg_alpha': 29.45687090117315, 'reg_lambda': 31.763353129732025, 'max_delta_step': 10, 'grow_policy': 'lossguide', 'max_leaves': 331}. Best is trial 4 with value: 0.5730659025787965.
# [I 2026-01-28 19:56:18,308] Trial 13 finished with value: 0.5565217391304348 and parameters: {'n_estimators': 9723, 'learning_rate': 0.030225637201127805, 'max_depth': 10, 'min_child_weight': 64, 'subsample': 0.7730478169797059, 'colsample_bytree': 0.5661060142685129, 'colsample_bylevel': 0.6229392800591568, 'colsample_bynode': 0.8899913761234023, 'max_bin': 142, 'gamma': 7.489261231982143, 'reg_alpha': 14.354823821310482, 'reg_lambda': 5.868150069082104, 'max_delta_step': 3, 'grow_policy': 'depthwise'}. Best is trial 4 with value: 0.5730659025787965.
# [I 2026-01-28 19:56:33,027] Trial 14 finished with value: 0.5105105105105106 and parameters: {'n_estimators': 12513, 'learning_rate': 0.0730484702522675, 'max_depth': 9, 'min_child_weight': 76, 'subsample': 0.7130254128512694, 'colsample_bytree': 0.4593761305675215, 'colsample_bylevel': 0.7184036675360732, 'colsample_bynode': 0.9211291223573982, 'max_bin': 264, 'gamma': 8.425836993284047, 'reg_alpha': 22.718570902903643, 'reg_lambda': 19.96533041910163, 'max_delta_step': 3, 'grow_policy': 'depthwise'}. Best is trial 4 with value: 0.5730659025787965.
# [I 2026-01-28 19:56:48,711] Trial 15 finished with value: 0.4727272727272727 and parameters: {'n_estimators': 9233, 'learning_rate': 0.034962375950590784, 'max_depth': 7, 'min_child_weight': 66, 'subsample': 0.5966932462469793, 'colsample_bytree': 0.749198678946602, 'colsample_bylevel': 0.8081199529074973, 'colsample_bynode': 0.9768375829961636, 'max_bin': 168, 'gamma': 0.7213806719866733, 'reg_alpha': 33.874104087923186, 'reg_lambda': 35.10718736060666, 'max_delta_step': 9, 'grow_policy': 'depthwise'}. Best is trial 4 with value: 0.5730659025787965.
# [I 2026-01-28 19:57:09,446] Trial 16 finished with value: 0.4405594405594406 and parameters: {'n_estimators': 8960, 'learning_rate': 0.008343070120065698, 'max_depth': 3, 'min_child_weight': 31, 'subsample': 0.5634597850544961, 'colsample_bytree': 0.5812302643808414, 'colsample_bylevel': 0.6086217404080451, 'colsample_bynode': 0.8983441915668249, 'max_bin': 146, 'gamma': 5.251054584260409, 'reg_alpha': 27.152390554245507, 'reg_lambda': 30.047457034246992, 'max_delta_step': 10, 'grow_policy': 'depthwise'}. Best is trial 4 with value: 0.5730659025787965.
# [I 2026-01-28 19:57:26,581] Trial 17 finished with value: 0.5792682926829268 and parameters: {'n_estimators': 5873, 'learning_rate': 0.07391443800848953, 'max_depth': 6, 'min_child_weight': 11, 'subsample': 0.5858413918302636, 'colsample_bytree': 0.8384424332908884, 'colsample_bylevel': 0.6880043851713546, 'colsample_bynode': 0.7345803873541084, 'max_bin': 216, 'gamma': 7.6622046480979265, 'reg_alpha': 20.752329607126697, 'reg_lambda': 21.38042011457902, 'max_delta_step': 9, 'grow_policy': 'depthwise'}. Best is trial 17 with value: 0.5792682926829268.
# [I 2026-01-28 19:57:43,423] Trial 18 finished with value: 0.5641025641025641 and parameters: {'n_estimators': 6943, 'learning_rate': 0.04694301094870814, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.5859303345233259, 'colsample_bytree': 0.7552266993125963, 'colsample_bylevel': 0.6641931924902388, 'colsample_bynode': 0.7159675702258209, 'max_bin': 151, 'gamma': 6.46106179898597, 'reg_alpha': 11.827309749069418, 'reg_lambda': 16.0441476478993, 'max_delta_step': 10, 'grow_policy': 'depthwise'}. Best is trial 17 with value: 0.5792682926829268.
# [I 2026-01-28 19:58:00,887] Trial 19 finished with value: 0.5135802469135803 and parameters: {'n_estimators': 7859, 'learning_rate': 0.04015434836079196, 'max_depth': 9, 'min_child_weight': 29, 'subsample': 0.6422851175333294, 'colsample_bytree': 0.5880142826432389, 'colsample_bylevel': 0.6658798202645949, 'colsample_bynode': 0.6607021622464584, 'max_bin': 277, 'gamma': 0.18655201148440081, 'reg_alpha': 27.465989447486223, 'reg_lambda': 27.885122699714884, 'max_delta_step': 9, 'grow_policy': 'depthwise'}. Best is trial 17 with value: 0.5792682926829268.
# [I 2026-01-28 19:58:22,070] Trial 20 finished with value: 0.5349544072948328 and parameters: {'n_estimators': 5708, 'learning_rate': 0.032098192961964, 'max_depth': 3, 'min_child_weight': 14, 'subsample': 0.6028568794934479, 'colsample_bytree': 0.7463099403529541, 'colsample_bylevel': 0.7612860334963043, 'colsample_bynode': 0.704095120965518, 'max_bin': 281, 'gamma': 9.787919728335078, 'reg_alpha': 26.684480378586485, 'reg_lambda': 41.86223899166346, 'max_delta_step': 8, 'grow_policy': 'depthwise'}. Best is trial 17 with value: 0.5792682926829268.
# [I 2026-01-28 19:58:54,410] Trial 21 finished with value: 0.5384615384615384 and parameters: {'n_estimators': 7819, 'learning_rate': 0.010299318828340892, 'max_depth': 7, 'min_child_weight': 18, 'subsample': 0.7974120571109762, 'colsample_bytree': 0.9671882885534074, 'colsample_bylevel': 0.734519172060639, 'colsample_bynode': 0.7744595108180197, 'max_bin': 198, 'gamma': 11.571650982590523, 'reg_alpha': 27.92676071390872, 'reg_lambda': 8.206935213998113, 'max_delta_step': 9, 'grow_policy': 'depthwise'}. Best is trial 17 with value: 0.5792682926829268.
# [I 2026-01-28 19:59:25,864] Trial 22 finished with value: 0.5483870967741935 and parameters: {'n_estimators': 5840, 'learning_rate': 0.014597564551254601, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.6060417912429151, 'colsample_bytree': 0.8325222192753863, 'colsample_bylevel': 0.7066064546103286, 'colsample_bynode': 0.9731975368892601, 'max_bin': 183, 'gamma': 4.095292179880049, 'reg_alpha': 23.527363247684406, 'reg_lambda': 39.837854471626805, 'max_delta_step': 10, 'grow_policy': 'depthwise'}. Best is trial 17 with value: 0.5792682926829268.
# [I 2026-01-28 19:59:41,802] Trial 23 finished with value: 0.5574712643678161 and parameters: {'n_estimators': 5513, 'learning_rate': 0.05816708166314894, 'max_depth': 7, 'min_child_weight': 11, 'subsample': 0.6422934276827138, 'colsample_bytree': 0.6868116236668712, 'colsample_bylevel': 0.7512254186195264, 'colsample_bynode': 0.652034253933336, 'max_bin': 203, 'gamma': 8.368481989467112, 'reg_alpha': 20.960266055387898, 'reg_lambda': 15.241069072768283, 'max_delta_step': 8, 'grow_policy': 'depthwise'}. Best is trial 17 with value: 0.5792682926829268.
# [I 2026-01-28 20:00:01,782] Trial 24 finished with value: 0.5517241379310345 and parameters: {'n_estimators': 7667, 'learning_rate': 0.02276667993599959, 'max_depth': 4, 'min_child_weight': 15, 'subsample': 0.5809115808124352, 'colsample_bytree': 0.6777241888563287, 'colsample_bylevel': 0.7509524342408602, 'colsample_bynode': 0.688036344784237, 'max_bin': 176, 'gamma': 4.852586420573151, 'reg_alpha': 5.182712455646718, 'reg_lambda': 12.086966621953877, 'max_delta_step': 9, 'grow_policy': 'depthwise'}. Best is trial 17 with value: 0.5792682926829268.
# [I 2026-01-28 20:00:17,539] Trial 25 finished with value: 0.5678233438485805 and parameters: {'n_estimators': 7331, 'learning_rate': 0.06930343390430242, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.5853022863058912, 'colsample_bytree': 0.7949846396795635, 'colsample_bylevel': 0.7344274509859318, 'colsample_bynode': 0.7211649121129066, 'max_bin': 232, 'gamma': 10.377188686210172, 'reg_alpha': 6.601116733403317, 'reg_lambda': 40.138507824057626, 'max_delta_step': 9, 'grow_policy': 'depthwise'}. Best is trial 17 with value: 0.5792682926829268.
# [I 2026-01-28 20:00:35,844] Trial 26 finished with value: 0.5862068965517241 and parameters: {'n_estimators': 8730, 'learning_rate': 0.04212253657208909, 'max_depth': 6, 'min_child_weight': 21, 'subsample': 0.6529071458109945, 'colsample_bytree': 0.9152693900764671, 'colsample_bylevel': 0.9116154598616543, 'colsample_bynode': 0.834046516286842, 'max_bin': 190, 'gamma': 11.207640130879533, 'reg_alpha': 8.215691735733655, 'reg_lambda': 38.85848119922468, 'max_delta_step': 7, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:01:07,642] Trial 27 finished with value: 0.5514950166112956 and parameters: {'n_estimators': 7338, 'learning_rate': 0.01773408664902843, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.7159345849959484, 'colsample_bytree': 0.9180576531489248, 'colsample_bylevel': 0.9242206836605714, 'colsample_bynode': 0.8047634977338118, 'max_bin': 219, 'gamma': 10.706121458132548, 'reg_alpha': 4.178011824251304, 'reg_lambda': 43.481103327876816, 'max_delta_step': 8, 'grow_policy': 'lossguide', 'max_leaves': 214}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:01:25,061] Trial 28 finished with value: 0.5351170568561873 and parameters: {'n_estimators': 8766, 'learning_rate': 0.07045230871741351, 'max_depth': 8, 'min_child_weight': 14, 'subsample': 0.5525685434686916, 'colsample_bytree': 0.907795790543531, 'colsample_bylevel': 0.9527143500258699, 'colsample_bynode': 0.7262654555751247, 'max_bin': 229, 'gamma': 7.067706933315864, 'reg_alpha': 14.480865325568207, 'reg_lambda': 32.81817806840355, 'max_delta_step': 4, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:01:52,853] Trial 29 finished with value: 0.4385026737967914 and parameters: {'n_estimators': 13790, 'learning_rate': 0.013882487011586528, 'max_depth': 6, 'min_child_weight': 22, 'subsample': 0.6549321486748416, 'colsample_bytree': 0.9052124594810602, 'colsample_bylevel': 0.9083478830070224, 'colsample_bynode': 0.9416942546422884, 'max_bin': 255, 'gamma': 9.199234119469848, 'reg_alpha': 11.607879784541531, 'reg_lambda': 40.50063241554769, 'max_delta_step': 9, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:02:13,359] Trial 30 finished with value: 0.5073746312684366 and parameters: {'n_estimators': 10036, 'learning_rate': 0.0474698525572672, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.539814155445741, 'colsample_bytree': 0.89354425406145, 'colsample_bylevel': 0.6413842524163279, 'colsample_bynode': 0.835279384158754, 'max_bin': 202, 'gamma': 3.38289079587249, 'reg_alpha': 31.513870804155673, 'reg_lambda': 16.87784561997438, 'max_delta_step': 6, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:02:33,642] Trial 31 finished with value: 0.5288753799392097 and parameters: {'n_estimators': 8084, 'learning_rate': 0.0270190557484086, 'max_depth': 8, 'min_child_weight': 41, 'subsample': 0.8452658465288624, 'colsample_bytree': 0.7762644411642176, 'colsample_bylevel': 0.9367460292010604, 'colsample_bynode': 0.7804994891693914, 'max_bin': 150, 'gamma': 10.298722351691554, 'reg_alpha': 14.469501610212232, 'reg_lambda': 38.50742408443201, 'max_delta_step': 7, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:02:54,959] Trial 32 finished with value: 0.5212464589235127 and parameters: {'n_estimators': 5995, 'learning_rate': 0.017796792934374576, 'max_depth': 6, 'min_child_weight': 34, 'subsample': 0.5167991717864283, 'colsample_bytree': 0.9398508644393875, 'colsample_bylevel': 0.9643145565521534, 'colsample_bynode': 0.7690250681792699, 'max_bin': 241, 'gamma': 8.29162772839263, 'reg_alpha': 5.447024451020685, 'reg_lambda': 34.22185173228792, 'max_delta_step': 10, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:03:12,526] Trial 33 finished with value: 0.5314285714285715 and parameters: {'n_estimators': 1576, 'learning_rate': 0.0707057280665537, 'max_depth': 6, 'min_child_weight': 10, 'subsample': 0.618090274348947, 'colsample_bytree': 0.8618464973727724, 'colsample_bylevel': 0.6922360494412804, 'colsample_bynode': 0.7124321229310373, 'max_bin': 334, 'gamma': 9.836849367762362, 'reg_alpha': 7.19411881591488, 'reg_lambda': 42.61397325514078, 'max_delta_step': 6, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:03:29,542] Trial 34 finished with value: 0.5345345345345346 and parameters: {'n_estimators': 11236, 'learning_rate': 0.05902947995945586, 'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.6628567177930573, 'colsample_bytree': 0.6698479923041676, 'colsample_bylevel': 0.747382073115653, 'colsample_bynode': 0.6572629967813599, 'max_bin': 204, 'gamma': 10.234004864338718, 'reg_alpha': 7.268421954908203, 'reg_lambda': 47.0465971913827, 'max_delta_step': 10, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:03:46,328] Trial 35 finished with value: 0.5658263305322129 and parameters: {'n_estimators': 7164, 'learning_rate': 0.07564151482243746, 'max_depth': 6, 'min_child_weight': 25, 'subsample': 0.5284783822854833, 'colsample_bytree': 0.8939138754403424, 'colsample_bylevel': 0.7100846203758978, 'colsample_bynode': 0.8462036805998396, 'max_bin': 253, 'gamma': 6.550410453604234, 'reg_alpha': 24.511466723501155, 'reg_lambda': 35.11968013046757, 'max_delta_step': 6, 'grow_policy': 'lossguide', 'max_leaves': 361}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:04:00,009] Trial 36 finished with value: 0.5800604229607251 and parameters: {'n_estimators': 7677, 'learning_rate': 0.07234108646308982, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.5425690143402061, 'colsample_bytree': 0.653300434744048, 'colsample_bylevel': 0.6880651942122308, 'colsample_bynode': 0.6443062336091151, 'max_bin': 198, 'gamma': 11.504800244956652, 'reg_alpha': 7.433373060117677, 'reg_lambda': 35.63309852379058, 'max_delta_step': 8, 'grow_policy': 'lossguide', 'max_leaves': 176}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:04:19,689] Trial 37 finished with value: 0.5386666666666666 and parameters: {'n_estimators': 11580, 'learning_rate': 0.022150489471214486, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.5418128712512904, 'colsample_bytree': 0.5348857146249528, 'colsample_bylevel': 0.5266871160072175, 'colsample_bynode': 0.5823912588130206, 'max_bin': 221, 'gamma': 10.795768472588021, 'reg_alpha': 8.07825755519391, 'reg_lambda': 37.29281824416588, 'max_delta_step': 4, 'grow_policy': 'lossguide', 'max_leaves': 178}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:04:39,430] Trial 38 finished with value: 0.5407166123778502 and parameters: {'n_estimators': 6771, 'learning_rate': 0.04253318228188994, 'max_depth': 10, 'min_child_weight': 3, 'subsample': 0.5403228318794271, 'colsample_bytree': 0.58106675501379, 'colsample_bylevel': 0.580298218996011, 'colsample_bynode': 0.7188666465362343, 'max_bin': 170, 'gamma': 9.162511596388182, 'reg_alpha': 3.0211643385201743, 'reg_lambda': 27.817229391131583, 'max_delta_step': 10, 'grow_policy': 'lossguide', 'max_leaves': 181}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:04:55,325] Trial 39 finished with value: 0.5634674922600619 and parameters: {'n_estimators': 8022, 'learning_rate': 0.041662248183566356, 'max_depth': 4, 'min_child_weight': 20, 'subsample': 0.5336042748455982, 'colsample_bytree': 0.6680618413721632, 'colsample_bylevel': 0.6862442700354606, 'colsample_bynode': 0.5250805237255244, 'max_bin': 170, 'gamma': 9.293996404709482, 'reg_alpha': 10.633973488676567, 'reg_lambda': 27.119942557121057, 'max_delta_step': 8, 'grow_policy': 'lossguide', 'max_leaves': 317}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:05:11,054] Trial 40 finished with value: 0.5587301587301587 and parameters: {'n_estimators': 8687, 'learning_rate': 0.057460992848182284, 'max_depth': 5, 'min_child_weight': 29, 'subsample': 0.6179377582331051, 'colsample_bytree': 0.8440477067365678, 'colsample_bylevel': 0.7196302721132737, 'colsample_bynode': 0.7576413290319506, 'max_bin': 187, 'gamma': 8.9188990150442, 'reg_alpha': 31.91397833975294, 'reg_lambda': 26.03735350032841, 'max_delta_step': 10, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:05:27,318] Trial 41 finished with value: 0.5714285714285714 and parameters: {'n_estimators': 9995, 'learning_rate': 0.07435312348223104, 'max_depth': 6, 'min_child_weight': 18, 'subsample': 0.5451376620286718, 'colsample_bytree': 0.5833645403862581, 'colsample_bylevel': 0.6753269015757108, 'colsample_bynode': 0.7583394501307459, 'max_bin': 279, 'gamma': 10.316816559881962, 'reg_alpha': 11.769743699325346, 'reg_lambda': 32.59511213263587, 'max_delta_step': 5, 'grow_policy': 'lossguide', 'max_leaves': 154}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:05:48,887] Trial 42 finished with value: 0.5561797752808989 and parameters: {'n_estimators': 5960, 'learning_rate': 0.02844736972006499, 'max_depth': 9, 'min_child_weight': 17, 'subsample': 0.5253623211544578, 'colsample_bytree': 0.5066152860186581, 'colsample_bylevel': 0.642382625055683, 'colsample_bynode': 0.89134924383859, 'max_bin': 233, 'gamma': 1.6183697279647355, 'reg_alpha': 25.344967646721283, 'reg_lambda': 23.1721055575556, 'max_delta_step': 9, 'grow_policy': 'lossguide', 'max_leaves': 18}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:05:54,838] Trial 43 pruned.
# [I 2026-01-28 20:06:12,764] Trial 44 finished with value: 0.5611111111111111 and parameters: {'n_estimators': 11565, 'learning_rate': 0.045900952408344464, 'max_depth': 5, 'min_child_weight': 42, 'subsample': 0.5403498487759204, 'colsample_bytree': 0.6370076446905136, 'colsample_bylevel': 0.6632189088196317, 'colsample_bynode': 0.7551217593891844, 'max_bin': 449, 'gamma': 9.587591244413712, 'reg_alpha': 11.048476621582582, 'reg_lambda': 37.79315696520828, 'max_delta_step': 4, 'grow_policy': 'lossguide', 'max_leaves': 160}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:06:31,856] Trial 45 finished with value: 0.5114754098360655 and parameters: {'n_estimators': 4953, 'learning_rate': 0.0341566949736628, 'max_depth': 8, 'min_child_weight': 25, 'subsample': 0.5477837585016432, 'colsample_bytree': 0.5156308418089144, 'colsample_bylevel': 0.7041303133811926, 'colsample_bynode': 0.9746888349221932, 'max_bin': 274, 'gamma': 6.9631090816112255, 'reg_alpha': 34.12802261167974, 'reg_lambda': 32.58067585975053, 'max_delta_step': 9, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:06:47,182] Trial 46 finished with value: 0.4789356984478936 and parameters: {'n_estimators': 11402, 'learning_rate': 0.048202569778601954, 'max_depth': 6, 'min_child_weight': 57, 'subsample': 0.6235462114062424, 'colsample_bytree': 0.8793664510005339, 'colsample_bylevel': 0.7497786127133567, 'colsample_bynode': 0.8680175086403442, 'max_bin': 223, 'gamma': 10.310000705001189, 'reg_alpha': 9.254005687962346, 'reg_lambda': 46.59626418934199, 'max_delta_step': 3, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:07:04,388] Trial 47 finished with value: 0.5754985754985755 and parameters: {'n_estimators': 9452, 'learning_rate': 0.066658100308184, 'max_depth': 6, 'min_child_weight': 20, 'subsample': 0.5933348046638721, 'colsample_bytree': 0.9607892024760626, 'colsample_bylevel': 0.9405425357520449, 'colsample_bynode': 0.9986542102902108, 'max_bin': 179, 'gamma': 11.045168835917877, 'reg_alpha': 5.53455531939709, 'reg_lambda': 41.75863341696033, 'max_delta_step': 6, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:07:23,622] Trial 48 finished with value: 0.5570469798657718 and parameters: {'n_estimators': 6774, 'learning_rate': 0.0609620168960083, 'max_depth': 6, 'min_child_weight': 20, 'subsample': 0.529248019031581, 'colsample_bytree': 0.9433910485576372, 'colsample_bylevel': 0.9448593967157154, 'colsample_bynode': 0.9807541457824163, 'max_bin': 216, 'gamma': 9.600300115827075, 'reg_alpha': 5.687309300569337, 'reg_lambda': 44.27556241078249, 'max_delta_step': 1, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:07:41,469] Trial 49 finished with value: 0.5626911314984709 and parameters: {'n_estimators': 10856, 'learning_rate': 0.06093156614028576, 'max_depth': 6, 'min_child_weight': 26, 'subsample': 0.713533830667215, 'colsample_bytree': 0.9694216633988272, 'colsample_bylevel': 0.8387643591146459, 'colsample_bynode': 0.9952667245349728, 'max_bin': 194, 'gamma': 10.322062233752042, 'reg_alpha': 2.237567337631659, 'reg_lambda': 48.7858442226026, 'max_delta_step': 7, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:07:57,044] Trial 50 finished with value: 0.5795454545454546 and parameters: {'n_estimators': 6463, 'learning_rate': 0.07394503567065816, 'max_depth': 6, 'min_child_weight': 23, 'subsample': 0.57846558702808, 'colsample_bytree': 0.6239163684177573, 'colsample_bylevel': 0.810212439869563, 'colsample_bynode': 0.5892871101462511, 'max_bin': 243, 'gamma': 11.490382694567593, 'reg_alpha': 3.102764553222352, 'reg_lambda': 38.71292822837213, 'max_delta_step': 7, 'grow_policy': 'lossguide', 'max_leaves': 289}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:08:12,187] Trial 51 finished with value: 0.5472972972972973 and parameters: {'n_estimators': 6951, 'learning_rate': 0.07316887843756195, 'max_depth': 7, 'min_child_weight': 37, 'subsample': 0.5097444110373239, 'colsample_bytree': 0.5356754027786415, 'colsample_bylevel': 0.837777310578558, 'colsample_bynode': 0.6164272339079531, 'max_bin': 218, 'gamma': 9.910358310192548, 'reg_alpha': 3.6852570320808287, 'reg_lambda': 36.826194032482036, 'max_delta_step': 9, 'grow_policy': 'lossguide', 'max_leaves': 303}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:08:28,586] Trial 52 finished with value: 0.5802469135802469 and parameters: {'n_estimators': 4967, 'learning_rate': 0.04826778446024511, 'max_depth': 5, 'min_child_weight': 18, 'subsample': 0.5870683741636522, 'colsample_bytree': 0.6231058146467436, 'colsample_bylevel': 0.6487144468761673, 'colsample_bynode': 0.7246738299292895, 'max_bin': 179, 'gamma': 10.431027365784773, 'reg_alpha': 1.5081578542975853, 'reg_lambda': 46.93570020633763, 'max_delta_step': 6, 'grow_policy': 'lossguide', 'max_leaves': 368}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:08:51,669] Trial 53 finished with value: 0.541095890410959 and parameters: {'n_estimators': 4063, 'learning_rate': 0.018442631512087172, 'max_depth': 4, 'min_child_weight': 21, 'subsample': 0.6183410355725515, 'colsample_bytree': 0.4090980957813406, 'colsample_bylevel': 0.661912668969388, 'colsample_bynode': 0.6276168232809962, 'max_bin': 228, 'gamma': 7.020095480601183, 'reg_alpha': 4.153119936531885, 'reg_lambda': 45.434757073419014, 'max_delta_step': 8, 'grow_policy': 'lossguide', 'max_leaves': 373}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:09:15,523] Trial 54 finished with value: 0.5214521452145214 and parameters: {'n_estimators': 3399, 'learning_rate': 0.018120481728200914, 'max_depth': 7, 'min_child_weight': 14, 'subsample': 0.6037894694372014, 'colsample_bytree': 0.5815542801006826, 'colsample_bylevel': 0.6759002304438056, 'colsample_bynode': 0.868919253690553, 'max_bin': 157, 'gamma': 10.973235960342906, 'reg_alpha': 7.749741648877853, 'reg_lambda': 40.19925163181518, 'max_delta_step': 7, 'grow_policy': 'lossguide', 'max_leaves': 373}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:09:37,355] Trial 55 finished with value: 0.5612903225806452 and parameters: {'n_estimators': 5896, 'learning_rate': 0.03280245666207137, 'max_depth': 7, 'min_child_weight': 26, 'subsample': 0.6835239267133235, 'colsample_bytree': 0.9093987640417487, 'colsample_bylevel': 0.8854205266889758, 'colsample_bynode': 0.8230186467182252, 'max_bin': 232, 'gamma': 10.716664991486512, 'reg_alpha': 2.101646681297353, 'reg_lambda': 30.648642766882418, 'max_delta_step': 5, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:09:53,364] Trial 56 finished with value: 0.5808580858085809 and parameters: {'n_estimators': 4742, 'learning_rate': 0.0703058366930069, 'max_depth': 6, 'min_child_weight': 18, 'subsample': 0.6311325346943308, 'colsample_bytree': 0.8005338360489608, 'colsample_bylevel': 0.8589225650301141, 'colsample_bynode': 0.5557265249708421, 'max_bin': 313, 'gamma': 11.856266292966556, 'reg_alpha': 3.912747464131654, 'reg_lambda': 19.901012180839977, 'max_delta_step': 9, 'grow_policy': 'lossguide', 'max_leaves': 261}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:10:11,822] Trial 57 finished with value: 0.554016620498615 and parameters: {'n_estimators': 3802, 'learning_rate': 0.07287409954472794, 'max_depth': 7, 'min_child_weight': 23, 'subsample': 0.646421341588747, 'colsample_bytree': 0.9147515537065991, 'colsample_bylevel': 0.9908780789115819, 'colsample_bynode': 0.5581782695800712, 'max_bin': 327, 'gamma': 10.24637146482384, 'reg_alpha': 5.998717734107071, 'reg_lambda': 5.371568379890908, 'max_delta_step': 8, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:10:17,822] Trial 58 pruned.
# [I 2026-01-28 20:10:33,558] Trial 59 finished with value: 0.5690140845070423 and parameters: {'n_estimators': 5313, 'learning_rate': 0.05520579256996283, 'max_depth': 6, 'min_child_weight': 38, 'subsample': 0.7701979671668471, 'colsample_bytree': 0.7840113058987593, 'colsample_bylevel': 0.8419540523952728, 'colsample_bynode': 0.5894160059614189, 'max_bin': 173, 'gamma': 7.945893055914819, 'reg_alpha': 0.16493579824362437, 'reg_lambda': 18.911081250957054, 'max_delta_step': 7, 'grow_policy': 'lossguide', 'max_leaves': 249}. Best is trial 26 with value: 0.5862068965517241.
# [I 2026-01-28 20:10:50,833] Trial 60 finished with value: 0.5878594249201278 and parameters: {'n_estimators': 4656, 'learning_rate': 0.07504609107083031, 'max_depth': 4, 'min_child_weight': 23, 'subsample': 0.5994177160226121, 'colsample_bytree': 0.9643560253113882, 'colsample_bylevel': 0.6038833845324858, 'colsample_bynode': 0.6781143305862798, 'max_bin': 346, 'gamma': 5.193131710629315, 'reg_alpha': 17.026093980094572, 'reg_lambda': 23.55953150244973, 'max_delta_step': 8, 'grow_policy': 'depthwise'}. Best is trial 60 with value: 0.5878594249201278.
# [I 2026-01-28 20:11:06,653] Trial 61 finished with value: 0.5597269624573379 and parameters: {'n_estimators': 4922, 'learning_rate': 0.027089296413230542, 'max_depth': 2, 'min_child_weight': 8, 'subsample': 0.7437772452570413, 'colsample_bytree': 0.9646002741261734, 'colsample_bylevel': 0.6797328546684055, 'colsample_bynode': 0.7085085017889392, 'max_bin': 262, 'gamma': 4.569817925247048, 'reg_alpha': 9.247247027558874, 'reg_lambda': 28.009979643550555, 'max_delta_step': 3, 'grow_policy': 'depthwise'}. Best is trial 60 with value: 0.5878594249201278.
# [I 2026-01-28 20:11:21,565] Trial 62 finished with value: 0.5595238095238095 and parameters: {'n_estimators': 6564, 'learning_rate': 0.06764110214982921, 'max_depth': 4, 'min_child_weight': 13, 'subsample': 0.5752562297848292, 'colsample_bytree': 0.7162048735355717, 'colsample_bylevel': 0.5438910504224282, 'colsample_bynode': 0.7208739101593032, 'max_bin': 136, 'gamma': 11.278996029452665, 'reg_alpha': 9.001305493246903, 'reg_lambda': 43.768189487735896, 'max_delta_step': 5, 'grow_policy': 'lossguide', 'max_leaves': 262}. Best is trial 60 with value: 0.5878594249201278.
# [I 2026-01-28 20:11:45,532] Trial 63 finished with value: 0.5681818181818182 and parameters: {'n_estimators': 5615, 'learning_rate': 0.052659814403593595, 'max_depth': 6, 'min_child_weight': 19, 'subsample': 0.6511189582236899, 'colsample_bytree': 0.9600601544681167, 'colsample_bylevel': 0.5419695942607166, 'colsample_bynode': 0.6179705357959556, 'max_bin': 399, 'gamma': 3.4387142773850687, 'reg_alpha': 13.795877001999227, 'reg_lambda': 21.485612010538304, 'max_delta_step': 9, 'grow_policy': 'depthwise'}. Best is trial 60 with value: 0.5878594249201278.
# [I 2026-01-28 20:11:59,769] Trial 64 finished with value: 0.5653710247349824 and parameters: {'n_estimators': 8011, 'learning_rate': 0.061972553100488464, 'max_depth': 3, 'min_child_weight': 22, 'subsample': 0.595813592779185, 'colsample_bytree': 0.5769306387347798, 'colsample_bylevel': 0.8192503486107409, 'colsample_bynode': 0.6773743054360476, 'max_bin': 244, 'gamma': 9.95877925522272, 'reg_alpha': 1.9565210020112436, 'reg_lambda': 44.35624564664229, 'max_delta_step': 4, 'grow_policy': 'lossguide', 'max_leaves': 368}. Best is trial 60 with value: 0.5878594249201278.
# [I 2026-01-28 20:12:04,741] Trial 65 pruned.
# [I 2026-01-28 20:12:21,297] Trial 66 finished with value: 0.5523255813953488 and parameters: {'n_estimators': 5135, 'learning_rate': 0.03824302261858294, 'max_depth': 8, 'min_child_weight': 50, 'subsample': 0.6378176460845326, 'colsample_bytree': 0.8624827718811964, 'colsample_bylevel': 0.6497129106380696, 'colsample_bynode': 0.5128440720420571, 'max_bin': 342, 'gamma': 9.975145442325834, 'reg_alpha': 11.384913251184894, 'reg_lambda': 6.379658885638964, 'max_delta_step': 9, 'grow_policy': 'lossguide', 'max_leaves': 269}. Best is trial 60 with value: 0.5878594249201278.
# [I 2026-01-28 20:12:38,157] Trial 67 finished with value: 0.5836298932384342 and parameters: {'n_estimators': 2981, 'learning_rate': 0.07007445486452911, 'max_depth': 7, 'min_child_weight': 19, 'subsample': 0.6974855620128011, 'colsample_bytree': 0.6673122886543369, 'colsample_bylevel': 0.5802182519643331, 'colsample_bynode': 0.705811476341399, 'max_bin': 255, 'gamma': 8.071850045061428, 'reg_alpha': 0.8780615619165877, 'reg_lambda': 44.724644265349454, 'max_delta_step': 7, 'grow_policy': 'lossguide', 'max_leaves': 404}. Best is trial 60 with value: 0.5878594249201278.
# [I 2026-01-28 20:13:03,447] Trial 68 finished with value: 0.5723684210526315 and parameters: {'n_estimators': 8736, 'learning_rate': 0.032424284572954154, 'max_depth': 6, 'min_child_weight': 14, 'subsample': 0.8995839442407827, 'colsample_bytree': 0.5002308331217152, 'colsample_bylevel': 0.57460459436748, 'colsample_bynode': 0.7500878061764549, 'max_bin': 283, 'gamma': 5.008179060423235, 'reg_alpha': 8.127914231852127, 'reg_lambda': 37.664549234638834, 'max_delta_step': 7, 'grow_policy': 'lossguide', 'max_leaves': 412}. Best is trial 60 with value: 0.5878594249201278.
# [I 2026-01-28 20:13:23,800] Trial 69 finished with value: 0.5464190981432361 and parameters: {'n_estimators': 2824, 'learning_rate': 0.04641723054760029, 'max_depth': 8, 'min_child_weight': 20, 'subsample': 0.6933753539425169, 'colsample_bytree': 0.6997270292307818, 'colsample_bylevel': 0.5221353687473217, 'colsample_bynode': 0.8523429826434625, 'max_bin': 331, 'gamma': 7.85926674918169, 'reg_alpha': 2.4726954153912435, 'reg_lambda': 49.32948812127301, 'max_delta_step': 8, 'grow_policy': 'lossguide', 'max_leaves': 419}. Best is trial 60 with value: 0.5878594249201278.
# [I 2026-01-28 20:13:43,588] Trial 70 finished with value: 0.5360230547550432 and parameters: {'n_estimators': 1635, 'learning_rate': 0.035641144577160326, 'max_depth': 7, 'min_child_weight': 7, 'subsample': 0.8108379706052873, 'colsample_bytree': 0.7329532190773236, 'colsample_bylevel': 0.6230355072294574, 'colsample_bynode': 0.5592931081840826, 'max_bin': 186, 'gamma': 9.58021919737883, 'reg_alpha': 7.8959743645859986, 'reg_lambda': 31.22331259046018, 'max_delta_step': 6, 'grow_policy': 'lossguide', 'max_leaves': 407}. Best is trial 60 with value: 0.5878594249201278.
# [I 2026-01-28 20:13:59,045] Trial 71 finished with value: 0.5307443365695793 and parameters: {'n_estimators': 2956, 'learning_rate': 0.07859818147992428, 'max_depth': 2, 'min_child_weight': 19, 'subsample': 0.63161535068442, 'colsample_bytree': 0.7808747861886921, 'colsample_bylevel': 0.548617565961566, 'colsample_bynode': 0.7925413416960857, 'max_bin': 380, 'gamma': 5.841693601606196, 'reg_alpha': 25.92918732230529, 'reg_lambda': 2.140201092822039, 'max_delta_step': 7, 'grow_policy': 'depthwise'}. Best is trial 60 with value: 0.5878594249201278.
# [I 2026-01-28 20:14:13,922] Trial 72 finished with value: 0.5531914893617021 and parameters: {'n_estimators': 2485, 'learning_rate': 0.0599687329183377, 'max_depth': 5, 'min_child_weight': 26, 'subsample': 0.6756123418127935, 'colsample_bytree': 0.7685520929723362, 'colsample_bylevel': 0.8050880932979576, 'colsample_bynode': 0.5971428956401257, 'max_bin': 173, 'gamma': 8.668510907099362, 'reg_alpha': 2.8779525499197405, 'reg_lambda': 47.83432691523867, 'max_delta_step': 6, 'grow_policy': 'lossguide', 'max_leaves': 309}. Best is trial 60 with value: 0.5878594249201278.
# [I 2026-01-28 20:14:31,745] Trial 73 finished with value: 0.5909090909090909 and parameters: {'n_estimators': 7979, 'learning_rate': 0.06998537722427427, 'max_depth': 8, 'min_child_weight': 23, 'subsample': 0.5583131541953514, 'colsample_bytree': 0.9463263289174205, 'colsample_bylevel': 0.889359381231571, 'colsample_bynode': 0.6094642935549288, 'max_bin': 348, 'gamma': 9.423614869973749, 'reg_alpha': 8.467831015389837, 'reg_lambda': 21.834845992064334, 'max_delta_step': 9, 'grow_policy': 'lossguide', 'max_leaves': 397}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:14:56,931] Trial 74 finished with value: 0.5755395683453237 and parameters: {'n_estimators': 7738, 'learning_rate': 0.028689291327839515, 'max_depth': 9, 'min_child_weight': 14, 'subsample': 0.5166799963945806, 'colsample_bytree': 0.8665951106063888, 'colsample_bylevel': 0.7940104325715852, 'colsample_bynode': 0.7394002637044723, 'max_bin': 380, 'gamma': 7.284620497946048, 'reg_alpha': 9.45992938920272, 'reg_lambda': 17.386148287688506, 'max_delta_step': 10, 'grow_policy': 'lossguide', 'max_leaves': 426}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:15:20,065] Trial 75 finished with value: 0.5481927710843374 and parameters: {'n_estimators': 4820, 'learning_rate': 0.02863897701546216, 'max_depth': 5, 'min_child_weight': 26, 'subsample': 0.7188222246610526, 'colsample_bytree': 0.9376670126382783, 'colsample_bylevel': 0.6060289223018523, 'colsample_bynode': 0.7017778890063181, 'max_bin': 267, 'gamma': 6.491434982533453, 'reg_alpha': 17.665038483720284, 'reg_lambda': 22.47385727100849, 'max_delta_step': 8, 'grow_policy': 'lossguide', 'max_leaves': 448}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:15:41,327] Trial 76 finished with value: 0.5460750853242321 and parameters: {'n_estimators': 4854, 'learning_rate': 0.05909248989234306, 'max_depth': 4, 'min_child_weight': 27, 'subsample': 0.7282194135409554, 'colsample_bytree': 0.8904226352321978, 'colsample_bylevel': 0.661538781571222, 'colsample_bynode': 0.9796375135366955, 'max_bin': 435, 'gamma': 5.88889393594724, 'reg_alpha': 10.906635165853418, 'reg_lambda': 29.4149077258733, 'max_delta_step': 7, 'grow_policy': 'depthwise'}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:15:47,613] Trial 77 pruned.
# [I 2026-01-28 20:15:54,519] Trial 78 pruned.
# [I 2026-01-28 20:16:12,390] Trial 79 finished with value: 0.54 and parameters: {'n_estimators': 2079, 'learning_rate': 0.05583803221018886, 'max_depth': 4, 'min_child_weight': 35, 'subsample': 0.6596889258540238, 'colsample_bytree': 0.981756083588887, 'colsample_bylevel': 0.7987374746235438, 'colsample_bynode': 0.6507154007841329, 'max_bin': 303, 'gamma': 4.4022366031148, 'reg_alpha': 6.352513824924527, 'reg_lambda': 18.07388914846262, 'max_delta_step': 8, 'grow_policy': 'depthwise'}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:16:21,985] Trial 80 pruned.
# [I 2026-01-28 20:16:37,675] Trial 81 finished with value: 0.5459317585301837 and parameters: {'n_estimators': 2318, 'learning_rate': 0.0561461968765011, 'max_depth': 4, 'min_child_weight': 15, 'subsample': 0.5531314922234261, 'colsample_bytree': 0.6957292654630578, 'colsample_bylevel': 0.6795982610785724, 'colsample_bynode': 0.732625565001783, 'max_bin': 172, 'gamma': 10.055030733556192, 'reg_alpha': 0.08458703585190075, 'reg_lambda': 30.68097719848449, 'max_delta_step': 8, 'grow_policy': 'lossguide', 'max_leaves': 255}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:16:53,320] Trial 82 finished with value: 0.5066666666666667 and parameters: {'n_estimators': 3353, 'learning_rate': 0.047969313243265525, 'max_depth': 3, 'min_child_weight': 37, 'subsample': 0.5469871847121146, 'colsample_bytree': 0.9732958564995224, 'colsample_bylevel': 0.5812756193197346, 'colsample_bynode': 0.580460342218263, 'max_bin': 369, 'gamma': 6.394080428450026, 'reg_alpha': 14.914476621583258, 'reg_lambda': 42.495080711568704, 'max_delta_step': 7, 'grow_policy': 'depthwise'}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:17:10,350] Trial 83 finished with value: 0.5373961218836565 and parameters: {'n_estimators': 11146, 'learning_rate': 0.07885712742842796, 'max_depth': 10, 'min_child_weight': 7, 'subsample': 0.5344401189261881, 'colsample_bytree': 0.9991885554287716, 'colsample_bylevel': 0.8349970103641574, 'colsample_bynode': 0.5542521807230415, 'max_bin': 310, 'gamma': 9.454010511634563, 'reg_alpha': 8.547640460877082, 'reg_lambda': 23.145094928300505, 'max_delta_step': 8, 'grow_policy': 'lossguide', 'max_leaves': 346}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:17:29,878] Trial 84 finished with value: 0.5676392572944297 and parameters: {'n_estimators': 3112, 'learning_rate': 0.07566687227006463, 'max_depth': 10, 'min_child_weight': 14, 'subsample': 0.8148253541721376, 'colsample_bytree': 0.7381877869990889, 'colsample_bylevel': 0.7139906681697252, 'colsample_bynode': 0.6338903772038491, 'max_bin': 215, 'gamma': 3.724479989762801, 'reg_alpha': 0.11525647727836852, 'reg_lambda': 47.638964168040076, 'max_delta_step': 9, 'grow_policy': 'lossguide', 'max_leaves': 238}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:17:36,251] Trial 85 pruned.
# [I 2026-01-28 20:17:54,339] Trial 86 finished with value: 0.524822695035461 and parameters: {'n_estimators': 11988, 'learning_rate': 0.027396444444288372, 'max_depth': 8, 'min_child_weight': 41, 'subsample': 0.5411346024156553, 'colsample_bytree': 0.98002894966635, 'colsample_bylevel': 0.8237933940474039, 'colsample_bynode': 0.666022609932716, 'max_bin': 204, 'gamma': 11.795760797355108, 'reg_alpha': 14.394604146649769, 'reg_lambda': 47.79969534651417, 'max_delta_step': 8, 'grow_policy': 'depthwise'}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:18:12,522] Trial 87 finished with value: 0.5741324921135647 and parameters: {'n_estimators': 1921, 'learning_rate': 0.070298293655958, 'max_depth': 7, 'min_child_weight': 7, 'subsample': 0.7365454917890603, 'colsample_bytree': 0.7279949750888502, 'colsample_bylevel': 0.5251217026284063, 'colsample_bynode': 0.6635180471841354, 'max_bin': 218, 'gamma': 5.652597650023344, 'reg_alpha': 0.6309777650200828, 'reg_lambda': 43.053825769741806, 'max_delta_step': 6, 'grow_policy': 'lossguide', 'max_leaves': 347}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:18:29,218] Trial 88 finished with value: 0.5181347150259067 and parameters: {'n_estimators': 9838, 'learning_rate': 0.05917925585942169, 'max_depth': 5, 'min_child_weight': 18, 'subsample': 0.6220805371906913, 'colsample_bytree': 0.8412472989166656, 'colsample_bylevel': 0.6755482514619985, 'colsample_bynode': 0.6398014063089212, 'max_bin': 217, 'gamma': 10.604290749698725, 'reg_alpha': 6.182774426740969, 'reg_lambda': 42.49113768509158, 'max_delta_step': 9, 'grow_policy': 'lossguide', 'max_leaves': 244}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:18:46,877] Trial 89 finished with value: 0.4891041162227603 and parameters: {'n_estimators': 7287, 'learning_rate': 0.026035069018014514, 'max_depth': 6, 'min_child_weight': 45, 'subsample': 0.6652006133056725, 'colsample_bytree': 0.4750118975591767, 'colsample_bylevel': 0.66175294151503, 'colsample_bynode': 0.7135076147477613, 'max_bin': 142, 'gamma': 10.41959747032047, 'reg_alpha': 4.610208429797625, 'reg_lambda': 48.04100605347262, 'max_delta_step': 5, 'grow_policy': 'lossguide', 'max_leaves': 132}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:19:04,820] Trial 90 finished with value: 0.5760517799352751 and parameters: {'n_estimators': 4453, 'learning_rate': 0.06557095451271466, 'max_depth': 8, 'min_child_weight': 22, 'subsample': 0.6965653844825798, 'colsample_bytree': 0.5737030110352006, 'colsample_bylevel': 0.7087463150330433, 'colsample_bynode': 0.5900135714098443, 'max_bin': 357, 'gamma': 8.073236595579848, 'reg_alpha': 12.800064745453792, 'reg_lambda': 42.88734918722314, 'max_delta_step': 5, 'grow_policy': 'lossguide', 'max_leaves': 396}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:19:24,461] Trial 91 finished with value: 0.5246913580246914 and parameters: {'n_estimators': 7166, 'learning_rate': 0.053280109931746575, 'max_depth': 7, 'min_child_weight': 31, 'subsample': 0.6770352380931246, 'colsample_bytree': 0.9876411672668396, 'colsample_bylevel': 0.7792401248607879, 'colsample_bynode': 0.7836778649392949, 'max_bin': 270, 'gamma': 6.586686545699957, 'reg_alpha': 19.321287560493044, 'reg_lambda': 15.243561917786458, 'max_delta_step': 8, 'grow_policy': 'depthwise'}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:19:45,368] Trial 92 finished with value: 0.5415384615384615 and parameters: {'n_estimators': 6782, 'learning_rate': 0.02722436165683283, 'max_depth': 8, 'min_child_weight': 50, 'subsample': 0.6201559043757707, 'colsample_bytree': 0.9465096638965398, 'colsample_bylevel': 0.9664292895292597, 'colsample_bynode': 0.5119057599019913, 'max_bin': 412, 'gamma': 6.460590577580184, 'reg_alpha': 12.326369004517087, 'reg_lambda': 24.48601826394347, 'max_delta_step': 10, 'grow_policy': 'lossguide', 'max_leaves': 323}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:19:53,115] Trial 93 pruned.
# [I 2026-01-28 20:20:14,488] Trial 94 finished with value: 0.5761772853185596 and parameters: {'n_estimators': 4854, 'learning_rate': 0.05611742658261391, 'max_depth': 7, 'min_child_weight': 24, 'subsample': 0.9193264844637499, 'colsample_bytree': 0.45043013310737534, 'colsample_bylevel': 0.782352298700501, 'colsample_bynode': 0.5150256829102164, 'max_bin': 402, 'gamma': 7.655036831353643, 'reg_alpha': 14.641203247814625, 'reg_lambda': 37.509139651400474, 'max_delta_step': 3, 'grow_policy': 'lossguide', 'max_leaves': 412}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:20:39,639] Trial 95 finished with value: 0.5068493150684932 and parameters: {'n_estimators': 4600, 'learning_rate': 0.029550022730017302, 'max_depth': 9, 'min_child_weight': 43, 'subsample': 0.8506678012278169, 'colsample_bytree': 0.4596298297850488, 'colsample_bylevel': 0.7811669103420307, 'colsample_bynode': 0.5234657846073212, 'max_bin': 439, 'gamma': 11.296120065959949, 'reg_alpha': 10.802181595463445, 'reg_lambda': 22.876634628194047, 'max_delta_step': 3, 'grow_policy': 'lossguide', 'max_leaves': 457}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:21:00,307] Trial 96 finished with value: 0.577639751552795 and parameters: {'n_estimators': 9703, 'learning_rate': 0.06009481064962957, 'max_depth': 7, 'min_child_weight': 35, 'subsample': 0.9116281267688181, 'colsample_bytree': 0.4815599349873097, 'colsample_bylevel': 0.9032164157641804, 'colsample_bynode': 0.5809108455736127, 'max_bin': 328, 'gamma': 6.593603535938921, 'reg_alpha': 14.862633080402556, 'reg_lambda': 35.099000228485174, 'max_delta_step': 4, 'grow_policy': 'lossguide', 'max_leaves': 394}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:21:21,434] Trial 97 finished with value: 0.5607476635514018 and parameters: {'n_estimators': 10450, 'learning_rate': 0.038874024574571245, 'max_depth': 8, 'min_child_weight': 34, 'subsample': 0.8354208871408771, 'colsample_bytree': 0.43428587907178023, 'colsample_bylevel': 0.7955417562657253, 'colsample_bynode': 0.6640622220617439, 'max_bin': 244, 'gamma': 7.74484838968918, 'reg_alpha': 18.96469618756094, 'reg_lambda': 43.80906194404254, 'max_delta_step': 4, 'grow_policy': 'depthwise'}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:21:28,717] Trial 98 pruned.
# [I 2026-01-28 20:21:35,032] Trial 99 pruned.
# [I 2026-01-28 20:21:52,796] Trial 100 finished with value: 0.5868263473053892 and parameters: {'n_estimators': 8370, 'learning_rate': 0.06522715564194817, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.5530906086458299, 'colsample_bytree': 0.5710864441425094, 'colsample_bylevel': 0.7934928532500607, 'colsample_bynode': 0.6014336078661071, 'max_bin': 131, 'gamma': 11.333497394278169, 'reg_alpha': 3.9165767223493377, 'reg_lambda': 37.90130352705121, 'max_delta_step': 7, 'grow_policy': 'lossguide', 'max_leaves': 355}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:22:09,089] Trial 101 finished with value: 0.5612903225806452 and parameters: {'n_estimators': 11537, 'learning_rate': 0.059865179252179844, 'max_depth': 5, 'min_child_weight': 19, 'subsample': 0.7182816961016713, 'colsample_bytree': 0.6152869254135704, 'colsample_bylevel': 0.8554809726533468, 'colsample_bynode': 0.5756567366341233, 'max_bin': 162, 'gamma': 10.726960079739728, 'reg_alpha': 2.8684644856322694, 'reg_lambda': 29.078970486673185, 'max_delta_step': 9, 'grow_policy': 'lossguide', 'max_leaves': 302}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:22:25,183] Trial 102 finished with value: 0.5763688760806917 and parameters: {'n_estimators': 7798, 'learning_rate': 0.061114888738785844, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.5351169732128092, 'colsample_bytree': 0.4299159852032889, 'colsample_bylevel': 0.7149010996930526, 'colsample_bynode': 0.60276375969728, 'max_bin': 131, 'gamma': 10.915284067930124, 'reg_alpha': 5.424627348550382, 'reg_lambda': 48.45458059269117, 'max_delta_step': 8, 'grow_policy': 'lossguide', 'max_leaves': 310}. Best is trial 73 with value: 0.5909090909090909.
# [I 2026-01-28 20:22:30,576] Trial 103 pruned.
# ...
# [I 2026-01-28 23:14:55,303] Trial 717 finished with value: 0.5760517799352751 and parameters: {'n_estimators': 9852, 'learning_rate': 0.06860382849944327, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 0.5494092937509742, 'colsample_bytree': 0.5092191571933311, 'colsample_bylevel': 0.6583924842594483, 'colsample_bynode': 0.6889372887644895, 'max_bin': 509, 'gamma': 7.014660993414579, 'reg_alpha': 2.7543430585346655, 'reg_lambda': 8.181093804449077, 'max_delta_step': 3, 'grow_policy': 'lossguide', 'max_leaves': 158}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:15:13,258] Trial 718 finished with value: 0.5384615384615384 and parameters: {'n_estimators': 6929, 'learning_rate': 0.07246513376682297, 'max_depth': 9, 'min_child_weight': 5, 'subsample': 0.594378603443573, 'colsample_bytree': 0.5859527180784986, 'colsample_bylevel': 0.5525996318627919, 'colsample_bynode': 0.6272221691338409, 'max_bin': 261, 'gamma': 4.937986547923825, 'reg_alpha': 15.057482932564392, 'reg_lambda': 7.484081553880107, 'max_delta_step': 1, 'grow_policy': 'depthwise'}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:15:32,858] Trial 719 finished with value: 0.5123152709359606 and parameters: {'n_estimators': 12421, 'learning_rate': 0.048278413192760765, 'max_depth': 10, 'min_child_weight': 26, 'subsample': 0.5727149352700389, 'colsample_bytree': 0.5490389960407706, 'colsample_bylevel': 0.8601520924172328, 'colsample_bynode': 0.7122922999845764, 'max_bin': 478, 'gamma': 9.567789640166115, 'reg_alpha': 0.25691809269610477, 'reg_lambda': 3.3275823231648323, 'max_delta_step': 0, 'grow_policy': 'lossguide', 'max_leaves': 99}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:15:47,691] Trial 720 finished with value: 0.5785714285714286 and parameters: {'n_estimators': 8115, 'learning_rate': 0.07463203124617818, 'max_depth': 8, 'min_child_weight': 16, 'subsample': 0.6075120794682561, 'colsample_bytree': 0.6317849899692578, 'colsample_bylevel': 0.5368047168794308, 'colsample_bynode': 0.7397358328531021, 'max_bin': 203, 'gamma': 8.507514590524858, 'reg_alpha': 17.483868049704395, 'reg_lambda': 11.381982361874893, 'max_delta_step': 2, 'grow_policy': 'lossguide', 'max_leaves': 211}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:16:02,063] Trial 721 finished with value: 0.5612903225806452 and parameters: {'n_estimators': 2838, 'learning_rate': 0.058838754485536986, 'max_depth': 3, 'min_child_weight': 21, 'subsample': 0.602625932001953, 'colsample_bytree': 0.4922696839697208, 'colsample_bylevel': 0.6519783273051656, 'colsample_bynode': 0.9451124551233466, 'max_bin': 152, 'gamma': 7.2873142293368005, 'reg_alpha': 2.9461324971489815, 'reg_lambda': 44.03861236740777, 'max_delta_step': 9, 'grow_policy': 'depthwise'}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:16:22,653] Trial 722 finished with value: 0.5785123966942148 and parameters: {'n_estimators': 11096, 'learning_rate': 0.06356619792219355, 'max_depth': 8, 'min_child_weight': 17, 'subsample': 0.5687385260225079, 'colsample_bytree': 0.5939669903542664, 'colsample_bylevel': 0.5892194756252708, 'colsample_bynode': 0.8500412900985059, 'max_bin': 481, 'gamma': 7.121424835204456, 'reg_alpha': 0.009246590524579518, 'reg_lambda': 19.243803737956583, 'max_delta_step': 1, 'grow_policy': 'lossguide', 'max_leaves': 160}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:16:44,333] Trial 723 finished with value: 0.5187032418952618 and parameters: {'n_estimators': 10383, 'learning_rate': 0.03112268754424624, 'max_depth': 9, 'min_child_weight': 18, 'subsample': 0.6454721508224276, 'colsample_bytree': 0.6779752835057207, 'colsample_bylevel': 0.5131530961467445, 'colsample_bynode': 0.5854232557248158, 'max_bin': 364, 'gamma': 4.42859944516604, 'reg_alpha': 6.312749717226749, 'reg_lambda': 20.413132332434316, 'max_delta_step': 2, 'grow_policy': 'depthwise'}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:16:53,944] Trial 724 pruned.
# [I 2026-01-28 23:17:02,261] Trial 725 pruned.
# [I 2026-01-28 23:17:20,599] Trial 726 finished with value: 0.5464788732394367 and parameters: {'n_estimators': 3611, 'learning_rate': 0.018812111550558838, 'max_depth': 7, 'min_child_weight': 41, 'subsample': 0.5754572653847814, 'colsample_bytree': 0.9667601881181543, 'colsample_bylevel': 0.8734184336052827, 'colsample_bynode': 0.5790536842604223, 'max_bin': 157, 'gamma': 10.890446260692343, 'reg_alpha': 0.9920714343966787, 'reg_lambda': 14.981931851250035, 'max_delta_step': 7, 'grow_policy': 'depthwise'}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:17:37,760] Trial 727 finished with value: 0.5822784810126582 and parameters: {'n_estimators': 13684, 'learning_rate': 0.0762214040847693, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.5107242926164182, 'colsample_bytree': 0.44617200295547055, 'colsample_bylevel': 0.5153255345740918, 'colsample_bynode': 0.7590010059701469, 'max_bin': 294, 'gamma': 9.55409346763716, 'reg_alpha': 8.53764514679951, 'reg_lambda': 4.363139782408481, 'max_delta_step': 1, 'grow_policy': 'lossguide', 'max_leaves': 264}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:17:55,433] Trial 728 finished with value: 0.5565217391304348 and parameters: {'n_estimators': 11217, 'learning_rate': 0.07995895864614781, 'max_depth': 7, 'min_child_weight': 20, 'subsample': 0.5809282008022523, 'colsample_bytree': 0.4139695390192135, 'colsample_bylevel': 0.7274641389772134, 'colsample_bynode': 0.8767076221719691, 'max_bin': 461, 'gamma': 9.156581855957578, 'reg_alpha': 4.520601267711738, 'reg_lambda': 17.510305431870187, 'max_delta_step': 3, 'grow_policy': 'depthwise'}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:18:00,509] Trial 729 pruned.
# [I 2026-01-28 23:18:17,608] Trial 730 finished with value: 0.5555555555555556 and parameters: {'n_estimators': 3253, 'learning_rate': 0.06082253386603507, 'max_depth': 9, 'min_child_weight': 29, 'subsample': 0.6242280923404506, 'colsample_bytree': 0.9527898718974388, 'colsample_bylevel': 0.9359211124367018, 'colsample_bynode': 0.5574914297148262, 'max_bin': 315, 'gamma': 11.385491813696698, 'reg_alpha': 9.119520830000951, 'reg_lambda': 33.356196307739104, 'max_delta_step': 10, 'grow_policy': 'lossguide', 'max_leaves': 181}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:18:38,817] Trial 731 finished with value: 0.5155555555555555 and parameters: {'n_estimators': 11353, 'learning_rate': 0.06243672607037349, 'max_depth': 10, 'min_child_weight': 11, 'subsample': 0.7679620918134906, 'colsample_bytree': 0.5479470143350261, 'colsample_bylevel': 0.7602055828422091, 'colsample_bynode': 0.6947314318534956, 'max_bin': 356, 'gamma': 3.9539818199197287, 'reg_alpha': 26.343898128048266, 'reg_lambda': 18.71299251733537, 'max_delta_step': 2, 'grow_policy': 'lossguide', 'max_leaves': 130}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:18:44,843] Trial 732 pruned.
# [I 2026-01-28 23:18:56,722] Trial 733 pruned.
# [I 2026-01-28 23:19:14,588] Trial 734 finished with value: 0.5740181268882175 and parameters: {'n_estimators': 3986, 'learning_rate': 0.057627192337120145, 'max_depth': 5, 'min_child_weight': 10, 'subsample': 0.6198740324334394, 'colsample_bytree': 0.40958828784032686, 'colsample_bylevel': 0.756133157518291, 'colsample_bynode': 0.7434470156447583, 'max_bin': 275, 'gamma': 8.444676060071544, 'reg_alpha': 16.912489601576375, 'reg_lambda': 26.849075938500917, 'max_delta_step': 5, 'grow_policy': 'depthwise'}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:19:29,584] Trial 735 finished with value: 0.554945054945055 and parameters: {'n_estimators': 8902, 'learning_rate': 0.06965827125009895, 'max_depth': 3, 'min_child_weight': 19, 'subsample': 0.5343931455447797, 'colsample_bytree': 0.5700234847669127, 'colsample_bylevel': 0.7547253628637896, 'colsample_bynode': 0.7138858576654062, 'max_bin': 283, 'gamma': 5.342313293171826, 'reg_alpha': 20.89523013919934, 'reg_lambda': 42.234210506578535, 'max_delta_step': 10, 'grow_policy': 'depthwise'}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:19:46,280] Trial 736 finished with value: 0.5333333333333333 and parameters: {'n_estimators': 3227, 'learning_rate': 0.07011860013857522, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.6782498026274512, 'colsample_bytree': 0.5537500720649903, 'colsample_bylevel': 0.7069499265697994, 'colsample_bynode': 0.9082005095611401, 'max_bin': 291, 'gamma': 0.6862525032466746, 'reg_alpha': 3.2961278673305143, 'reg_lambda': 43.92335059708752, 'max_delta_step': 7, 'grow_policy': 'depthwise'}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:20:07,680] Trial 737 finished with value: 0.5916230366492147 and parameters: {'n_estimators': 11628, 'learning_rate': 0.04758764673578681, 'max_depth': 10, 'min_child_weight': 3, 'subsample': 0.6802810978615773, 'colsample_bytree': 0.657688945708986, 'colsample_bylevel': 0.7001427837861178, 'colsample_bynode': 0.6061814113769596, 'max_bin': 387, 'gamma': 11.401666832014193, 'reg_alpha': 0.9673016734088669, 'reg_lambda': 11.92045188939274, 'max_delta_step': 2, 'grow_policy': 'lossguide', 'max_leaves': 268}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:20:29,258] Trial 738 finished with value: 0.5352798053527981 and parameters: {'n_estimators': 13755, 'learning_rate': 0.04112691683363402, 'max_depth': 10, 'min_child_weight': 21, 'subsample': 0.6146361523305007, 'colsample_bytree': 0.5545304532565604, 'colsample_bylevel': 0.7551920635613903, 'colsample_bynode': 0.8560430023458977, 'max_bin': 399, 'gamma': 6.652773546122722, 'reg_alpha': 4.775289761397565, 'reg_lambda': 13.257404284424974, 'max_delta_step': 0, 'grow_policy': 'lossguide', 'max_leaves': 97}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:20:58,518] Trial 739 finished with value: 0.524390243902439 and parameters: {'n_estimators': 13883, 'learning_rate': 0.01695781792612868, 'max_depth': 10, 'min_child_weight': 35, 'subsample': 0.5034905702975818, 'colsample_bytree': 0.5932706489568663, 'colsample_bylevel': 0.8792006154446275, 'colsample_bynode': 0.6811689936935218, 'max_bin': 506, 'gamma': 4.252318829148207, 'reg_alpha': 2.3205591130002197, 'reg_lambda': 3.63807929281797, 'max_delta_step': 0, 'grow_policy': 'lossguide', 'max_leaves': 158}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:21:06,004] Trial 740 pruned.
# [I 2026-01-28 23:21:30,150] Trial 741 finished with value: 0.5107398568019093 and parameters: {'n_estimators': 11619, 'learning_rate': 0.037478216058459246, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 0.6366017176104005, 'colsample_bytree': 0.5045678513683315, 'colsample_bylevel': 0.6967567772601854, 'colsample_bynode': 0.636990709494285, 'max_bin': 442, 'gamma': 10.6568190756868, 'reg_alpha': 13.708492003272006, 'reg_lambda': 5.53628528872404, 'max_delta_step': 1, 'grow_policy': 'lossguide', 'max_leaves': 154}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:21:39,662] Trial 742 pruned.
# [I 2026-01-28 23:21:54,322] Trial 743 pruned.
# [I 2026-01-28 23:22:10,355] Trial 744 finished with value: 0.47983014861995754 and parameters: {'n_estimators': 5815, 'learning_rate': 0.0334138948309424, 'max_depth': 6, 'min_child_weight': 19, 'subsample': 0.5280747873907049, 'colsample_bytree': 0.580789740739173, 'colsample_bylevel': 0.5605042678807953, 'colsample_bynode': 0.9546505338793944, 'max_bin': 138, 'gamma': 11.411254684321868, 'reg_alpha': 9.240901725704946, 'reg_lambda': 25.426022948111743, 'max_delta_step': 9, 'grow_policy': 'depthwise'}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:22:16,990] Trial 745 pruned.
# [I 2026-01-28 23:22:43,171] Trial 746 finished with value: 0.5760869565217391 and parameters: {'n_estimators': 11055, 'learning_rate': 0.0491483198149365, 'max_depth': 9, 'min_child_weight': 19, 'subsample': 0.5076055419125307, 'colsample_bytree': 0.6212796555694652, 'colsample_bylevel': 0.5903659915332655, 'colsample_bynode': 0.6755446238117891, 'max_bin': 494, 'gamma': 5.6864147315496405, 'reg_alpha': 1.237968461905136, 'reg_lambda': 11.55601022494552, 'max_delta_step': 0, 'grow_policy': 'lossguide', 'max_leaves': 172}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:22:52,845] Trial 747 pruned.
# [I 2026-01-28 23:23:10,549] Trial 748 finished with value: 0.5757575757575758 and parameters: {'n_estimators': 2272, 'learning_rate': 0.07626969398856, 'max_depth': 4, 'min_child_weight': 28, 'subsample': 0.6912474125143012, 'colsample_bytree': 0.46783931483946334, 'colsample_bylevel': 0.6116643102140308, 'colsample_bynode': 0.9853447198630175, 'max_bin': 263, 'gamma': 3.3814380762104825, 'reg_alpha': 21.04854405001238, 'reg_lambda': 43.0368418563444, 'max_delta_step': 9, 'grow_policy': 'lossguide', 'max_leaves': 263}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:23:40,336] Trial 749 finished with value: 0.5608108108108109 and parameters: {'n_estimators': 12881, 'learning_rate': 0.026093248143148392, 'max_depth': 9, 'min_child_weight': 10, 'subsample': 0.6092937262359054, 'colsample_bytree': 0.452613990714078, 'colsample_bylevel': 0.6954818993291592, 'colsample_bynode': 0.8072499041200211, 'max_bin': 504, 'gamma': 9.599389761601067, 'reg_alpha': 0.24804201277992766, 'reg_lambda': 11.264941931333276, 'max_delta_step': 1, 'grow_policy': 'lossguide', 'max_leaves': 204}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:23:45,449] Trial 750 pruned.
# [I 2026-01-28 23:23:55,005] Trial 751 pruned.
# [I 2026-01-28 23:24:17,580] Trial 752 finished with value: 0.3956989247311828 and parameters: {'n_estimators': 13593, 'learning_rate': 0.0024992133378603037, 'max_depth': 2, 'min_child_weight': 41, 'subsample': 0.910029595994877, 'colsample_bytree': 0.8985136755249687, 'colsample_bylevel': 0.7448983632726276, 'colsample_bynode': 0.6181682597591209, 'max_bin': 331, 'gamma': 8.415747154847303, 'reg_alpha': 11.923689964812734, 'reg_lambda': 11.077567048973092, 'max_delta_step': 7, 'grow_policy': 'depthwise'}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:24:24,627] Trial 753 pruned.
# [I 2026-01-28 23:24:29,654] Trial 754 pruned.
# [I 2026-01-28 23:24:44,187] Trial 755 finished with value: 0.5775075987841946 and parameters: {'n_estimators': 6178, 'learning_rate': 0.06328193189019106, 'max_depth': 10, 'min_child_weight': 28, 'subsample': 0.5520347465764454, 'colsample_bytree': 0.5145669503977137, 'colsample_bylevel': 0.5904899921742818, 'colsample_bynode': 0.9356241500649238, 'max_bin': 141, 'gamma': 10.70429120862768, 'reg_alpha': 2.882273628456023, 'reg_lambda': 20.48964816346693, 'max_delta_step': 9, 'grow_policy': 'depthwise'}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:25:01,461] Trial 756 finished with value: 0.5722543352601156 and parameters: {'n_estimators': 8225, 'learning_rate': 0.06535795017958221, 'max_depth': 5, 'min_child_weight': 14, 'subsample': 0.5821495475231441, 'colsample_bytree': 0.5518494852545563, 'colsample_bylevel': 0.6129068549844341, 'colsample_bynode': 0.5417750321811221, 'max_bin': 181, 'gamma': 2.0897793510714493, 'reg_alpha': 5.709824999708272, 'reg_lambda': 4.59113942206223, 'max_delta_step': 0, 'grow_policy': 'depthwise'}. Best is trial 455 with value: 0.621160409556314.
# [I 2026-01-28 23:25:10,497] Trial 757 pruned.
# [I 2026-01-28 23:25:21,909] Trial 758 pruned.
# Optuna best OOF F1: 0.621160409556314
# Best params:
# n_estimators = 13766
# learning_rate = 0.050603476812327144
# max_depth = 10
# min_child_weight = 9
# subsample = 0.5723283701529599
# colsample_bytree = 0.516403894620754
# colsample_bylevel = 0.7799543042418213
# colsample_bynode = 0.7212143975334366
# max_bin = 428
# gamma = 11.452693842650536
# reg_alpha = 14.18474346691553
# reg_lambda = 17.70580633614985
# max_delta_step = 1
# grow_policy = lossguide
# max_leaves = 165

# %%
import numpy as np

def save_feature_tables(train_feat, test_feat, feature_cols, out_prefix="feat"):
    train_df = train_feat.copy()
    test_df  = test_feat.copy()

    meta_train = [c for c in ["object_id", "split", "target", "photoz_aug"] if c in train_df.columns]
    meta_test  = [c for c in ["object_id", "split", "photoz_aug"] if c in test_df.columns]

    missing_tr = [c for c in feature_cols if c not in train_df.columns]
    missing_te = [c for c in feature_cols if c not in test_df.columns]
    if missing_tr or missing_te:
        raise ValueError(f"Missing cols. train missing={missing_tr[:10]} test missing={missing_te[:10]}")

    for c in feature_cols:
        train_df[c] = train_df[c].astype(np.float32)
        test_df[c]  = test_df[c].astype(np.float32)

    train_out = train_df[meta_train + feature_cols]
    test_out  = test_df[meta_test  + feature_cols]

    train_path = f"{out_prefix}_train.csv.gz"
    test_path  = f"{out_prefix}_test.csv.gz"

    train_out.to_csv(train_path, index=False, compression="gzip")
    test_out.to_csv(test_path, index=False, compression="gzip")

    print("Saved:", train_path, train_out.shape)
    print("Saved:", test_path, test_out.shape)

save_feature_tables(train_feat, test_feat, selected_cols, out_prefix="mallorn_tabular")
# Out:
# Saved: mallorn_tabular_train.csv.gz (9129, 384)
# Saved: mallorn_tabular_test.csv.gz (7135, 383)

# %%
p_test_xgb, th_xgb, oof_xgb_base = predict_xgb_multiseed_augtrain(
    train_feat, test_feat, best_params,
    feature_cols=selected_cols,
    n_splits_oof=10,
    seeds=SEEDS
)
# Out:
# XGB base-OOF best_th: 0.6588577330112457
# XGB base-OOF best_F1: 0.5816993464052288
# XGB base-OOF AP: 0.5645702654577617

# %% [markdown]
# 20 fold result:
# XGB base-OOF best_th: 0.5860117375850677
# XGB base-OOF best_F1: 0.6184971098265896
# XGB base-OOF AP: 0.5335738973125117

# %%
test_pred = (p_test_xgb > th_xgb).astype(int)

sub = pd.DataFrame({
    "object_id": test_feat["object_id"].values,
    "target": test_pred
})
out_name = "XGB_only_model6.csv"
sub.to_csv(out_name, index=False)
print("Saved", out_name, " threshold:", th_xgb)
# Out:
# Saved XGB_only_model6.csv  threshold: 0.5860117375850677

# %%
lgb_params = dict(
    n_estimators=20000,
    learning_rate=0.01,
    num_leaves=127,
    min_child_samples=30,
    subsample=0.8,
    subsample_freq=1,
    colsample_bytree=0.8,
    reg_alpha=1.0,
    reg_lambda=10.0,
    verbosity=-1,
    force_col_wise=True,
    extra_trees=True,
)

p_test_lgb, th_lgb, oof_lgb_base = predict_lgb_multiseed_augtrain(
    train_feat, test_feat, lgb_params,
    feature_cols=selected_cols,
    n_splits_oof=min(FINAL_OOF_FOLDS, len(train_splits)),
    seeds=SEEDS
)
# Out:
# LGB base-OOF best_th: 0.1916771905353098
# LGB base-OOF best_F1: 0.46881720430107526
# LGB base-OOF AP: 0.4916098119929631

# %%
def best_blend_weight_and_threshold(y, oof_a, oof_b, grid=np.linspace(0, 1, 101)):
    best = {"w": None, "th": None, "f1": -1.0}
    for w in grid:
        oof = w * oof_a + (1 - w) * oof_b
        th, f1 = best_threshold_f1(y, oof)
        if f1 > best["f1"]:
            best.update(w=float(w), th=float(th), f1=float(f1))
    return best

# %%
y_base = train_feat.loc[train_feat["photoz_aug"].fillna(0).astype(int) == 0, "target"].astype(int).to_numpy()

best = best_blend_weight_and_threshold(y_base, oof_xgb_base, oof_lgb_base)
print("Best blend:", best)
# Out:
# Best blend: {'w': 1.0, 'th': 0.5860117375850677, 'f1': 0.6184971098265896}

# %% [markdown]
# Best blend: {'w': 0.99, 'th': 0.5833887217355469, 'f1': 0.6184971098265896}

# %%
w = best["w"]
p_final = w * p_test_xgb + (1 - w) * p_test_lgb
test_pred = (p_final > best["th"]).astype(int)

sub = pd.DataFrame({
    "object_id": test_feat["object_id"].values,
    "target": test_pred
})

out_name = "XGB+LGBM_model6.csv"
sub.to_csv(out_name, index=False)
print("Saved", out_name, " threshold:", best["th"], " positives:", int(test_pred.sum()))
# Out:
# Saved XGB+LGBM_model6.csv  threshold: 0.5833887217355469  positives: 336

# %% [markdown]
# Saved XGB+LGBM_model6.csv  threshold: 0.5833887217355469  positives: 336
